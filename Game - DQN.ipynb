# %%
# %pip install pygame
# %pip install numpy
# %pip install tensorflow

# %%
import random
import numpy as np
import tensorflow as tf

# Set a specific integer for reproducibility
SEED_VALUE = 20250506

# 1. Set seed for Python's built-in random module
random.seed(SEED_VALUE)

# 2. Set seed for NumPy operations
np.random.seed(SEED_VALUE)

# 3. Set seed for TensorFlow (affects weight initialization and some GPU operations)
tf.random.set_seed(SEED_VALUE)
# Note: You might also need to set some environment variables for complete determinism

# %%
import pygame
from datetime import datetime

pygame.init()

# ----------------
# Constants
# ----------------
DISPLAY_INFO = pygame.display.Info()
MONITOR_WIDTH = DISPLAY_INFO.current_w
MONITOR_HEIGHT = DISPLAY_INFO.current_h

SCREEN_WIDTH = int(MONITOR_WIDTH * 0.6)
SCREEN_HEIGHT = int(MONITOR_HEIGHT * 0.8)

GRID_SIZE = 8
AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
AVAILABLE_WIDTH = SCREEN_WIDTH - 40

TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
MARGIN = 150

MINE_COUNT = 5
FLAG_LIMIT = 5
MAX_LIVES = 3

FILE_NAME = f"{datetime.now().strftime('%Y%m%d_%H%M%S')}"
LOG_NAME = f"dqn_logs_{FILE_NAME}.txt"
MODEL_NAME = f"dqn_model_{FILE_NAME}"

AUTO_QUIT = False
# Out:
# e:\Files\School Files\Reinforcement Learning\Project\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import os
import json
from datetime import datetime
from DQN import DQN

def saveModel(modelName: str, agent: DQN):
    """Saves the agent's model weights and training metrics."""
    modelsDir = "./models"
    if not os.path.exists(modelsDir):
        os.makedirs(modelsDir)
    
    filePath = os.path.join(modelsDir, modelName)
    weightsPathQ = f'{filePath}_qnetwork.weights.h5'
    weightsPathTarget = f'{filePath}_targetnetwork.weights.h5'
    metricsPath = f'{filePath}_metrics.json'
    
    print(f"\nSaving progress to {filePath}...")
    
    # Save both networks
    agent.qNetwork.save_weights(weightsPathQ)
    agent.targetNetwork.save_weights(weightsPathTarget)
    
    # Prepare metrics data
    metricsData = {
        "EPISODES": agent.EPISODES,
        "ELAPSED_TIME": agent.ELAPSED_TIME,
        "GAME_CONCLUSIONS": agent.GAME_CONCLUSIONS,
        "WIN_RATE": agent.WIN_RATE,
        "HIGHEST_SCORE": agent.HIGHEST_SCORE,
        "SCORES": agent.SCORES,
        "TIME_EFFICIENCY": agent.TIME_EFFICIENCY,
        "CLICKS": agent.CLICKS,
        "EPSILON": agent.epsilon,
        "TRAIN_STEP": agent.TRAIN_STEP,
    }
    
    with open(metricsPath, 'w') as f:
        json.dump(metricsData, f, indent=4)
        
    print("Progress saved successfully.")

def loadModel(modelName: str, agent: DQN) -> DQN:
    """Loads the agent's model weights and training metrics."""
    filePath = os.path.join("./models", modelName)
    weightsPathQ = f'{filePath}_qnetwork.weights.h5'
    weightsPathTarget = f'{filePath}_targetnetwork.weights.h5'
    metricsPath = f'{filePath}_metrics.json'
    
    if os.path.exists(weightsPathQ) and os.path.exists(weightsPathTarget) and os.path.exists(metricsPath):
        print(f"\nLoading progress from {filePath}...")
        
        agent.qNetwork.load_weights(weightsPathQ)
        agent.targetNetwork.load_weights(weightsPathTarget)
        
        with open(metricsPath, 'r') as f:
            metricsData = json.load(f)
        
        agent.EPISODES = metricsData.get("EPISODES", 1)
        agent.ELAPSED_TIME = metricsData.get("ELAPSED_TIME", [])
        agent.GAME_CONCLUSIONS = metricsData.get("GAME_CONCLUSIONS", [])
        agent.WIN_RATE = metricsData.get("WIN_RATE", 0.0)
        agent.HIGHEST_SCORE = metricsData.get("HIGHEST_SCORE", 0)
        agent.SCORES = metricsData.get("SCORES", [])
        agent.TIME_EFFICIENCY = metricsData.get("TIME_EFFICIENCY", 0.0)
        agent.CLICKS = metricsData.get("CLICKS", {"left": [], "right": [], "total": []})
        agent.epsilon = metricsData.get("EPSILON", agent.EPSILON_START)
        agent.TRAIN_STEP = metricsData.get("TRAIN_STEP", 0)
        
        if isinstance(agent.LR, dict):
            currentLR = agent.optimizer.learning_rate.numpy()
            newLR = currentLR
            
            for milestone in sorted(agent.LR.keys()):
                if agent.EPISODES >= milestone:
                    newLR = agent.LR[milestone]
            
            if newLR != currentLR:
                print(f"[LR Scheduler] Loaded at Episode {agent.EPISODES}: Setting learning rate to {newLR:.6f}")
                agent.optimizer.learning_rate.assign(newLR)
        
        print("Progress loaded successfully.")
    else:
        print("\nNo saved progress found. Starting a new training run.")
        
    return agent

def log(string: str) -> str:
    if not os.path.exists("logs"):
        os.makedirs("logs")

    logName = os.path.join("logs", LOG_NAME)

    if not os.path.exists(logName):
        with open(logName, "w") as f:
            f.write(f"Log created on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write("="*50 + "\n")

    with open(logName, "a") as f:
        f.write(string + "\n")

    return string

# %%
# Cell 5: Minesweeper Game Class
import pygame
import random

pygame.init()

display_info = pygame.display.Info()
MONITOR_WIDTH = display_info.current_w
MONITOR_HEIGHT = display_info.current_h

SCREEN_WIDTH = int(MONITOR_WIDTH * 0.6)
SCREEN_HEIGHT = int(MONITOR_HEIGHT * 0.8)

GRID_SIZE = 8
AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
AVAILABLE_WIDTH = SCREEN_WIDTH - 40

TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
MARGIN = 150

MINE_COUNT = 5
FLAG_LIMIT = 5
LIVES = 3

# Colors
BG_COLOR = (40, 44, 52)
PANEL_COLOR = (30, 34, 42)
UNREVEALED_COLOR = (58, 95, 135)
UNREVEALED_HOVER_COLOR = (75, 115, 160)
REVEALED_COLOR = (220, 220, 225)
MINE_COLOR = (215, 95, 95)
FLAG_COLOR = (255, 50, 50)
BORDER_COLOR = (20, 20, 25)
LIFE_COLOR = (255, 80, 80)

NUMBER_COLORS = {
    1: (45, 85, 165),
    2: (60, 145, 70),
    3: (185, 60, 60),
    4: (35, 60, 135),
    5: (150, 50, 50),
    6: (50, 140, 140),
    7: (40, 40, 40),
    8: (100, 100, 100)
}

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT), pygame.RESIZABLE)
pygame.display.set_caption("Minesweeper RL - DQN")

class Tile:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.is_mine = False
        self.is_revealed = False
        self.is_flagged = False
        self.adjacent_mines = 0
        self.hover = False

class MinesweeperGame:
    def __init__(self):
        self.grid = [[Tile(x, y) for y in range(GRID_SIZE)] for x in range(GRID_SIZE)]
        self.game_over = False
        self.game_won = False
        self.flags_placed = 0
        self.flag_limit = FLAG_LIMIT
        self.revealed_count = 0
        self.score = 0
        self.start_time = pygame.time.get_ticks()
        self.end_time = None
        self.combo = 0
        self.max_combo = 0
        self.lives = LIVES
        self.total_mines = MINE_COUNT
        self.mines_hit = []
        self.setup_mines()
        self.calculate_adjacent_mines()
    
    def setup_mines(self):
        mines_placed = 0
        while mines_placed < self.total_mines:
            x = random.randint(0, GRID_SIZE - 1)
            y = random.randint(0, GRID_SIZE - 1)
            if not self.grid[x][y].is_mine:
                self.grid[x][y].is_mine = True
                mines_placed += 1
    
    def calculate_adjacent_mines(self):
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                if not self.grid[x][y].is_mine:
                    count = 0
                    for dx in [-1, 0, 1]:
                        for dy in [-1, 0, 1]:
                            if dx == 0 and dy == 0:
                                continue
                            nx, ny = x + dx, y + dy
                            if 0 <= nx < GRID_SIZE and 0 <= ny < GRID_SIZE:
                                if self.grid[nx][ny].is_mine:
                                    count += 1
                    self.grid[x][y].adjacent_mines = count
    
    def reveal_tile(self, x, y):
        if self.game_over or self.game_won:
            return
        
        tile = self.grid[x][y]
        if tile.is_revealed or tile.is_flagged:
            return
        
        tile.is_revealed = True
        self.revealed_count += 1
        
        if tile.is_mine:
            self.lives -= 1
            self.combo = 0
            self.mines_hit.append((x, y))
            
            if self.lives <= 0:
                self.game_over = True
                self.end_time = pygame.time.get_ticks()
                self.reveal_all_mines()
            return
        
        if tile.adjacent_mines == 0:
            self.score += 10
            self.combo += 1
        else:
            self.score += tile.adjacent_mines * 5
            self.combo += 1
        
        if self.combo > 5:
            self.score += self.combo * 2
        
        self.max_combo = max(self.max_combo, self.combo)
        
        if tile.adjacent_mines == 0:
            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    if dx == 0 and dy == 0:
                        continue
                    nx, ny = x + dx, y + dy
                    if 0 <= nx < GRID_SIZE and 0 <= ny < GRID_SIZE:
                        self.reveal_tile(nx, ny)
        
        non_mine_tiles = GRID_SIZE * GRID_SIZE - self.total_mines
        safe_tiles_revealed = self.revealed_count - len(self.mines_hit)
        
        if safe_tiles_revealed == non_mine_tiles:
            self.game_won = True
            self.end_time = pygame.time.get_ticks()
            time_bonus = max(0, 1000 - (self.end_time - self.start_time) // 100)
            self.score += time_bonus
            if self.flags_placed == MINE_COUNT:
                self.score += 500
            self.score += self.lives * 200
    
    def toggle_flag(self, x, y):
        if self.game_over or self.game_won:
            return
        tile = self.grid[x][y]
        if not tile.is_revealed:
            if tile.is_flagged:
                tile.is_flagged = False
                self.flags_placed -= 1
                self.combo = 0
                if tile.is_mine:
                    self.score -= 50
            elif self.flags_placed < self.flag_limit:
                tile.is_flagged = True
                self.flags_placed += 1
                if tile.is_mine:
                    self.score += 50
                self.combo = 0
    
    def reveal_all_mines(self):
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                if self.grid[x][y].is_mine:
                    self.grid[x][y].is_revealed = True

# %%
from typing import Optional
from DQN import DQN

def get_tile_from_mouse(mx, my):
    if my < MARGIN or my >= MARGIN + GRID_SIZE * TILE_SIZE:
        return None, None
    if mx < (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2:
        return None, None
    if mx >= (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2 + GRID_SIZE * TILE_SIZE:
        return None, None
    
    offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
    grid_x = (mx - offset_x) // TILE_SIZE
    grid_y = (my - MARGIN) // TILE_SIZE
    
    if 0 <= grid_x < GRID_SIZE and 0 <= grid_y < GRID_SIZE:
        return int(grid_x), int(grid_y)
    
    return None, None

def draw_game(game, agent: Optional[DQN] = None):
    screen.fill(BG_COLOR)
    
    pygame.draw.rect(screen, PANEL_COLOR, (0, 0, SCREEN_WIDTH, MARGIN))
    pygame.draw.rect(screen, PANEL_COLOR, (0, SCREEN_HEIGHT - 80, SCREEN_WIDTH, 80))
    
    offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
    offset_y = MARGIN
    
    for x in range(GRID_SIZE):
        for y in range(GRID_SIZE):
            tile = game.grid[x][y]
            rect = pygame.Rect(offset_x + x * TILE_SIZE, offset_y + y * TILE_SIZE, TILE_SIZE, TILE_SIZE)
            
            pygame.draw.rect(screen, BORDER_COLOR, rect, 3)
            inner_rect = rect.inflate(-6, -6)
            
            if tile.is_revealed:
                if tile.is_mine:
                    pygame.draw.rect(screen, MINE_COLOR, inner_rect)
                    center = inner_rect.center
                    pygame.draw.circle(screen, (40, 40, 40), center, 20)
                    if (x, y) in game.mines_hit:
                        pygame.draw.line(screen, (255, 255, 255), 
                                       (center[0] - 12, center[1] - 12), 
                                       (center[0] + 12, center[1] + 12), 4)
                        pygame.draw.line(screen, (255, 255, 255), 
                                       (center[0] + 12, center[1] - 12), 
                                       (center[0] - 12, center[1] + 12), 4)
                else:
                    pygame.draw.rect(screen, REVEALED_COLOR, inner_rect)
                    if tile.adjacent_mines > 0:
                        font = pygame.font.Font(None, 60)
                        text = font.render(str(tile.adjacent_mines), True, NUMBER_COLORS[tile.adjacent_mines])
                        text_rect = text.get_rect(center=inner_rect.center)
                        screen.blit(text, text_rect)
            else:
                if tile.hover:
                    pygame.draw.rect(screen, UNREVEALED_HOVER_COLOR, inner_rect)
                else:
                    pygame.draw.rect(screen, UNREVEALED_COLOR, inner_rect)
                
                if tile.is_flagged:
                    center_x, center_y = inner_rect.center
                    pygame.draw.rect(screen, (60, 60, 60), (center_x - 2, center_y - 20, 4, 35))
                    flag_points = [
                        (center_x + 2, center_y - 18),
                        (center_x + 22, center_y - 8),
                        (center_x + 2, center_y + 2)
                    ]
                    pygame.draw.polygon(screen, FLAG_COLOR, flag_points)
                    pygame.draw.polygon(screen, (180, 30, 30), flag_points, 2)

    if agent is not None and agent.LAST_ACTION is not None:
        x, y, action_type = agent.LAST_ACTION
        
        offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
        offset_y = MARGIN
        
        action_x = offset_x + x * TILE_SIZE + TILE_SIZE // 2
        action_y = offset_y + y * TILE_SIZE + TILE_SIZE // 2
        
        color = (100, 200, 255) if action_type == 0 else (255, 100, 100)
        pygame.draw.circle(screen, color, (action_x, action_y), TILE_SIZE // 2, 5)
    
    font_large = pygame.font.Font(None, 48)
    font_medium = pygame.font.Font(None, 36)
    font_small = pygame.font.Font(None, 28)
    font_xsmall = pygame.font.Font(None, 20)
    
    if game.end_time:
        elapsed = (game.end_time - game.start_time) // 1000
    else:
        elapsed = (pygame.time.get_ticks() - game.start_time) // 1000
    
    if game.game_over:
        text = font_large.render("GAME OVER!", True, (235, 100, 95))
        screen.blit(text, (SCREEN_WIDTH // 2 - text.get_width() // 2, 30))
        score_text = font_medium.render(f"Final Score: {game.score}", True, (255, 200, 100))
        screen.blit(score_text, (SCREEN_WIDTH // 2 - score_text.get_width() // 2, 80))
    elif game.game_won:
        text = font_large.render("YOU WIN!", True, (90, 200, 110))
        screen.blit(text, (SCREEN_WIDTH // 2 - text.get_width() // 2, 30))
        score_text = font_medium.render(f"Final Score: {game.score}", True, (100, 255, 150))
        screen.blit(score_text, (SCREEN_WIDTH // 2 - score_text.get_width() // 2, 80))
    else:
        text1 = font_medium.render(f"Score: {game.score}", True, (255, 215, 0))
        text2 = font_medium.render(f"Time: {elapsed}s", True, (100, 200, 255))
        screen.blit(text1, (30, 30))
        screen.blit(text2, (30, 65))
        
        heart_y = 100
        for i in range(LIVES):
            heart_x = 40 + i * 35
            if i < game.lives:
                color = LIFE_COLOR
            else:
                color = (80, 80, 80)
            
            pygame.draw.circle(screen, color, (heart_x, heart_y), 10)
            pygame.draw.circle(screen, color, (heart_x + 14, heart_y), 10)
            heart_points = [
                (heart_x - 10, heart_y + 3),
                (heart_x + 7, heart_y + 20),
                (heart_x + 24, heart_y + 3)
            ]
            pygame.draw.polygon(screen, color, heart_points)
        
        mines_left = MINE_COUNT - game.flags_placed
        text3 = font_medium.render(f"Mines: {mines_left}", True, (240, 200, 120))
        text4 = font_medium.render(f"Flags: {game.flags_placed}/{FLAG_LIMIT}", True, (120, 180, 230))
        screen.blit(text3, (SCREEN_WIDTH - 200, 30))
        screen.blit(text4, (SCREEN_WIDTH - 200, 65))
        
        if game.combo > 3:
            combo_text = font_medium.render(f"Combo x{game.combo}!", True, (255, 100, 255))
            yPos = 30 if agent is None else 5
            screen.blit(combo_text, (SCREEN_WIDTH // 2 - combo_text.get_width() // 2, yPos))

    if agent is not None:
        metrics_y = 36
        metrics = [
            agent.printMetrics(["Win Rate"], True),
            agent.printMetrics(["Episodes", "Current Episode"], True),
            agent.printMetrics(["Highest Score"], True),
            agent.printMetrics(["Time Efficiency"], True),
            agent.printMetrics(["Left Click Avg", "Right Click Avg"], True),
            agent.printMetrics(["Total Click Avg"], True),
            agent.printMetrics(["Game Conclusion History"], True)
        ]

        for metric in metrics:
            metric_text = font_xsmall.render(metric, True, (200, 200, 200))
            screen.blit(metric_text, (SCREEN_WIDTH // 2 - metric_text.get_width() // 2, metrics_y))
            metrics_y += metric_text.get_height()
    
    text1 = font_small.render("Left Click: Reveal", True, (200, 200, 200))
    text2 = font_small.render("Right Click: Flag", True, (200, 200, 200))
    text3 = font_small.render("R: Restart", True, (200, 200, 200))

    if agent is not None:
        text4 = font_small.render("Blue: Reveal", True, (100, 200, 255))
        text5 = font_small.render("Red: Flag", True, (255, 100, 100))
        screen.blit(text4, (SCREEN_WIDTH - 150, SCREEN_HEIGHT - 75))
        screen.blit(text5, (SCREEN_WIDTH - 150, SCREEN_HEIGHT - 25))
    
    screen.blit(text1, (30, SCREEN_HEIGHT - 50))
    screen.blit(text2, (250, SCREEN_HEIGHT - 50))
    screen.blit(text3, (450, SCREEN_HEIGHT - 50))

# %% [markdown]
# # Key Implementation Changes
#
# The initial proposal provided a strong foundation. The following changes were implemented during development to improve the training effectiveness and final performance of the Actor-Critic agent.

# %% [markdown]
# ## Enhanced Agent State ($S_t$)
#
# The agent's state representation was enhanced to provide a richer understanding of the environment. This allows the agent to make more intelligent decisions and prevents it from getting stuck in unproductive loops.
#
# The original proposed state included:
#
# - Visible Grid
# - Score
# - Lives
# - Flags
# - Combo
# - Game Status (active/won/lost)
#
# The final implementation was updated to these:
#
# - **Visible Grid:** The board state.
# - **Lives:** Tracks how many lives are left in the episode.
# - **Combo:** Tracks the real-time combo in the run.
# - **Flags:** Tracks how many flags are left allowed to be place on the board.
# - **Progress:** Tracks the ratio of revealed safe tiles to the total number of safe tiles.
# - **Interaction History:** Encodes how recently the agent has interacted with each tiles. Basically a history of actions.

# %% [markdown]
# ## Simplified Reward Function ($R_t$)
#
# The initial reward function, tied to the complex in-game score, proved to be a noisy signal that limited the agent's performance (resulting in a 5-13% win rate). Therefore, it was replaced with a simplified, sparse reward function to provide a clearer learning objective.
#
# The new function is based on four simple rules:
#
# - **Win Bonus:** A large positive reward of **+100** is given when the agent successfully clears all non-mine tiles. This defines the ultimate goal.
# - **Loss Penalty:** A large negative penalty of **-100** is given when the agent loses its last life or runs out of time. This clearly punishes failure.
# - **Progress Reward:** A small positive reward of **+1 is given for each new safe tile** the agent successfully reveals in a single turn. This encourages the agent to explore and clear the board.
# - **Efficiency Penalty:** A tiny negative penalty of **-0.1 is applied for every action taken**. This incentivizes the agent to win in as few steps as possible.

# %%
from DQN import DQN
import numpy as np

game = None
agent = None

def main():
    global SCREEN_WIDTH, SCREEN_HEIGHT, TILE_SIZE, screen, game, agent

    game = MinesweeperGame()
    agent = DQN(
        gridSize=GRID_SIZE,
        maxLives=LIVES,
        gameInstance=game,
        discountFactor=0.99,
        lr={
            0: 0.001,
            2000: 0.0005,
            5000: 0.0001,
        },
        bufferSize=50000,
        batchSize=64,
        targetUpdateFreq=100,
        epsilonStart=1.0,
        epsilonEnd=0.01,
        epsilonDecay=0.995
    )
    
    clock = pygame.time.Clock()
    running = True

    def clickHandler():
        mx, my = pygame.mouse.get_pos()
        gridX, gridY = get_tile_from_mouse(mx, my)
            
        if gridX is not None:
            if event.button == 1:
                game.reveal_tile(gridX, gridY)
            elif event.button == 3:
                game.toggle_flag(gridX, gridY)
        return

    def agentTurnLogic():
        global game, agent

        done = False
        elapsedTime = ((pygame.time.get_ticks() - game.start_time) / 1000)
        
        if not (game.game_over or game.game_won):
            
            stateCurrent = agent._encodeState()
            x, y, actionType, actionIdx, _ = agent.chooseAction(stateCurrent)
            
            agent.ACTION_HISTORY.append((x, y, actionType))
            if len(agent.ACTION_HISTORY) > agent.ACTION_HISTORY_SIZE:
                agent.ACTION_HISTORY.pop(0)
            
            agent.TILE_INTERACTION_HISTORY[(x, y)] = len(agent.ACTION_HISTORY)
            agent.LAST_ACTION = (x, y, actionType)
            
            livesOld = game.lives
            revealedOld = game.revealed_count
            reward = 0

            if actionType == 0:
                game.reveal_tile(x, y)
            else:
                game.toggle_flag(x, y)

            # Simplified Reward Calculation
            reward -= 0.1
            
            mine_hit = livesOld > game.lives
            if not mine_hit:
                newly_revealed = game.revealed_count - revealedOld
                if newly_revealed > 0:
                    reward += newly_revealed * 1.0

            done = game.game_over or game.game_won
            if done:
                if game.game_won:
                    reward += 100
                else:
                    reward += -100
            
            if len(agent.CLICKS["left"]) < agent.EPISODES:
                agent.CLICKS["left"].append(0)
                agent.CLICKS["right"].append(0)
                agent.CLICKS["total"].append(0)

            agent.CLICKS["total"][agent.EPISODES - 1] += 1
            if actionType == 0:
                agent.CLICKS["left"][agent.EPISODES - 1] += 1
            else:
                agent.CLICKS["right"][agent.EPISODES - 1] += 1

            if elapsedTime > 45:
                game.game_over = True
                done = True
                if not game.game_won:
                    reward = -100
                print(log("Game terminated: Time limit exceeded"))

            reward = np.clip(reward, -100, 100)
            
            stateNext = agent._encodeState()
            
            # Store transition in replay buffer
            agent.storeTransition(stateCurrent, actionIdx, reward, stateNext, done)
            
            # Train the agent
            loss = agent.train()
            
            if agent.CLICKS["total"][agent.EPISODES - 1] % 10 == 0 or done:
                loss_str = f"{loss:.4f}" if loss is not None else "N/A"
                print(log(f"[Ep {agent.EPISODES}, Step {agent.CLICKS['total'][agent.EPISODES - 1]}] "
                    f"Score: {game.score} | Reward: {reward:.2f} | Loss: {loss_str} | "
                    f"Epsilon: {agent.epsilon:.4f} | "
                    f"Action: ({x}, {y}) {'Reveal' if actionType == 0 else 'Flag'} | "
                    f"Revealed: {game.revealed_count}/{GRID_SIZE * GRID_SIZE - game.total_mines}"))

        if game.game_over or game.game_won:
            draw_game(game, agent)
            pygame.display.flip()
            pygame.time.delay(1000)

            game = MinesweeperGame()
            agent.endEpisode(game)

            print(log(f"\n{'='*60}"))
            print(log(f"Episode {agent.EPISODES - 1} finished: {'WIN' if agent.GAME_CONCLUSIONS[-1] else 'LOSS'} | Score: {agent.SCORES[-1]}"))
            print(log(agent.printMetrics(asString=True)))
            print(log(f"{'='*60}\n"))

        return done

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.VIDEORESIZE:
                SCREEN_WIDTH, SCREEN_HEIGHT = event.w, event.h
                screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT), pygame.RESIZABLE)
                
                AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
                AVAILABLE_WIDTH = SCREEN_WIDTH - 40
                TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
                
            elif event.type == pygame.MOUSEBUTTONDOWN:
                clickHandler()
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_r:
                    game = MinesweeperGame()

        if agent is not None:
            gameDone = agentTurnLogic()

            # Stop after 300 episodes
            if agent.EPISODES > 300 and gameDone:
                saveModel(MODEL_NAME, agent)
                running = False
                return

        mx, my = pygame.mouse.get_pos()
        hoverX, hoverY = get_tile_from_mouse(mx, my)
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                game.grid[x][y].hover = (x == hoverX and y == hoverY)
        
        draw_game(game, agent)
        pygame.display.flip()
        clock.tick(60)

    if AUTO_QUIT:
        pygame.quit()

if __name__ == "__main__":
    main()
# Out:
# [Ep 1, Step 10] Score: 2752 | Reward: -0.10 | Loss: N/A | Epsilon: 1.0000 | Action: (7, 4) Flag | Revealed: 50/59
# [Ep 1, Step 20] Score: 2812 | Reward: -0.10 | Loss: N/A | Epsilon: 1.0000 | Action: (6, 4) Reveal | Revealed: 53/59
# [Ep 1, Step 30] Score: 2832 | Reward: -0.10 | Loss: N/A | Epsilon: 1.0000 | Action: (6, 2) Flag | Revealed: 57/59
# [Ep 1, Step 31] Score: 2832 | Reward: -100.00 | Loss: N/A | Epsilon: 1.0000 | Action: (6, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 1 finished: LOSS | Score: 2832
# Episodes: 1 | Win Rate: 0.00% | Highest Score: 2832.00 | Time Efficiency: 9.95 steps/sec | Left Click Avg: 14.00 c/g (4.49 c/s) | Right Click Avg: 17.00 c/g (5.45 c/s) | Total Click Avg: 31.00 c/g (9.95 c/s) | Game Conclusion History: 0 Wins, 1 Losses
# ============================================================
#
# [Ep 2, Step 10] Score: 1153 | Reward: 26.90 | Loss: N/A | Epsilon: 0.9950 | Action: (5, 0) Reveal | Revealed: 41/59
# [Ep 2, Step 17] Score: 2034 | Reward: -100.00 | Loss: N/A | Epsilon: 0.9950 | Action: (5, 4) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 2 finished: LOSS | Score: 2034
# Episodes: 2 | Win Rate: 0.00% | Highest Score: 2832.00 | Time Efficiency: 10.21 steps/sec | Left Click Avg: 12.50 c/g (5.32 c/s) | Right Click Avg: 11.50 c/g (4.89 c/s) | Total Click Avg: 24.00 c/g (10.21 c/s) | Game Conclusion History: 0 Wins, 2 Losses
# ============================================================
#
# [Ep 3, Step 10] Score: 3282 | Reward: 0.90 | Loss: N/A | Epsilon: 0.9900 | Action: (7, 7) Reveal | Revealed: 56/59
# [Ep 3, Step 12] Score: 3282 | Reward: -100.00 | Loss: N/A | Epsilon: 0.9900 | Action: (3, 7) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 3 finished: LOSS | Score: 3282
# Episodes: 3 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 9.67 steps/sec | Left Click Avg: 10.33 c/g (4.99 c/s) | Right Click Avg: 9.67 c/g (4.67 c/s) | Total Click Avg: 20.00 c/g (9.67 c/s) | Game Conclusion History: 0 Wins, 3 Losses
# ============================================================
#
# [Ep 4, Step 10] Score: 2980 | Reward: 0.90 | Loss: 551.0502 | Epsilon: 0.9851 | Action: (7, 6) Reveal | Revealed: 52/59
# [Ep 4, Step 20] Score: 3055 | Reward: 0.90 | Loss: 211.7796 | Epsilon: 0.9851 | Action: (7, 3) Reveal | Revealed: 55/59
# [Ep 4, Step 29] Score: 3125 | Reward: -100.00 | Loss: 55.2830 | Epsilon: 0.9851 | Action: (7, 7) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 4 finished: LOSS | Score: 3125
# Episodes: 4 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 8.28 steps/sec | Left Click Avg: 10.50 c/g (3.91 c/s) | Right Click Avg: 11.75 c/g (4.37 c/s) | Total Click Avg: 22.25 c/g (8.28 c/s) | Game Conclusion History: 0 Wins, 4 Losses
# ============================================================
#
# [Ep 5, Step 10] Score: 170 | Reward: 8.90 | Loss: 126.9856 | Epsilon: 0.9801 | Action: (5, 0) Reveal | Revealed: 13/59
# [Ep 5, Step 20] Score: 3142 | Reward: -0.10 | Loss: 60.5386 | Epsilon: 0.9801 | Action: (4, 6) Flag | Revealed: 57/59
# [Ep 5, Step 23] Score: 3142 | Reward: -100.00 | Loss: 155.2103 | Epsilon: 0.9801 | Action: (1, 4) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 5 finished: LOSS | Score: 3142
# Episodes: 5 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 7.83 steps/sec | Left Click Avg: 11.00 c/g (3.85 c/s) | Right Click Avg: 11.40 c/g (3.99 c/s) | Total Click Avg: 22.40 c/g (7.83 c/s) | Game Conclusion History: 0 Wins, 5 Losses
# ============================================================
#
# [Ep 6, Step 10] Score: 2415 | Reward: -0.10 | Loss: 51.3393 | Epsilon: 0.9752 | Action: (6, 5) Flag | Revealed: 48/59
# [Ep 6, Step 20] Score: 2522 | Reward: -0.10 | Loss: 26.0259 | Epsilon: 0.9752 | Action: (7, 3) Flag | Revealed: 55/59
# [Ep 6, Step 21] Score: 2522 | Reward: -100.00 | Loss: 177.1613 | Epsilon: 0.9752 | Action: (7, 3) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 6 finished: LOSS | Score: 2522
# Episodes: 6 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 7.75 steps/sec | Left Click Avg: 10.67 c/g (3.73 c/s) | Right Click Avg: 11.50 c/g (4.02 c/s) | Total Click Avg: 22.17 c/g (7.75 c/s) | Game Conclusion History: 0 Wins, 6 Losses
# ============================================================
#
# [Ep 7, Step 10] Score: 257 | Reward: -0.10 | Loss: 171.4880 | Epsilon: 0.9704 | Action: (4, 3) Flag | Revealed: 16/59
# [Ep 7, Step 20] Score: 1047 | Reward: -0.10 | Loss: 108.6708 | Epsilon: 0.9704 | Action: (3, 4) Flag | Revealed: 44/59
# [Ep 7, Step 30] Score: 1123 | Reward: -0.10 | Loss: 34.1469 | Epsilon: 0.9704 | Action: (6, 7) Flag | Revealed: 51/59
# [Ep 7, Step 39] Score: 1203 | Reward: -100.00 | Loss: 1083.5551 | Epsilon: 0.9704 | Action: (6, 6) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 7 finished: LOSS | Score: 1203
# Episodes: 7 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 7.91 steps/sec | Left Click Avg: 11.86 c/g (3.82 c/s) | Right Click Avg: 12.71 c/g (4.09 c/s) | Total Click Avg: 24.57 c/g (7.91 c/s) | Game Conclusion History: 0 Wins, 7 Losses
# ============================================================
#
# [Ep 8, Step 10] Score: 2380 | Reward: -0.10 | Loss: 798.2328 | Epsilon: 0.9655 | Action: (7, 6) Flag | Revealed: 48/59
# [Ep 8, Step 20] Score: 2375 | Reward: -0.10 | Loss: 177.1869 | Epsilon: 0.9655 | Action: (6, 5) Flag | Revealed: 53/59
# [Ep 8, Step 21] Score: 2375 | Reward: -100.00 | Loss: 622.8222 | Epsilon: 0.9655 | Action: (3, 5) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 8 finished: LOSS | Score: 2375
# Episodes: 8 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 7.14 steps/sec | Left Click Avg: 11.38 c/g (3.37 c/s) | Right Click Avg: 12.75 c/g (3.77 c/s) | Total Click Avg: 24.12 c/g (7.14 c/s) | Game Conclusion History: 0 Wins, 8 Losses
# ============================================================
#
# [Ep 9, Step 10] Score: 1701 | Reward: -0.10 | Loss: 389.1861 | Epsilon: 0.9607 | Action: (6, 0) Reveal | Revealed: 40/59
# [Ep 9, Step 20] Score: 1761 | Reward: 0.90 | Loss: 101.1299 | Epsilon: 0.9607 | Action: (4, 1) Reveal | Revealed: 47/59
# [Ep 9, Step 25] Score: 1791 | Reward: -100.00 | Loss: 80.2201 | Epsilon: 0.9607 | Action: (7, 6) Reveal | Revealed: 51/59
#
# ============================================================
# Episode 9 finished: LOSS | Score: 1791
# Episodes: 9 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 6.84 steps/sec | Left Click Avg: 11.56 c/g (3.26 c/s) | Right Click Avg: 12.67 c/g (3.58 c/s) | Total Click Avg: 24.22 c/g (6.84 c/s) | Game Conclusion History: 0 Wins, 9 Losses
# ============================================================
#
# [Ep 10, Step 10] Score: 2980 | Reward: 49.90 | Loss: 144.6133 | Epsilon: 0.9559 | Action: (2, 5) Reveal | Revealed: 54/59
# [Ep 10, Step 12] Score: 2980 | Reward: -100.00 | Loss: 119.1669 | Epsilon: 0.9559 | Action: (2, 0) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 10 finished: LOSS | Score: 2980
# Episodes: 10 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 6.40 steps/sec | Left Click Avg: 11.00 c/g (3.06 c/s) | Right Click Avg: 12.00 c/g (3.34 c/s) | Total Click Avg: 23.00 c/g (6.40 c/s) | Game Conclusion History: 0 Wins, 10 Losses
# ============================================================
#
# [Ep 11, Step 10] Score: 3050 | Reward: -0.10 | Loss: 240.5344 | Epsilon: 0.9511 | Action: (7, 5) Reveal | Revealed: 56/59
# [Ep 11, Step 19] Score: 3015 | Reward: -100.00 | Loss: 371.9595 | Epsilon: 0.9511 | Action: (0, 2) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 11 finished: LOSS | Score: 3015
# Episodes: 11 | Win Rate: 0.00% | Highest Score: 3282.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 10.82 c/g (2.93 c/s) | Right Click Avg: 11.82 c/g (3.20 c/s) | Total Click Avg: 22.64 c/g (6.13 c/s) | Game Conclusion History: 0 Wins, 11 Losses
# ============================================================
#
# [Ep 12, Step 10] Score: 3475 | Reward: -0.10 | Loss: 244.4679 | Epsilon: 0.9464 | Action: (0, 1) Flag | Revealed: 60/59
# [Ep 12, Step 12] Score: 3525 | Reward: -100.00 | Loss: 533.9542 | Epsilon: 0.9464 | Action: (0, 1) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 12 finished: LOSS | Score: 3525
# Episodes: 12 | Win Rate: 0.00% | Highest Score: 3525.00 | Time Efficiency: 6.01 steps/sec | Left Click Avg: 10.33 c/g (2.86 c/s) | Right Click Avg: 11.42 c/g (3.15 c/s) | Total Click Avg: 21.75 c/g (6.01 c/s) | Game Conclusion History: 0 Wins, 12 Losses
# ============================================================
#
# [Ep 13, Step 10] Score: 2445 | Reward: -0.10 | Loss: 428.3032 | Epsilon: 0.9416 | Action: (0, 1) Flag | Revealed: 47/59
# [Ep 13, Step 18] Score: 2531 | Reward: -100.00 | Loss: 848.7119 | Epsilon: 0.9416 | Action: (0, 3) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 13 finished: LOSS | Score: 2531
# Episodes: 13 | Win Rate: 0.00% | Highest Score: 3525.00 | Time Efficiency: 5.94 steps/sec | Left Click Avg: 10.38 c/g (2.87 c/s) | Right Click Avg: 11.08 c/g (3.06 c/s) | Total Click Avg: 21.46 c/g (5.94 c/s) | Game Conclusion History: 0 Wins, 13 Losses
# ============================================================
#
# [Ep 14, Step 1] Score: 13625 | Reward: 100.00 | Loss: 248.0003 | Epsilon: 0.9369 | Action: (7, 7) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 14 finished: WIN | Score: 13625
# Episodes: 14 | Win Rate: 7.14% | Highest Score: 13625.00 | Time Efficiency: 5.82 steps/sec | Left Click Avg: 9.71 c/g (2.83 c/s) | Right Click Avg: 10.29 c/g (2.99 c/s) | Total Click Avg: 20.00 c/g (5.82 c/s) | Game Conclusion History: 1 Wins, 13 Losses
# ============================================================
#
# [Ep 15, Step 10] Score: 1957 | Reward: 0.90 | Loss: 365.3166 | Epsilon: 0.9322 | Action: (2, 6) Reveal | Revealed: 52/59
# [Ep 15, Step 20] Score: 2027 | Reward: -0.10 | Loss: 639.8282 | Epsilon: 0.9322 | Action: (0, 6) Flag | Revealed: 56/59
# [Ep 15, Step 30] Score: 2027 | Reward: -100.00 | Loss: 101.6255 | Epsilon: 0.9322 | Action: (4, 4) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 15 finished: LOSS | Score: 2027
# Episodes: 15 | Win Rate: 6.67% | Highest Score: 13625.00 | Time Efficiency: 5.87 steps/sec | Left Click Avg: 9.80 c/g (2.79 c/s) | Right Click Avg: 10.87 c/g (3.09 c/s) | Total Click Avg: 20.67 c/g (5.87 c/s) | Game Conclusion History: 1 Wins, 14 Losses
# ============================================================
#
# [Ep 16, Step 10] Score: 769 | Reward: -0.10 | Loss: 530.1489 | Epsilon: 0.9276 | Action: (2, 5) Reveal | Revealed: 32/59
# [Ep 16, Step 16] Score: 1496 | Reward: -100.00 | Loss: 391.0623 | Epsilon: 0.9276 | Action: (2, 1) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 16 finished: LOSS | Score: 1496
# Episodes: 16 | Win Rate: 6.25% | Highest Score: 13625.00 | Time Efficiency: 5.84 steps/sec | Left Click Avg: 9.81 c/g (2.81 c/s) | Right Click Avg: 10.56 c/g (3.03 c/s) | Total Click Avg: 20.38 c/g (5.84 c/s) | Game Conclusion History: 1 Wins, 15 Losses
# ============================================================
#
# [Ep 17, Step 10] Score: 1347 | Reward: -0.10 | Loss: 525.5510 | Epsilon: 0.9229 | Action: (2, 7) Flag | Revealed: 52/59
# [Ep 17, Step 20] Score: 1382 | Reward: -0.10 | Loss: 118.2262 | Epsilon: 0.9229 | Action: (0, 2) Flag | Revealed: 56/59
# [Ep 17, Step 30] Score: 1492 | Reward: -0.10 | Loss: 244.9062 | Epsilon: 0.9229 | Action: (4, 0) Flag | Revealed: 59/59
# [Ep 17, Step 35] Score: 1452 | Reward: -100.00 | Loss: 380.5804 | Epsilon: 0.9229 | Action: (6, 4) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 17 finished: LOSS | Score: 1452
# Episodes: 17 | Win Rate: 5.88% | Highest Score: 13625.00 | Time Efficiency: 5.77 steps/sec | Left Click Avg: 10.00 c/g (2.72 c/s) | Right Click Avg: 11.24 c/g (3.05 c/s) | Total Click Avg: 21.24 c/g (5.77 c/s) | Game Conclusion History: 1 Wins, 16 Losses
# ============================================================
#
# [Ep 18, Step 9] Score: 2825 | Reward: -100.00 | Loss: 1234.8743 | Epsilon: 0.9183 | Action: (6, 4) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 18 finished: LOSS | Score: 2825
# Episodes: 18 | Win Rate: 5.56% | Highest Score: 13625.00 | Time Efficiency: 5.70 steps/sec | Left Click Avg: 9.83 c/g (2.73 c/s) | Right Click Avg: 10.72 c/g (2.97 c/s) | Total Click Avg: 20.56 c/g (5.70 c/s) | Game Conclusion History: 1 Wins, 17 Losses
# ============================================================
#
# [Ep 19, Step 10] Score: 2527 | Reward: -0.10 | Loss: 333.4852 | Epsilon: 0.9137 | Action: (7, 0) Flag | Revealed: 46/59
# [Ep 19, Step 19] Score: 2612 | Reward: -100.00 | Loss: 404.8808 | Epsilon: 0.9137 | Action: (3, 4) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 19 finished: LOSS | Score: 2612
# Episodes: 19 | Win Rate: 5.26% | Highest Score: 13625.00 | Time Efficiency: 5.71 steps/sec | Left Click Avg: 9.74 c/g (2.72 c/s) | Right Click Avg: 10.74 c/g (3.00 c/s) | Total Click Avg: 20.47 c/g (5.71 c/s) | Game Conclusion History: 1 Wins, 18 Losses
# ============================================================
#
# [Ep 20, Step 10] Score: 2495 | Reward: 0.90 | Loss: 193.7749 | Epsilon: 0.9092 | Action: (0, 2) Reveal | Revealed: 51/59
# [Ep 20, Step 20] Score: 2510 | Reward: -0.10 | Loss: 725.3863 | Epsilon: 0.9092 | Action: (0, 5) Flag | Revealed: 55/59
# [Ep 20, Step 30] Score: 2520 | Reward: -0.10 | Loss: 737.4549 | Epsilon: 0.9092 | Action: (2, 0) Flag | Revealed: 57/59
# [Ep 20, Step 32] Score: 2470 | Reward: -100.00 | Loss: 107.0165 | Epsilon: 0.9092 | Action: (1, 7) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 20 finished: LOSS | Score: 2470
# Episodes: 20 | Win Rate: 5.00% | Highest Score: 13625.00 | Time Efficiency: 5.69 steps/sec | Left Click Avg: 9.95 c/g (2.69 c/s) | Right Click Avg: 11.10 c/g (3.00 c/s) | Total Click Avg: 21.05 c/g (5.69 c/s) | Game Conclusion History: 1 Wins, 19 Losses
# ============================================================
#
# [Ep 21, Step 10] Score: 2865 | Reward: -0.10 | Loss: 158.0000 | Epsilon: 0.9046 | Action: (5, 2) Flag | Revealed: 51/59
# [Ep 21, Step 20] Score: 2935 | Reward: -0.10 | Loss: 154.8109 | Epsilon: 0.9046 | Action: (1, 6) Flag | Revealed: 56/59
# [Ep 21, Step 25] Score: 2935 | Reward: -100.00 | Loss: 45.8049 | Epsilon: 0.9046 | Action: (1, 6) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 21 finished: LOSS | Score: 2935
# Episodes: 21 | Win Rate: 4.76% | Highest Score: 13625.00 | Time Efficiency: 5.72 steps/sec | Left Click Avg: 10.00 c/g (2.69 c/s) | Right Click Avg: 11.24 c/g (3.02 c/s) | Total Click Avg: 21.24 c/g (5.72 c/s) | Game Conclusion History: 1 Wins, 20 Losses
# ============================================================
#
# [Ep 22, Step 10] Score: 3137 | Reward: -0.10 | Loss: 184.0867 | Epsilon: 0.9001 | Action: (1, 5) Flag | Revealed: 52/59
# [Ep 22, Step 20] Score: 3107 | Reward: -0.10 | Loss: 3193.3701 | Epsilon: 0.9001 | Action: (6, 6) Flag | Revealed: 57/59
# [Ep 22, Step 22] Score: 3107 | Reward: -100.00 | Loss: 1275.7748 | Epsilon: 0.9001 | Action: (6, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 22 finished: LOSS | Score: 3107
# Episodes: 22 | Win Rate: 4.55% | Highest Score: 13625.00 | Time Efficiency: 5.74 steps/sec | Left Click Avg: 9.95 c/g (2.68 c/s) | Right Click Avg: 11.32 c/g (3.05 c/s) | Total Click Avg: 21.27 c/g (5.74 c/s) | Game Conclusion History: 1 Wins, 21 Losses
# ============================================================
#
# [Ep 23, Step 10] Score: 1617 | Reward: 0.90 | Loss: 573.0459 | Epsilon: 0.8956 | Action: (2, 4) Reveal | Revealed: 40/59
# [Ep 23, Step 19] Score: 1889 | Reward: -100.00 | Loss: 361.2065 | Epsilon: 0.8956 | Action: (6, 1) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 23 finished: LOSS | Score: 1889
# Episodes: 23 | Win Rate: 4.35% | Highest Score: 13625.00 | Time Efficiency: 5.75 steps/sec | Left Click Avg: 9.96 c/g (2.70 c/s) | Right Click Avg: 11.22 c/g (3.04 c/s) | Total Click Avg: 21.17 c/g (5.75 c/s) | Game Conclusion History: 1 Wins, 22 Losses
# ============================================================
#
# [Ep 24, Step 10] Score: 5043 | Reward: 100.00 | Loss: 387.8284 | Epsilon: 0.8911 | Action: (0, 0) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 24 finished: WIN | Score: 5043
# Episodes: 24 | Win Rate: 8.33% | Highest Score: 13625.00 | Time Efficiency: 5.69 steps/sec | Left Click Avg: 9.79 c/g (2.69 c/s) | Right Click Avg: 10.92 c/g (3.00 c/s) | Total Click Avg: 20.71 c/g (5.69 c/s) | Game Conclusion History: 2 Wins, 22 Losses
# ============================================================
#
# [Ep 25, Step 10] Score: 1965 | Reward: -0.10 | Loss: 243.0868 | Epsilon: 0.8867 | Action: (6, 1) Reveal | Revealed: 42/59
# [Ep 25, Step 14] Score: 1970 | Reward: -100.00 | Loss: 232.4666 | Epsilon: 0.8867 | Action: (6, 2) Reveal | Revealed: 45/59
#
# ============================================================
# Episode 25 finished: LOSS | Score: 1970
# Episodes: 25 | Win Rate: 8.00% | Highest Score: 13625.00 | Time Efficiency: 5.68 steps/sec | Left Click Avg: 9.64 c/g (2.68 c/s) | Right Click Avg: 10.80 c/g (3.00 c/s) | Total Click Avg: 20.44 c/g (5.68 c/s) | Game Conclusion History: 2 Wins, 23 Losses
# ============================================================
#
# [Ep 26, Step 6] Score: 3736 | Reward: -100.00 | Loss: 281.2738 | Epsilon: 0.8822 | Action: (0, 7) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 26 finished: LOSS | Score: 3736
# Episodes: 26 | Win Rate: 7.69% | Highest Score: 13625.00 | Time Efficiency: 5.64 steps/sec | Left Click Avg: 9.42 c/g (2.67 c/s) | Right Click Avg: 10.46 c/g (2.97 c/s) | Total Click Avg: 19.88 c/g (5.64 c/s) | Game Conclusion History: 2 Wins, 24 Losses
# ============================================================
#
# [Ep 27, Step 10] Score: 3387 | Reward: -0.10 | Loss: 1166.9302 | Epsilon: 0.8778 | Action: (3, 6) Reveal | Revealed: 54/59
# [Ep 27, Step 12] Score: 3387 | Reward: -100.00 | Loss: 248.7870 | Epsilon: 0.8778 | Action: (7, 6) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 27 finished: LOSS | Score: 3387
# Episodes: 27 | Win Rate: 7.41% | Highest Score: 13625.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 9.26 c/g (2.62 c/s) | Right Click Avg: 10.33 c/g (2.92 c/s) | Total Click Avg: 19.59 c/g (5.54 c/s) | Game Conclusion History: 2 Wins, 25 Losses
# ============================================================
#
# [Ep 28, Step 10] Score: 3642 | Reward: -0.10 | Loss: 193.3476 | Epsilon: 0.8734 | Action: (0, 4) Flag | Revealed: 59/59
# [Ep 28, Step 19] Score: 3647 | Reward: -100.00 | Loss: 324.5423 | Epsilon: 0.8734 | Action: (1, 0) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 28 finished: LOSS | Score: 3647
# Episodes: 28 | Win Rate: 7.14% | Highest Score: 13625.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 9.14 c/g (2.59 c/s) | Right Click Avg: 10.43 c/g (2.95 c/s) | Total Click Avg: 19.57 c/g (5.54 c/s) | Game Conclusion History: 2 Wins, 26 Losses
# ============================================================
#
# [Ep 29, Step 10] Score: 3352 | Reward: -0.10 | Loss: 606.1947 | Epsilon: 0.8691 | Action: (4, 2) Reveal | Revealed: 56/59
# [Ep 29, Step 12] Score: 3352 | Reward: -100.00 | Loss: 704.5897 | Epsilon: 0.8691 | Action: (7, 7) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 29 finished: LOSS | Score: 3352
# Episodes: 29 | Win Rate: 6.90% | Highest Score: 13625.00 | Time Efficiency: 5.50 steps/sec | Left Click Avg: 9.07 c/g (2.58 c/s) | Right Click Avg: 10.24 c/g (2.92 c/s) | Total Click Avg: 19.31 c/g (5.50 c/s) | Game Conclusion History: 2 Wins, 27 Losses
# ============================================================
#
# [Ep 30, Step 10] Score: 2420 | Reward: -0.10 | Loss: 1071.9861 | Epsilon: 0.8647 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 30, Step 18] Score: 2505 | Reward: -100.00 | Loss: 2708.3462 | Epsilon: 0.8647 | Action: (7, 6) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 30 finished: LOSS | Score: 2505
# Episodes: 30 | Win Rate: 6.67% | Highest Score: 13625.00 | Time Efficiency: 5.46 steps/sec | Left Click Avg: 9.10 c/g (2.58 c/s) | Right Click Avg: 10.17 c/g (2.88 c/s) | Total Click Avg: 19.27 c/g (5.46 c/s) | Game Conclusion History: 2 Wins, 28 Losses
# ============================================================
#
# [Ep 31, Step 10] Score: 3585 | Reward: -0.10 | Loss: 813.3850 | Epsilon: 0.8604 | Action: (4, 2) Reveal | Revealed: 58/59
# [Ep 31, Step 11] Score: 3585 | Reward: -100.00 | Loss: 451.3349 | Epsilon: 0.8604 | Action: (6, 5) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 31 finished: LOSS | Score: 3585
# Episodes: 31 | Win Rate: 6.45% | Highest Score: 13625.00 | Time Efficiency: 5.43 steps/sec | Left Click Avg: 9.00 c/g (2.57 c/s) | Right Click Avg: 10.00 c/g (2.86 c/s) | Total Click Avg: 19.00 c/g (5.43 c/s) | Game Conclusion History: 2 Wins, 29 Losses
# ============================================================
#
# [Ep 32, Step 10] Score: 3322 | Reward: -0.10 | Loss: 641.6535 | Epsilon: 0.8561 | Action: (3, 1) Flag | Revealed: 57/59
# [Ep 32, Step 14] Score: 3372 | Reward: -100.00 | Loss: 587.0073 | Epsilon: 0.8561 | Action: (4, 3) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 32 finished: LOSS | Score: 3372
# Episodes: 32 | Win Rate: 6.25% | Highest Score: 13625.00 | Time Efficiency: 5.42 steps/sec | Left Click Avg: 8.91 c/g (2.56 c/s) | Right Click Avg: 9.94 c/g (2.86 c/s) | Total Click Avg: 18.84 c/g (5.42 c/s) | Game Conclusion History: 2 Wins, 30 Losses
# ============================================================
#
# [Ep 33, Step 8] Score: 3856 | Reward: -100.00 | Loss: 2543.2468 | Epsilon: 0.8518 | Action: (4, 7) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 33 finished: LOSS | Score: 3856
# Episodes: 33 | Win Rate: 6.06% | Highest Score: 13625.00 | Time Efficiency: 5.39 steps/sec | Left Click Avg: 8.85 c/g (2.58 c/s) | Right Click Avg: 9.67 c/g (2.82 c/s) | Total Click Avg: 18.52 c/g (5.39 c/s) | Game Conclusion History: 2 Wins, 31 Losses
# ============================================================
#
# [Ep 34, Step 10] Score: 3287 | Reward: -0.10 | Loss: 4330.6299 | Epsilon: 0.8475 | Action: (5, 0) Flag | Revealed: 56/59
# [Ep 34, Step 13] Score: 3292 | Reward: -100.00 | Loss: 505.0433 | Epsilon: 0.8475 | Action: (4, 7) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 34 finished: LOSS | Score: 3292
# Episodes: 34 | Win Rate: 5.88% | Highest Score: 13625.00 | Time Efficiency: 5.38 steps/sec | Left Click Avg: 8.82 c/g (2.59 c/s) | Right Click Avg: 9.53 c/g (2.79 c/s) | Total Click Avg: 18.35 c/g (5.38 c/s) | Game Conclusion History: 2 Wins, 32 Losses
# ============================================================
#
# [Ep 35, Step 10] Score: 2832 | Reward: -0.10 | Loss: 398.9586 | Epsilon: 0.8433 | Action: (0, 4) Reveal | Revealed: 51/59
# [Ep 35, Step 15] Score: 2933 | Reward: -100.00 | Loss: 1269.9594 | Epsilon: 0.8433 | Action: (1, 4) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 35 finished: LOSS | Score: 2933
# Episodes: 35 | Win Rate: 5.71% | Highest Score: 13625.00 | Time Efficiency: 5.34 steps/sec | Left Click Avg: 8.77 c/g (2.57 c/s) | Right Click Avg: 9.49 c/g (2.78 c/s) | Total Click Avg: 18.26 c/g (5.34 c/s) | Game Conclusion History: 2 Wins, 33 Losses
# ============================================================
#
# [Ep 36, Step 10] Score: 2041 | Reward: 0.90 | Loss: 619.9148 | Epsilon: 0.8391 | Action: (6, 6) Reveal | Revealed: 54/59
# [Ep 36, Step 12] Score: 2041 | Reward: -100.00 | Loss: 971.8174 | Epsilon: 0.8391 | Action: (7, 5) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 36 finished: LOSS | Score: 2041
# Episodes: 36 | Win Rate: 5.56% | Highest Score: 13625.00 | Time Efficiency: 5.29 steps/sec | Left Click Avg: 8.75 c/g (2.56 c/s) | Right Click Avg: 9.33 c/g (2.73 c/s) | Total Click Avg: 18.08 c/g (5.29 c/s) | Game Conclusion History: 2 Wins, 34 Losses
# ============================================================
#
# [Ep 37, Step 10] Score: 1960 | Reward: 38.90 | Loss: 1597.4188 | Epsilon: 0.8349 | Action: (1, 2) Reveal | Revealed: 43/59
# [Ep 37, Step 12] Score: 1960 | Reward: -100.00 | Loss: 1575.7318 | Epsilon: 0.8349 | Action: (1, 4) Reveal | Revealed: 45/59
#
# ============================================================
# Episode 37 finished: LOSS | Score: 1960
# Episodes: 37 | Win Rate: 5.41% | Highest Score: 13625.00 | Time Efficiency: 5.29 steps/sec | Left Click Avg: 8.70 c/g (2.57 c/s) | Right Click Avg: 9.22 c/g (2.72 c/s) | Total Click Avg: 17.92 c/g (5.29 c/s) | Game Conclusion History: 2 Wins, 35 Losses
# ============================================================
#
# [Ep 38, Step 10] Score: 1714 | Reward: -0.10 | Loss: 6703.2100 | Epsilon: 0.8307 | Action: (0, 5) Reveal | Revealed: 53/59
# [Ep 38, Step 20] Score: 1764 | Reward: -0.10 | Loss: 1573.1531 | Epsilon: 0.8307 | Action: (3, 0) Flag | Revealed: 54/59
# [Ep 38, Step 30] Score: 1854 | Reward: -0.10 | Loss: 1174.1593 | Epsilon: 0.8307 | Action: (6, 0) Flag | Revealed: 58/59
# [Ep 38, Step 40] Score: 1864 | Reward: -100.00 | Loss: 3633.2996 | Epsilon: 0.8307 | Action: (4, 3) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 38 finished: LOSS | Score: 1864
# Episodes: 38 | Win Rate: 5.26% | Highest Score: 13625.00 | Time Efficiency: 5.37 steps/sec | Left Click Avg: 8.79 c/g (2.55 c/s) | Right Click Avg: 9.71 c/g (2.82 c/s) | Total Click Avg: 18.50 c/g (5.37 c/s) | Game Conclusion History: 2 Wins, 36 Losses
# ============================================================
#
# [Ep 39, Step 10] Score: 3427 | Reward: -0.10 | Loss: 761.6215 | Epsilon: 0.8266 | Action: (4, 2) Flag | Revealed: 55/59
# [Ep 39, Step 20] Score: 3452 | Reward: 0.90 | Loss: 446.4903 | Epsilon: 0.8266 | Action: (5, 2) Reveal | Revealed: 60/59
# [Ep 39, Step 21] Score: 4637 | Reward: 100.00 | Loss: 706.8835 | Epsilon: 0.8266 | Action: (5, 0) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 39 finished: WIN | Score: 4637
# Episodes: 39 | Win Rate: 7.69% | Highest Score: 13625.00 | Time Efficiency: 5.40 steps/sec | Left Click Avg: 8.79 c/g (2.56 c/s) | Right Click Avg: 9.77 c/g (2.84 c/s) | Total Click Avg: 18.56 c/g (5.40 c/s) | Game Conclusion History: 3 Wins, 36 Losses
# ============================================================
#
# [Ep 40, Step 7] Score: 3415 | Reward: -100.00 | Loss: 386.7061 | Epsilon: 0.8224 | Action: (7, 2) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 40 finished: LOSS | Score: 3415
# Episodes: 40 | Win Rate: 7.50% | Highest Score: 13625.00 | Time Efficiency: 5.38 steps/sec | Left Click Avg: 8.70 c/g (2.56 c/s) | Right Click Avg: 9.57 c/g (2.82 c/s) | Total Click Avg: 18.27 c/g (5.38 c/s) | Game Conclusion History: 3 Wins, 37 Losses
# ============================================================
#
# [Ep 41, Step 10] Score: 3670 | Reward: -0.10 | Loss: 1568.9949 | Epsilon: 0.8183 | Action: (0, 0) Flag | Revealed: 59/59
# [Ep 41, Step 14] Score: 3620 | Reward: -100.00 | Loss: 3941.8086 | Epsilon: 0.8183 | Action: (5, 2) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 41 finished: LOSS | Score: 3620
# Episodes: 41 | Win Rate: 7.32% | Highest Score: 13625.00 | Time Efficiency: 5.38 steps/sec | Left Click Avg: 8.66 c/g (2.57 c/s) | Right Click Avg: 9.51 c/g (2.82 c/s) | Total Click Avg: 18.17 c/g (5.38 c/s) | Game Conclusion History: 3 Wins, 38 Losses
# ============================================================
#
# [Ep 42, Step 10] Score: 2950 | Reward: -0.10 | Loss: 1572.7375 | Epsilon: 0.8142 | Action: (0, 1) Flag | Revealed: 52/59
# [Ep 42, Step 17] Score: 3065 | Reward: -100.00 | Loss: 604.9849 | Epsilon: 0.8142 | Action: (4, 0) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 42 finished: LOSS | Score: 3065
# Episodes: 42 | Win Rate: 7.14% | Highest Score: 13625.00 | Time Efficiency: 5.40 steps/sec | Left Click Avg: 8.62 c/g (2.56 c/s) | Right Click Avg: 9.52 c/g (2.83 c/s) | Total Click Avg: 18.14 c/g (5.40 c/s) | Game Conclusion History: 3 Wins, 39 Losses
# ============================================================
#
# [Ep 43, Step 10] Score: 3407 | Reward: -0.10 | Loss: 6288.5225 | Epsilon: 0.8102 | Action: (0, 6) Flag | Revealed: 55/59
# [Ep 43, Step 19] Score: 3427 | Reward: -100.00 | Loss: 4275.3262 | Epsilon: 0.8102 | Action: (1, 4) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 43 finished: LOSS | Score: 3427
# Episodes: 43 | Win Rate: 6.98% | Highest Score: 13625.00 | Time Efficiency: 5.40 steps/sec | Left Click Avg: 8.58 c/g (2.55 c/s) | Right Click Avg: 9.58 c/g (2.85 c/s) | Total Click Avg: 18.16 c/g (5.40 c/s) | Game Conclusion History: 3 Wins, 40 Losses
# ============================================================
#
# [Ep 44, Step 10] Score: 3256 | Reward: -0.10 | Loss: 3837.5027 | Epsilon: 0.8061 | Action: (7, 7) Flag | Revealed: 55/59
# [Ep 44, Step 20] Score: 3171 | Reward: -0.10 | Loss: 5140.9136 | Epsilon: 0.8061 | Action: (5, 7) Flag | Revealed: 58/59
# [Ep 44, Step 23] Score: 3171 | Reward: -100.00 | Loss: 1858.9344 | Epsilon: 0.8061 | Action: (5, 7) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 44 finished: LOSS | Score: 3171
# Episodes: 44 | Win Rate: 6.82% | Highest Score: 13625.00 | Time Efficiency: 5.42 steps/sec | Left Click Avg: 8.57 c/g (2.54 c/s) | Right Click Avg: 9.70 c/g (2.88 c/s) | Total Click Avg: 18.27 c/g (5.42 c/s) | Game Conclusion History: 3 Wins, 41 Losses
# ============================================================
#
# [Ep 45, Step 10] Score: 3580 | Reward: -0.10 | Loss: 5358.0742 | Epsilon: 0.8021 | Action: (7, 7) Flag | Revealed: 57/59
# [Ep 45, Step 20] Score: 3480 | Reward: -0.10 | Loss: 2625.3679 | Epsilon: 0.8021 | Action: (6, 0) Flag | Revealed: 58/59
# [Ep 45, Step 30] Score: 3485 | Reward: -0.10 | Loss: 1010.1119 | Epsilon: 0.8021 | Action: (7, 7) Flag | Revealed: 59/59
# [Ep 45, Step 31] Score: 3485 | Reward: -100.00 | Loss: 2845.8682 | Epsilon: 0.8021 | Action: (7, 7) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 45 finished: LOSS | Score: 3485
# Episodes: 45 | Win Rate: 6.67% | Highest Score: 13625.00 | Time Efficiency: 5.47 steps/sec | Left Click Avg: 8.53 c/g (2.51 c/s) | Right Click Avg: 10.02 c/g (2.95 c/s) | Total Click Avg: 18.56 c/g (5.47 c/s) | Game Conclusion History: 3 Wins, 42 Losses
# ============================================================
#
# [Ep 46, Step 10] Score: 1031 | Reward: 0.90 | Loss: 704.1240 | Epsilon: 0.7981 | Action: (3, 1) Reveal | Revealed: 29/59
# [Ep 46, Step 20] Score: 1988 | Reward: -0.10 | Loss: 1224.4459 | Epsilon: 0.7981 | Action: (6, 5) Flag | Revealed: 55/59
# [Ep 46, Step 30] Score: 1938 | Reward: -0.10 | Loss: 22254.1660 | Epsilon: 0.7981 | Action: (5, 5) Flag | Revealed: 55/59
# [Ep 46, Step 40] Score: 2038 | Reward: -0.10 | Loss: 9649.1934 | Epsilon: 0.7981 | Action: (3, 3) Reveal | Revealed: 56/59
# [Ep 46, Step 48] Score: 1998 | Reward: -100.00 | Loss: 4201.2539 | Epsilon: 0.7981 | Action: (1, 2) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 46 finished: LOSS | Score: 1998
# Episodes: 46 | Win Rate: 6.52% | Highest Score: 13625.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 8.57 c/g (2.47 c/s) | Right Click Avg: 10.63 c/g (3.07 c/s) | Total Click Avg: 19.20 c/g (5.54 c/s) | Game Conclusion History: 3 Wins, 43 Losses
# ============================================================
#
# [Ep 47, Step 10] Score: 2955 | Reward: -0.10 | Loss: 2514.7869 | Epsilon: 0.7941 | Action: (0, 4) Flag | Revealed: 52/59
# [Ep 47, Step 11] Score: 2955 | Reward: -100.00 | Loss: 3782.3745 | Epsilon: 0.7941 | Action: (1, 1) Reveal | Revealed: 53/59
#
# ============================================================
# Episode 47 finished: LOSS | Score: 2955
# Episodes: 47 | Win Rate: 6.38% | Highest Score: 13625.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 8.49 c/g (2.47 c/s) | Right Click Avg: 10.53 c/g (3.06 c/s) | Total Click Avg: 19.02 c/g (5.54 c/s) | Game Conclusion History: 3 Wins, 44 Losses
# ============================================================
#
# [Ep 48, Step 10] Score: 3585 | Reward: -0.10 | Loss: 2642.8999 | Epsilon: 0.7901 | Action: (0, 6) Flag | Revealed: 57/59
# [Ep 48, Step 17] Score: 3585 | Reward: -100.00 | Loss: 1995.8828 | Epsilon: 0.7901 | Action: (4, 0) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 48 finished: LOSS | Score: 3585
# Episodes: 48 | Win Rate: 6.25% | Highest Score: 13625.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 8.42 c/g (2.46 c/s) | Right Click Avg: 10.56 c/g (3.09 c/s) | Total Click Avg: 18.98 c/g (5.54 c/s) | Game Conclusion History: 3 Wins, 45 Losses
# ============================================================
#
# [Ep 49, Step 8] Score: 3622 | Reward: -100.00 | Loss: 5838.4668 | Epsilon: 0.7862 | Action: (5, 0) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 49 finished: LOSS | Score: 3622
# Episodes: 49 | Win Rate: 6.12% | Highest Score: 13625.00 | Time Efficiency: 5.53 steps/sec | Left Click Avg: 8.35 c/g (2.46 c/s) | Right Click Avg: 10.41 c/g (3.07 c/s) | Total Click Avg: 18.76 c/g (5.53 c/s) | Game Conclusion History: 3 Wins, 46 Losses
# ============================================================
#
# [Ep 50, Step 10] Score: 3382 | Reward: -0.10 | Loss: 2889.9475 | Epsilon: 0.7822 | Action: (0, 4) Flag | Revealed: 54/59
# [Ep 50, Step 18] Score: 3337 | Reward: -100.00 | Loss: 2233.9600 | Epsilon: 0.7822 | Action: (6, 7) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 50 finished: LOSS | Score: 3337
# Episodes: 50 | Win Rate: 6.00% | Highest Score: 13625.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 8.30 c/g (2.45 c/s) | Right Click Avg: 10.44 c/g (3.09 c/s) | Total Click Avg: 18.74 c/g (5.54 c/s) | Game Conclusion History: 3 Wins, 47 Losses
# ============================================================
#
# [Ep 51, Step 10] Score: 3767 | Reward: -0.10 | Loss: 4345.1855 | Epsilon: 0.7783 | Action: (3, 6) Flag | Revealed: 60/59
# [Ep 51, Step 12] Score: 3767 | Reward: -100.00 | Loss: 12044.2881 | Epsilon: 0.7783 | Action: (7, 0) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 51 finished: LOSS | Score: 3767
# Episodes: 51 | Win Rate: 5.88% | Highest Score: 13625.00 | Time Efficiency: 5.53 steps/sec | Left Click Avg: 8.25 c/g (2.45 c/s) | Right Click Avg: 10.35 c/g (3.08 c/s) | Total Click Avg: 18.61 c/g (5.53 c/s) | Game Conclusion History: 3 Wins, 48 Losses
# ============================================================
#
# [Ep 52, Step 10] Score: 3372 | Reward: 0.90 | Loss: 5596.0767 | Epsilon: 0.7744 | Action: (5, 5) Reveal | Revealed: 55/59
# [Ep 52, Step 20] Score: 3432 | Reward: -0.10 | Loss: 32599.4980 | Epsilon: 0.7744 | Action: (4, 6) Flag | Revealed: 57/59
# [Ep 52, Step 25] Score: 3442 | Reward: -100.00 | Loss: 19560.3828 | Epsilon: 0.7744 | Action: (5, 4) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 52 finished: LOSS | Score: 3442
# Episodes: 52 | Win Rate: 5.77% | Highest Score: 13625.00 | Time Efficiency: 5.53 steps/sec | Left Click Avg: 8.27 c/g (2.44 c/s) | Right Click Avg: 10.46 c/g (3.09 c/s) | Total Click Avg: 18.73 c/g (5.53 c/s) | Game Conclusion History: 3 Wins, 49 Losses
# ============================================================
#
# [Ep 53, Step 10] Score: 1470 | Reward: -0.10 | Loss: 6040.8569 | Epsilon: 0.7705 | Action: (3, 3) Flag | Revealed: 36/59
# [Ep 53, Step 20] Score: 1825 | Reward: 0.90 | Loss: 10017.0039 | Epsilon: 0.7705 | Action: (4, 0) Reveal | Revealed: 55/59
# [Ep 53, Step 22] Score: 1825 | Reward: -100.00 | Loss: 4660.2617 | Epsilon: 0.7705 | Action: (4, 1) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 53 finished: LOSS | Score: 1825
# Episodes: 53 | Win Rate: 5.66% | Highest Score: 13625.00 | Time Efficiency: 5.55 steps/sec | Left Click Avg: 8.30 c/g (2.45 c/s) | Right Click Avg: 10.49 c/g (3.10 c/s) | Total Click Avg: 18.79 c/g (5.55 c/s) | Game Conclusion History: 3 Wins, 50 Losses
# ============================================================
#
# [Ep 54, Step 10] Score: 3590 | Reward: -0.10 | Loss: 3442.7415 | Epsilon: 0.7667 | Action: (1, 6) Reveal | Revealed: 57/59
# [Ep 54, Step 18] Score: 3550 | Reward: -100.00 | Loss: 5825.0259 | Epsilon: 0.7667 | Action: (5, 1) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 54 finished: LOSS | Score: 3550
# Episodes: 54 | Win Rate: 5.56% | Highest Score: 13625.00 | Time Efficiency: 5.55 steps/sec | Left Click Avg: 8.28 c/g (2.45 c/s) | Right Click Avg: 10.50 c/g (3.10 c/s) | Total Click Avg: 18.78 c/g (5.55 c/s) | Game Conclusion History: 3 Wins, 51 Losses
# ============================================================
#
# [Ep 55, Step 10] Score: 2500 | Reward: 0.90 | Loss: 12649.2383 | Epsilon: 0.7629 | Action: (1, 6) Reveal | Revealed: 49/59
# [Ep 55, Step 20] Score: 2505 | Reward: -0.10 | Loss: 5138.2598 | Epsilon: 0.7629 | Action: (1, 7) Flag | Revealed: 52/59
# [Ep 55, Step 21] Score: 2505 | Reward: -100.00 | Loss: 7283.9434 | Epsilon: 0.7629 | Action: (2, 5) Reveal | Revealed: 53/59
#
# ============================================================
# Episode 55 finished: LOSS | Score: 2505
# Episodes: 55 | Win Rate: 5.45% | Highest Score: 13625.00 | Time Efficiency: 5.57 steps/sec | Left Click Avg: 8.29 c/g (2.45 c/s) | Right Click Avg: 10.53 c/g (3.12 c/s) | Total Click Avg: 18.82 c/g (5.57 c/s) | Game Conclusion History: 3 Wins, 52 Losses
# ============================================================
#
# [Ep 56, Step 10] Score: 2636 | Reward: -0.10 | Loss: 5922.1768 | Epsilon: 0.7590 | Action: (6, 7) Flag | Revealed: 48/59
# [Ep 56, Step 20] Score: 2766 | Reward: -0.10 | Loss: 3290.1404 | Epsilon: 0.7590 | Action: (1, 2) Flag | Revealed: 54/59
# [Ep 56, Step 23] Score: 2776 | Reward: -100.00 | Loss: 3498.0186 | Epsilon: 0.7590 | Action: (4, 3) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 56 finished: LOSS | Score: 2776
# Episodes: 56 | Win Rate: 5.36% | Highest Score: 13625.00 | Time Efficiency: 5.58 steps/sec | Left Click Avg: 8.27 c/g (2.44 c/s) | Right Click Avg: 10.62 c/g (3.14 c/s) | Total Click Avg: 18.89 c/g (5.58 c/s) | Game Conclusion History: 3 Wins, 53 Losses
# ============================================================
#
# [Ep 57, Step 10] Score: 2435 | Reward: -0.10 | Loss: 18634.3594 | Epsilon: 0.7553 | Action: (7, 0) Flag | Revealed: 49/59
# [Ep 57, Step 20] Score: 2547 | Reward: -0.10 | Loss: 16554.1367 | Epsilon: 0.7553 | Action: (4, 5) Flag | Revealed: 57/59
# [Ep 57, Step 23] Score: 2547 | Reward: -100.00 | Loss: 13299.9414 | Epsilon: 0.7553 | Action: (3, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 57 finished: LOSS | Score: 2547
# Episodes: 57 | Win Rate: 5.26% | Highest Score: 13625.00 | Time Efficiency: 5.60 steps/sec | Left Click Avg: 8.30 c/g (2.45 c/s) | Right Click Avg: 10.67 c/g (3.15 c/s) | Total Click Avg: 18.96 c/g (5.60 c/s) | Game Conclusion History: 3 Wins, 54 Losses
# ============================================================
#
# [Ep 58, Step 10] Score: 2251 | Reward: 0.90 | Loss: 14387.3750 | Epsilon: 0.7515 | Action: (0, 2) Reveal | Revealed: 53/59
# [Ep 58, Step 13] Score: 2251 | Reward: -100.00 | Loss: 7165.0127 | Epsilon: 0.7515 | Action: (4, 0) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 58 finished: LOSS | Score: 2251
# Episodes: 58 | Win Rate: 5.17% | Highest Score: 13625.00 | Time Efficiency: 5.60 steps/sec | Left Click Avg: 8.28 c/g (2.46 c/s) | Right Click Avg: 10.59 c/g (3.14 c/s) | Total Click Avg: 18.86 c/g (5.60 c/s) | Game Conclusion History: 3 Wins, 55 Losses
# ============================================================
#
# [Ep 59, Step 10] Score: 1670 | Reward: 4.90 | Loss: 11604.2695 | Epsilon: 0.7477 | Action: (0, 4) Reveal | Revealed: 51/59
# [Ep 59, Step 20] Score: 1765 | Reward: -100.00 | Loss: 9459.1191 | Epsilon: 0.7477 | Action: (2, 4) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 59 finished: LOSS | Score: 1765
# Episodes: 59 | Win Rate: 5.08% | Highest Score: 13625.00 | Time Efficiency: 5.61 steps/sec | Left Click Avg: 8.27 c/g (2.46 c/s) | Right Click Avg: 10.61 c/g (3.15 c/s) | Total Click Avg: 18.88 c/g (5.61 c/s) | Game Conclusion History: 3 Wins, 56 Losses
# ============================================================
#
# [Ep 60, Step 10] Score: 55 | Reward: -0.10 | Loss: 6764.9438 | Epsilon: 0.7440 | Action: (0, 4) Flag | Revealed: 3/59
# [Ep 60, Step 20] Score: 1221 | Reward: -0.10 | Loss: 6359.9473 | Epsilon: 0.7440 | Action: (7, 3) Flag | Revealed: 53/59
# [Ep 60, Step 21] Score: 1221 | Reward: -100.00 | Loss: 18731.2402 | Epsilon: 0.7440 | Action: (4, 3) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 60 finished: LOSS | Score: 1221
# Episodes: 60 | Win Rate: 5.00% | Highest Score: 13625.00 | Time Efficiency: 5.63 steps/sec | Left Click Avg: 8.25 c/g (2.45 c/s) | Right Click Avg: 10.67 c/g (3.17 c/s) | Total Click Avg: 18.92 c/g (5.63 c/s) | Game Conclusion History: 3 Wins, 57 Losses
# ============================================================
#
# [Ep 61, Step 10] Score: 2517 | Reward: -0.10 | Loss: 5879.3003 | Epsilon: 0.7403 | Action: (1, 0) Flag | Revealed: 46/59
# [Ep 61, Step 20] Score: 2592 | Reward: 0.90 | Loss: 5928.4194 | Epsilon: 0.7403 | Action: (0, 5) Reveal | Revealed: 51/59
# [Ep 61, Step 30] Score: 2652 | Reward: -0.10 | Loss: 60807.2891 | Epsilon: 0.7403 | Action: (4, 1) Flag | Revealed: 53/59
# [Ep 61, Step 37] Score: 2682 | Reward: -100.00 | Loss: 25961.9941 | Epsilon: 0.7403 | Action: (1, 6) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 61 finished: LOSS | Score: 2682
# Episodes: 61 | Win Rate: 4.92% | Highest Score: 13625.00 | Time Efficiency: 5.67 steps/sec | Left Click Avg: 8.36 c/g (2.47 c/s) | Right Click Avg: 10.85 c/g (3.20 c/s) | Total Click Avg: 19.21 c/g (5.67 c/s) | Game Conclusion History: 3 Wins, 58 Losses
# ============================================================
#
# [Ep 62, Step 10] Score: 1794 | Reward: -0.10 | Loss: 13367.3848 | Epsilon: 0.7366 | Action: (7, 6) Flag | Revealed: 55/59
# [Ep 62, Step 15] Score: 1794 | Reward: -100.00 | Loss: 11995.1914 | Epsilon: 0.7366 | Action: (4, 3) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 62 finished: LOSS | Score: 1794
# Episodes: 62 | Win Rate: 4.84% | Highest Score: 13625.00 | Time Efficiency: 5.67 steps/sec | Left Click Avg: 8.34 c/g (2.47 c/s) | Right Click Avg: 10.81 c/g (3.20 c/s) | Total Click Avg: 19.15 c/g (5.67 c/s) | Game Conclusion History: 3 Wins, 59 Losses
# ============================================================
#
# [Ep 63, Step 10] Score: 3630 | Reward: -0.10 | Loss: 12276.5400 | Epsilon: 0.7329 | Action: (0, 7) Flag | Revealed: 58/59
# [Ep 63, Step 11] Score: 3630 | Reward: -100.00 | Loss: 16756.4258 | Epsilon: 0.7329 | Action: (0, 6) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 63 finished: LOSS | Score: 3630
# Episodes: 63 | Win Rate: 4.76% | Highest Score: 13625.00 | Time Efficiency: 5.66 steps/sec | Left Click Avg: 8.29 c/g (2.47 c/s) | Right Click Avg: 10.73 c/g (3.19 c/s) | Total Click Avg: 19.02 c/g (5.66 c/s) | Game Conclusion History: 3 Wins, 60 Losses
# ============================================================
#
# [Ep 64, Step 10] Score: 1940 | Reward: -0.10 | Loss: 10446.2910 | Epsilon: 0.7292 | Action: (3, 1) Flag | Revealed: 42/59
# [Ep 64, Step 15] Score: 1950 | Reward: -100.00 | Loss: 24806.6035 | Epsilon: 0.7292 | Action: (3, 6) Reveal | Revealed: 45/59
#
# ============================================================
# Episode 64 finished: LOSS | Score: 1950
# Episodes: 64 | Win Rate: 4.69% | Highest Score: 13625.00 | Time Efficiency: 5.66 steps/sec | Left Click Avg: 8.27 c/g (2.47 c/s) | Right Click Avg: 10.69 c/g (3.19 c/s) | Total Click Avg: 18.95 c/g (5.66 c/s) | Game Conclusion History: 3 Wins, 61 Losses
# ============================================================
#
# [Ep 65, Step 10] Score: 2432 | Reward: -0.10 | Loss: 25843.0273 | Epsilon: 0.7256 | Action: (1, 5) Reveal | Revealed: 56/59
# [Ep 65, Step 13] Score: 2442 | Reward: -100.00 | Loss: 7228.2192 | Epsilon: 0.7256 | Action: (4, 3) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 65 finished: LOSS | Score: 2442
# Episodes: 65 | Win Rate: 4.62% | Highest Score: 13625.00 | Time Efficiency: 5.66 steps/sec | Left Click Avg: 8.26 c/g (2.48 c/s) | Right Click Avg: 10.60 c/g (3.18 c/s) | Total Click Avg: 18.86 c/g (5.66 c/s) | Game Conclusion History: 3 Wins, 62 Losses
# ============================================================
#
# [Ep 66, Step 10] Score: 3575 | Reward: -0.10 | Loss: 12080.8457 | Epsilon: 0.7219 | Action: (3, 2) Flag | Revealed: 55/59
# [Ep 66, Step 19] Score: 3530 | Reward: -100.00 | Loss: 20372.3574 | Epsilon: 0.7219 | Action: (1, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 66 finished: LOSS | Score: 3530
# Episodes: 66 | Win Rate: 4.55% | Highest Score: 13625.00 | Time Efficiency: 5.67 steps/sec | Left Click Avg: 8.23 c/g (2.47 c/s) | Right Click Avg: 10.64 c/g (3.20 c/s) | Total Click Avg: 18.86 c/g (5.67 c/s) | Game Conclusion History: 3 Wins, 63 Losses
# ============================================================
#
# [Ep 67, Step 10] Score: 867 | Reward: -0.10 | Loss: 12681.5166 | Epsilon: 0.7183 | Action: (3, 3) Flag | Revealed: 32/59
# [Ep 67, Step 20] Score: 1387 | Reward: -0.10 | Loss: 99872.6797 | Epsilon: 0.7183 | Action: (7, 6) Flag | Revealed: 54/59
# [Ep 67, Step 25] Score: 1397 | Reward: -100.00 | Loss: 25188.1250 | Epsilon: 0.7183 | Action: (6, 5) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 67 finished: LOSS | Score: 1397
# Episodes: 67 | Win Rate: 4.48% | Highest Score: 13625.00 | Time Efficiency: 5.69 steps/sec | Left Click Avg: 8.27 c/g (2.48 c/s) | Right Click Avg: 10.69 c/g (3.21 c/s) | Total Click Avg: 18.96 c/g (5.69 c/s) | Game Conclusion History: 3 Wins, 64 Losses
# ============================================================
#
# [Ep 68, Step 10] Score: 2704 | Reward: -0.10 | Loss: 33946.8047 | Epsilon: 0.7147 | Action: (5, 2) Reveal | Revealed: 57/59
# [Ep 68, Step 11] Score: 2704 | Reward: -100.00 | Loss: 32214.4395 | Epsilon: 0.7147 | Action: (3, 3) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 68 finished: LOSS | Score: 2704
# ...
# ============================================================
#
# [Ep 286, Step 10] Score: 3615 | Reward: -0.10 | Loss: 3540208128.0000 | Epsilon: 0.2397 | Action: (4, 2) Flag | Revealed: 58/59
# [Ep 286, Step 13] Score: 3565 | Reward: -100.00 | Loss: 6229597696.0000 | Epsilon: 0.2397 | Action: (7, 1) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 286 finished: LOSS | Score: 3565
# Episodes: 286 | Win Rate: 7.34% | Highest Score: 13625.00 | Time Efficiency: 6.29 steps/sec | Left Click Avg: 8.27 c/g (2.15 c/s) | Right Click Avg: 15.95 c/g (4.14 c/s) | Total Click Avg: 24.23 c/g (6.29 c/s) | Game Conclusion History: 21 Wins, 265 Losses
# ============================================================
#
# [Ep 287, Step 10] Score: 2925 | Reward: -0.10 | Loss: 3147588608.0000 | Epsilon: 0.2385 | Action: (7, 4) Flag | Revealed: 52/59
# [Ep 287, Step 20] Score: 2935 | Reward: -0.10 | Loss: 3805199360.0000 | Epsilon: 0.2385 | Action: (6, 0) Flag | Revealed: 55/59
# [Ep 287, Step 30] Score: 3010 | Reward: -0.10 | Loss: 5918337024.0000 | Epsilon: 0.2385 | Action: (6, 0) Flag | Revealed: 58/59
# [Ep 287, Step 40] Score: 3065 | Reward: -0.10 | Loss: 5957571584.0000 | Epsilon: 0.2385 | Action: (0, 0) Flag | Revealed: 59/59
# [Ep 287, Step 50] Score: 3015 | Reward: -0.10 | Loss: 3354409728.0000 | Epsilon: 0.2385 | Action: (7, 3) Flag | Revealed: 59/59
# [Ep 287, Step 60] Score: 2970 | Reward: -0.10 | Loss: 11444497408.0000 | Epsilon: 0.2385 | Action: (7, 3) Flag | Revealed: 60/59
# [Ep 287, Step 62] Score: 2970 | Reward: -100.00 | Loss: 4954849792.0000 | Epsilon: 0.2385 | Action: (1, 1) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 287 finished: LOSS | Score: 2970
# Episodes: 287 | Win Rate: 7.32% | Highest Score: 13625.00 | Time Efficiency: 6.30 steps/sec | Left Click Avg: 8.29 c/g (2.14 c/s) | Right Click Avg: 16.07 c/g (4.16 c/s) | Total Click Avg: 24.36 c/g (6.30 c/s) | Game Conclusion History: 21 Wins, 266 Losses
# ============================================================
#
# [Ep 288, Step 10] Score: 0 | Reward: -0.10 | Loss: 4788392960.0000 | Epsilon: 0.2373 | Action: (5, 3) Flag | Revealed: 0/59
# [Ep 288, Step 20] Score: 5 | Reward: -0.10 | Loss: 3568990720.0000 | Epsilon: 0.2373 | Action: (4, 0) Flag | Revealed: 1/59
# [Ep 288, Step 30] Score: 2777 | Reward: -0.10 | Loss: 2763719936.0000 | Epsilon: 0.2373 | Action: (2, 3) Flag | Revealed: 51/59
# [Ep 288, Step 40] Score: 2807 | Reward: -0.10 | Loss: 10038762496.0000 | Epsilon: 0.2373 | Action: (2, 4) Flag | Revealed: 54/59
# [Ep 288, Step 47] Score: 2807 | Reward: -100.00 | Loss: 11712894976.0000 | Epsilon: 0.2373 | Action: (2, 4) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 288 finished: LOSS | Score: 2807
# Episodes: 288 | Win Rate: 7.29% | Highest Score: 13625.00 | Time Efficiency: 6.30 steps/sec | Left Click Avg: 8.31 c/g (2.14 c/s) | Right Click Avg: 16.13 c/g (4.16 c/s) | Total Click Avg: 24.44 c/g (6.30 c/s) | Game Conclusion History: 21 Wins, 267 Losses
# ============================================================
#
# [Ep 289, Step 10] Score: 2161 | Reward: -0.10 | Loss: 8360092672.0000 | Epsilon: 0.2361 | Action: (6, 3) Reveal | Revealed: 46/59
# [Ep 289, Step 20] Score: 2242 | Reward: -0.10 | Loss: 2685877248.0000 | Epsilon: 0.2361 | Action: (0, 2) Flag | Revealed: 54/59
# [Ep 289, Step 30] Score: 2247 | Reward: -0.10 | Loss: 4159547648.0000 | Epsilon: 0.2361 | Action: (0, 2) Flag | Revealed: 56/59
# [Ep 289, Step 40] Score: 2252 | Reward: 0.90 | Loss: 3582154240.0000 | Epsilon: 0.2361 | Action: (7, 0) Reveal | Revealed: 57/59
# [Ep 289, Step 50] Score: 2252 | Reward: -0.10 | Loss: 4349873152.0000 | Epsilon: 0.2361 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 289, Step 60] Score: 2252 | Reward: -0.10 | Loss: 4469193728.0000 | Epsilon: 0.2361 | Action: (1, 6) Flag | Revealed: 57/59
# [Ep 289, Step 62] Score: 2252 | Reward: -100.00 | Loss: 3961540608.0000 | Epsilon: 0.2361 | Action: (1, 2) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 289 finished: LOSS | Score: 2252
# Episodes: 289 | Win Rate: 7.27% | Highest Score: 13625.00 | Time Efficiency: 6.31 steps/sec | Left Click Avg: 8.32 c/g (2.14 c/s) | Right Click Avg: 16.25 c/g (4.17 c/s) | Total Click Avg: 24.57 c/g (6.31 c/s) | Game Conclusion History: 21 Wins, 268 Losses
# ============================================================
#
# [Ep 290, Step 10] Score: 941 | Reward: -0.10 | Loss: 7611034624.0000 | Epsilon: 0.2349 | Action: (3, 2) Flag | Revealed: 28/59
# [Ep 290, Step 20] Score: 1313 | Reward: 0.90 | Loss: 4483643904.0000 | Epsilon: 0.2349 | Action: (0, 0) Reveal | Revealed: 44/59
# [Ep 290, Step 30] Score: 1504 | Reward: -0.10 | Loss: 1396655872.0000 | Epsilon: 0.2349 | Action: (6, 5) Flag | Revealed: 54/59
# [Ep 290, Step 40] Score: 1504 | Reward: -0.10 | Loss: 9308145664.0000 | Epsilon: 0.2349 | Action: (3, 4) Flag | Revealed: 54/59
# [Ep 290, Step 50] Score: 1454 | Reward: -0.10 | Loss: 4162508288.0000 | Epsilon: 0.2349 | Action: (4, 5) Flag | Revealed: 54/59
# [Ep 290, Step 60] Score: 1459 | Reward: 0.90 | Loss: 14075049984.0000 | Epsilon: 0.2349 | Action: (4, 5) Reveal | Revealed: 55/59
# [Ep 290, Step 70] Score: 1509 | Reward: -0.10 | Loss: 9110073344.0000 | Epsilon: 0.2349 | Action: (6, 5) Flag | Revealed: 55/59
# [Ep 290, Step 80] Score: 1569 | Reward: 0.90 | Loss: 5491360256.0000 | Epsilon: 0.2349 | Action: (5, 3) Reveal | Revealed: 57/59
# [Ep 290, Step 86] Score: 1519 | Reward: -100.00 | Loss: 4560946688.0000 | Epsilon: 0.2349 | Action: (1, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 290 finished: LOSS | Score: 1519
# Episodes: 290 | Win Rate: 7.24% | Highest Score: 13625.00 | Time Efficiency: 6.32 steps/sec | Left Click Avg: 8.34 c/g (2.13 c/s) | Right Click Avg: 16.44 c/g (4.19 c/s) | Total Click Avg: 24.78 c/g (6.32 c/s) | Game Conclusion History: 21 Wins, 269 Losses
# ============================================================
#
# [Ep 291, Step 10] Score: 3841 | Reward: -0.10 | Loss: 4116428288.0000 | Epsilon: 0.2337 | Action: (0, 2) Flag | Revealed: 58/59
# [Ep 291, Step 20] Score: 3851 | Reward: -0.10 | Loss: 3900865536.0000 | Epsilon: 0.2337 | Action: (4, 6) Reveal | Revealed: 60/59
# [Ep 291, Step 30] Score: 3801 | Reward: -100.00 | Loss: 7703955456.0000 | Epsilon: 0.2337 | Action: (0, 2) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 291 finished: LOSS | Score: 3801
# Episodes: 291 | Win Rate: 7.22% | Highest Score: 13625.00 | Time Efficiency: 6.32 steps/sec | Left Click Avg: 8.33 c/g (2.12 c/s) | Right Click Avg: 16.47 c/g (4.20 c/s) | Total Click Avg: 24.80 c/g (6.32 c/s) | Game Conclusion History: 21 Wins, 270 Losses
# ============================================================
#
# [Ep 292, Step 10] Score: 3902 | Reward: -0.10 | Loss: 3105607680.0000 | Epsilon: 0.2326 | Action: (2, 3) Flag | Revealed: 60/59
# [Ep 292, Step 20] Score: 3952 | Reward: -0.10 | Loss: 5338293760.0000 | Epsilon: 0.2326 | Action: (7, 3) Flag | Revealed: 60/59
# [Ep 292, Step 21] Score: 3952 | Reward: -100.00 | Loss: 2921356288.0000 | Epsilon: 0.2326 | Action: (3, 1) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 292 finished: LOSS | Score: 3952
# Episodes: 292 | Win Rate: 7.19% | Highest Score: 13625.00 | Time Efficiency: 6.32 steps/sec | Left Click Avg: 8.31 c/g (2.12 c/s) | Right Click Avg: 16.47 c/g (4.20 c/s) | Total Click Avg: 24.78 c/g (6.32 c/s) | Game Conclusion History: 21 Wins, 271 Losses
# ============================================================
#
# [Ep 293, Step 10] Score: 2677 | Reward: 8.90 | Loss: 10983075840.0000 | Epsilon: 0.2314 | Action: (4, 1) Reveal | Revealed: 55/59
# [Ep 293, Step 20] Score: 2757 | Reward: -0.10 | Loss: 8900559872.0000 | Epsilon: 0.2314 | Action: (3, 1) Flag | Revealed: 57/59
# [Ep 293, Step 30] Score: 2762 | Reward: -0.10 | Loss: 5206124032.0000 | Epsilon: 0.2314 | Action: (2, 0) Flag | Revealed: 58/59
# [Ep 293, Step 40] Score: 2812 | Reward: -0.10 | Loss: 22689478656.0000 | Epsilon: 0.2314 | Action: (4, 5) Reveal | Revealed: 59/59
# [Ep 293, Step 48] Score: 2762 | Reward: -100.00 | Loss: 3130093056.0000 | Epsilon: 0.2314 | Action: (2, 0) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 293 finished: LOSS | Score: 2762
# Episodes: 293 | Win Rate: 7.17% | Highest Score: 13625.00 | Time Efficiency: 6.33 steps/sec | Left Click Avg: 8.32 c/g (2.12 c/s) | Right Click Avg: 16.54 c/g (4.21 c/s) | Total Click Avg: 24.86 c/g (6.33 c/s) | Game Conclusion History: 21 Wins, 272 Losses
# ============================================================
#
# [Ep 294, Step 10] Score: 3256 | Reward: -0.10 | Loss: 6045548544.0000 | Epsilon: 0.2302 | Action: (6, 4) Flag | Revealed: 56/59
# [Ep 294, Step 20] Score: 3256 | Reward: -0.10 | Loss: 4211084032.0000 | Epsilon: 0.2302 | Action: (6, 4) Flag | Revealed: 56/59
# [Ep 294, Step 30] Score: 3256 | Reward: -0.10 | Loss: 12271497216.0000 | Epsilon: 0.2302 | Action: (6, 4) Flag | Revealed: 56/59
# [Ep 294, Step 40] Score: 3366 | Reward: -0.10 | Loss: 10969321472.0000 | Epsilon: 0.2302 | Action: (7, 4) Flag | Revealed: 57/59
# [Ep 294, Step 50] Score: 3276 | Reward: -0.10 | Loss: 5954971648.0000 | Epsilon: 0.2302 | Action: (6, 1) Flag | Revealed: 58/59
# [Ep 294, Step 51] Score: 3276 | Reward: -100.00 | Loss: 4762969088.0000 | Epsilon: 0.2302 | Action: (6, 4) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 294 finished: LOSS | Score: 3276
# Episodes: 294 | Win Rate: 7.14% | Highest Score: 13625.00 | Time Efficiency: 6.35 steps/sec | Left Click Avg: 8.32 c/g (2.12 c/s) | Right Click Avg: 16.63 c/g (4.23 c/s) | Total Click Avg: 24.95 c/g (6.35 c/s) | Game Conclusion History: 21 Wins, 273 Losses
# ============================================================
#
# [Ep 295, Step 10] Score: 3317 | Reward: -0.10 | Loss: 8075271168.0000 | Epsilon: 0.2291 | Action: (6, 6) Flag | Revealed: 55/59
# [Ep 295, Step 20] Score: 3267 | Reward: -0.10 | Loss: 5197825024.0000 | Epsilon: 0.2291 | Action: (7, 7) Flag | Revealed: 55/59
# [Ep 295, Step 30] Score: 3267 | Reward: -0.10 | Loss: 13250275328.0000 | Epsilon: 0.2291 | Action: (6, 6) Flag | Revealed: 55/59
# [Ep 295, Step 40] Score: 3277 | Reward: 0.90 | Loss: 36240838656.0000 | Epsilon: 0.2291 | Action: (0, 4) Reveal | Revealed: 57/59
# [Ep 295, Step 50] Score: 3327 | Reward: -100.00 | Loss: 10664317952.0000 | Epsilon: 0.2291 | Action: (5, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 295 finished: LOSS | Score: 3327
# Episodes: 295 | Win Rate: 7.12% | Highest Score: 13625.00 | Time Efficiency: 6.36 steps/sec | Left Click Avg: 8.32 c/g (2.11 c/s) | Right Click Avg: 16.72 c/g (4.25 c/s) | Total Click Avg: 25.04 c/g (6.36 c/s) | Game Conclusion History: 21 Wins, 274 Losses
# ============================================================
#
# [Ep 296, Step 10] Score: 3211 | Reward: -0.10 | Loss: 7386386432.0000 | Epsilon: 0.2279 | Action: (0, 7) Flag | Revealed: 55/59
# [Ep 296, Step 18] Score: 3161 | Reward: -100.00 | Loss: 9739978752.0000 | Epsilon: 0.2279 | Action: (6, 4) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 296 finished: LOSS | Score: 3161
# Episodes: 296 | Win Rate: 7.09% | Highest Score: 13625.00 | Time Efficiency: 6.36 steps/sec | Left Click Avg: 8.30 c/g (2.11 c/s) | Right Click Avg: 16.71 c/g (4.25 c/s) | Total Click Avg: 25.01 c/g (6.36 c/s) | Game Conclusion History: 21 Wins, 275 Losses
# ============================================================
#
# [Ep 297, Step 10] Score: 3332 | Reward: -0.10 | Loss: 13421450240.0000 | Epsilon: 0.2268 | Action: (2, 3) Flag | Revealed: 56/59
# [Ep 297, Step 20] Score: 3342 | Reward: -0.10 | Loss: 5842232832.0000 | Epsilon: 0.2268 | Action: (2, 3) Flag | Revealed: 57/59
# [Ep 297, Step 29] Score: 3362 | Reward: -100.00 | Loss: 6845586944.0000 | Epsilon: 0.2268 | Action: (2, 3) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 297 finished: LOSS | Score: 3362
# Episodes: 297 | Win Rate: 7.07% | Highest Score: 13625.00 | Time Efficiency: 6.36 steps/sec | Left Click Avg: 8.31 c/g (2.11 c/s) | Right Click Avg: 16.72 c/g (4.25 c/s) | Total Click Avg: 25.03 c/g (6.36 c/s) | Game Conclusion History: 21 Wins, 276 Losses
# ============================================================
#
# [Ep 298, Step 10] Score: 3005 | Reward: 0.90 | Loss: 22312112128.0000 | Epsilon: 0.2257 | Action: (2, 4) Reveal | Revealed: 55/59
# [Ep 298, Step 20] Score: 2970 | Reward: -0.10 | Loss: 9010149376.0000 | Epsilon: 0.2257 | Action: (7, 1) Flag | Revealed: 59/59
# [Ep 298, Step 30] Score: 3070 | Reward: -0.10 | Loss: 18860693504.0000 | Epsilon: 0.2257 | Action: (7, 0) Flag | Revealed: 59/59
# [Ep 298, Step 39] Score: 3020 | Reward: -100.00 | Loss: 23418040320.0000 | Epsilon: 0.2257 | Action: (1, 4) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 298 finished: LOSS | Score: 3020
# Episodes: 298 | Win Rate: 7.05% | Highest Score: 13625.00 | Time Efficiency: 6.37 steps/sec | Left Click Avg: 8.33 c/g (2.11 c/s) | Right Click Avg: 16.75 c/g (4.25 c/s) | Total Click Avg: 25.07 c/g (6.37 c/s) | Game Conclusion History: 21 Wins, 277 Losses
# ============================================================
#
# [Ep 299, Step 10] Score: 3525 | Reward: -0.10 | Loss: 14294355968.0000 | Epsilon: 0.2245 | Action: (6, 6) Flag | Revealed: 59/59
# [Ep 299, Step 14] Score: 3575 | Reward: -100.00 | Loss: 8993332224.0000 | Epsilon: 0.2245 | Action: (0, 4) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 299 finished: LOSS | Score: 3575
# Episodes: 299 | Win Rate: 7.02% | Highest Score: 13625.00 | Time Efficiency: 6.37 steps/sec | Left Click Avg: 8.32 c/g (2.12 c/s) | Right Click Avg: 16.72 c/g (4.25 c/s) | Total Click Avg: 25.04 c/g (6.37 c/s) | Game Conclusion History: 21 Wins, 278 Losses
# ============================================================
#
# [Ep 300, Step 10] Score: 3550 | Reward: -0.10 | Loss: 18134294528.0000 | Epsilon: 0.2234 | Action: (3, 1) Flag | Revealed: 55/59
# [Ep 300, Step 20] Score: 3565 | Reward: -0.10 | Loss: 50346278912.0000 | Epsilon: 0.2234 | Action: (6, 6) Flag | Revealed: 57/59
# [Ep 300, Step 30] Score: 3615 | Reward: -0.10 | Loss: 7525671424.0000 | Epsilon: 0.2234 | Action: (6, 6) Flag | Revealed: 59/59
# [Ep 300, Step 40] Score: 3665 | Reward: -0.10 | Loss: 7216942592.0000 | Epsilon: 0.2234 | Action: (4, 0) Flag | Revealed: 59/59
# [Ep 300, Step 50] Score: 3665 | Reward: -0.10 | Loss: 5779951616.0000 | Epsilon: 0.2234 | Action: (6, 6) Flag | Revealed: 59/59
# [Ep 300, Step 60] Score: 3625 | Reward: -0.10 | Loss: 6802570240.0000 | Epsilon: 0.2234 | Action: (7, 7) Flag | Revealed: 60/59
# [Ep 300, Step 70] Score: 3625 | Reward: -0.10 | Loss: 11536695296.0000 | Epsilon: 0.2234 | Action: (7, 7) Flag | Revealed: 60/59
# [Ep 300, Step 73] Score: 3575 | Reward: -100.00 | Loss: 10252744704.0000 | Epsilon: 0.2234 | Action: (4, 0) Reveal | Revealed: 61/59
#
# Saving progress to ./models\dqn_model_20251011_173428_checkpoint_ep300...
# Progress saved successfully.
#
# ============================================================
# Episode 300 finished: LOSS | Score: 3575
# Episodes: 300 | Win Rate: 7.00% | Highest Score: 13625.00 | Time Efficiency: 6.38 steps/sec | Left Click Avg: 8.32 c/g (2.11 c/s) | Right Click Avg: 16.88 c/g (4.28 c/s) | Total Click Avg: 25.20 c/g (6.38 c/s) | Game Conclusion History: 21 Wins, 279 Losses
# ============================================================
#
#
# Saving progress to ./models\dqn_model_20251011_173428...
# Progress saved successfully.

# %%
# pygame.quit()

# %%
# saveModel(MODEL_NAME, agent)
