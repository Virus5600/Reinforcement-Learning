# %%
# %pip install pygame
# %pip install numpy
# %pip install tensorflow

# %%
import random
import numpy as np
import tensorflow as tf

# Set a specific integer for reproducibility
SEED_VALUE = 20250506

# 1. Set seed for Python's built-in random module
random.seed(SEED_VALUE)

# 2. Set seed for NumPy operations
np.random.seed(SEED_VALUE)

# 3. Set seed for TensorFlow (affects weight initialization and some GPU operations)
tf.random.set_seed(SEED_VALUE)
# Note: You might also need to set some environment variables for complete determinism

# %%
import pygame
from datetime import datetime

pygame.init()

# ----------------
# Constants
# ----------------
DISPLAY_INFO = pygame.display.Info()
MONITOR_WIDTH = DISPLAY_INFO.current_w
MONITOR_HEIGHT = DISPLAY_INFO.current_h

SCREEN_WIDTH = int(MONITOR_WIDTH * 0.6)
SCREEN_HEIGHT = int(MONITOR_HEIGHT * 0.8)

GRID_SIZE = 8
AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
AVAILABLE_WIDTH = SCREEN_WIDTH - 40

TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
MARGIN = 150

MINE_COUNT = 5
FLAG_LIMIT = 5
MAX_LIVES = 3

FILE_NAME = f"{datetime.now().strftime('%Y%m%d_%H%M%S')}"
LOG_NAME = f"a2c_logs_{FILE_NAME}.txt"
MODEL_NAME = f"a2c_model_{FILE_NAME}"

AUTO_QUIT = False
# Out:
# e:\Files\School Files\Reinforcement Learning\Project\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import os
import json
from datetime import datetime
from A2C import A2C

def saveModel(modelName: str, agent: A2C):
    """
    Saves the agent's model weights and training metrics to the './models' directory.

    :param modelName: The name for the save file (e.g., "run1").
    :type modelName: str
    
    :param agent: The A2C agent instance to save.
    :type agent: A2C
    """
    # Ensure the save directory exists
    modelsDir = "./models"
    if not os.path.exists(modelsDir):
        os.makedirs(modelsDir)
    
    # Define file paths
    filePath = os.path.join(modelsDir, modelName)
    weightsPath = f'{filePath}_model.weights.h5'
    metricsPath = f'{filePath}_metrics.json'
    
    print(f"\nSaving progress to {filePath}...")
    
    # Save the model's weights
    agent.model.save_weights(weightsPath)
    
    # Prepare metrics data for saving
    metricsData = {
        "EPISODES": agent.EPISODES,
        "ELAPSED_TIME": agent.ELAPSED_TIME,
        "GAME_CONCLUSIONS": agent.GAME_CONCLUSIONS,
        "WIN_RATE": agent.WIN_RATE,
        "HIGHEST_SCORE": agent.HIGHEST_SCORE,
        "SCORES": agent.SCORES,
        "TIME_EFFICIENCY": agent.TIME_EFFICIENCY,
        "CLICKS": agent.CLICKS,
    }
    
    # Save metrics to a JSON file
    with open(metricsPath, 'w') as f:
        json.dump(metricsData, f, indent = 4)
        
    print("Progress saved successfully.")

def loadModel(modelName: str, agent: A2C) -> A2C:
    """
    Loads the agent's model weights and training metrics from the './models' directory.

    :param modelName: The name of the save file to load (e.g., "run1").
    :type modelName: str
    
    :param agent: The A2C agent instance to load progress into.
    :type agent: A2C
    
    :returns: The agent instance with loaded progress.
    :rtype: A2C
    """
    # Define file paths
    filePath = os.path.join("./models", modelName)
    weightsPath = f'{filePath}_model.weights.h5'
    metricsPath = f'{filePath}_metrics.json'
    
    # Check if both weights and metrics files exist
    if os.path.exists(weightsPath) and os.path.exists(metricsPath):
        print(f"\nLoading progress from {filePath}...")
        
        # Load the model's weights
        agent.model.load_weights(weightsPath)
        
        # Load metrics from the JSON file
        with open(metricsPath, 'r') as f:
            metricsData = json.load(f)
        
        # Populate the agent's attributes with the loaded data
        agent.EPISODES = metricsData.get("EPISODES", 1)
        agent.ELAPSED_TIME = metricsData.get("ELAPSED_TIME", [])
        agent.GAME_CONCLUSIONS = metricsData.get("GAME_CONCLUSIONS", [])
        agent.WIN_RATE = metricsData.get("WIN_RATE", 0.0)
        agent.HIGHEST_SCORE = metricsData.get("HIGHEST_SCORE", 0)
        agent.SCORES = metricsData.get("SCORES", [])
        agent.TIME_EFFICIENCY = metricsData.get("TIME_EFFICIENCY", 0.0)
        agent.CLICKS = metricsData.get("CLICKS", {"left": [], "right": [], "total": []})
        
        # Ensure the learning rate is correct for the loaded episode
        if isinstance(agent.LR, dict):
            currentLR = agent.optimizer.learning_rate.numpy()
            newLR = currentLR
            
            # Find the latest episode milestone that has been passed
            for milestone in sorted(agent.LR.keys()):
                if agent.EPISODES >= milestone:
                    newLR = agent.LR[milestone]
            
            # If the learning rate needs to be changed, update the optimizer
            if newLR != currentLR:
                print(f"[LR Scheduler] Loaded at Episode {agent.EPISODES}: Setting learning rate to {newLR:.6f}")
                agent.optimizer.learning_rate.assign(newLR)
        
        print("Progress loaded successfully.")
    else:
        print("\nNo saved progress found. Starting a new training run.")
        
    return agent

def log(string: str) -> str:
    if not os.path.exists("logs"):
        os.makedirs("logs")

    logName = os.path.join("logs", LOG_NAME)

    if not os.path.exists(logName):
        with open(logName, "w") as f:
            f.write(f"Log created on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write("="*50 + "\n")

    with open(logName, "a") as f:
        f.write(string + "\n")

    return string

# %%
import pygame
import random

# Initialize Pygame
pygame.init()

# Get display info and set screen size based on monitor
display_info = pygame.display.Info()
MONITOR_WIDTH = display_info.current_w
MONITOR_HEIGHT = display_info.current_h

# Set screen size to a percentage of monitor size
SCREEN_WIDTH = int(MONITOR_WIDTH * 0.6)  # 60% of monitor width
SCREEN_HEIGHT = int(MONITOR_HEIGHT * 0.8)  # 80% of monitor height

# Adjust tile size based on screen size
GRID_SIZE = 8
AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230  # Subtract margins (150 top + 80 bottom)
AVAILABLE_WIDTH = SCREEN_WIDTH - 40  # Some padding

# Calculate tile size to fit the grid
TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
MARGIN = 150

# Game constants
MINE_COUNT = 5
FLAG_LIMIT = 5
LIVES = 3

# Colors
BG_COLOR = (40, 44, 52)
PANEL_COLOR = (30, 34, 42)
UNREVEALED_COLOR = (58, 95, 135)
UNREVEALED_HOVER_COLOR = (75, 115, 160)
REVEALED_COLOR = (220, 220, 225)
MINE_COLOR = (215, 95, 95)
FLAG_COLOR = (255, 50, 50)
BORDER_COLOR = (20, 20, 25)
LIFE_COLOR = (255, 80, 80)

# Number colors (classic minesweeper colors)
NUMBER_COLORS = {
    1: (45, 85, 165),
    2: (60, 145, 70),
    3: (185, 60, 60),
    4: (35, 60, 135),
    5: (150, 50, 50),
    6: (50, 140, 140),
    7: (40, 40, 40),
    8: (100, 100, 100)
}

# Create resizable window
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT), pygame.RESIZABLE)
pygame.display.set_caption("Minesweeper RL")

class Tile:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.is_mine = False
        self.is_revealed = False
        self.is_flagged = False
        self.adjacent_mines = 0
        self.hover = False

class MinesweeperGame:
    def __init__(self):
        self.grid = [[Tile(x, y) for y in range(GRID_SIZE)] for x in range(GRID_SIZE)]
        self.game_over = False
        self.game_won = False
        self.flags_placed = 0
        self.flag_limit = FLAG_LIMIT
        self.revealed_count = 0
        self.score = 0
        self.start_time = pygame.time.get_ticks()
        self.end_time = None
        self.combo = 0
        self.max_combo = 0
        self.lives = LIVES
        self.total_mines = MINE_COUNT
        self.mines_hit = []  # Track which mines were hit
        self.setup_mines()
        self.calculate_adjacent_mines()
    
    def setup_mines(self):
        mines_placed = 0
        while mines_placed < self.total_mines:
            x = random.randint(0, GRID_SIZE - 1)
            y = random.randint(0, GRID_SIZE - 1)
            if not self.grid[x][y].is_mine:
                self.grid[x][y].is_mine = True
                mines_placed += 1
    
    def calculate_adjacent_mines(self):
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                if not self.grid[x][y].is_mine:
                    count = 0
                    for dx in [-1, 0, 1]:
                        for dy in [-1, 0, 1]:
                            if dx == 0 and dy == 0:
                                continue
                            nx, ny = x + dx, y + dy
                            if 0 <= nx < GRID_SIZE and 0 <= ny < GRID_SIZE:
                                if self.grid[nx][ny].is_mine:
                                    count += 1
                    self.grid[x][y].adjacent_mines = count
    
    def reveal_tile(self, x, y):
        if self.game_over or self.game_won:
            return
        
        tile = self.grid[x][y]
        if tile.is_revealed or tile.is_flagged:
            return
        
        tile.is_revealed = True
        self.revealed_count += 1
        
        if tile.is_mine:
            self.lives -= 1
            self.combo = 0  # Reset combo on mine hit
            self.mines_hit.append((x, y))
            
            if self.lives <= 0:
                self.game_over = True
                self.end_time = pygame.time.get_ticks()
                self.reveal_all_mines()
            return
        
        # Add score based on tile value
        if tile.adjacent_mines == 0:
            self.score += 10
            self.combo += 1
        else:
            self.score += tile.adjacent_mines * 5
            self.combo += 1
        
        # Combo bonus
        if self.combo > 5:
            self.score += self.combo * 2
        
        self.max_combo = max(self.max_combo, self.combo)
        
        if tile.adjacent_mines == 0:
            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    if dx == 0 and dy == 0:
                        continue
                    nx, ny = x + dx, y + dy
                    if 0 <= nx < GRID_SIZE and 0 <= ny < GRID_SIZE:
                        self.reveal_tile(nx, ny)
        
        # Check win condition: all non-mine tiles revealed
        non_mine_tiles = GRID_SIZE * GRID_SIZE - self.total_mines
        safe_tiles_revealed = self.revealed_count - len(self.mines_hit)
        
        if safe_tiles_revealed == non_mine_tiles:
            self.game_won = True
            self.end_time = pygame.time.get_ticks()
            # Win bonus
            time_bonus = max(0, 1000 - (self.end_time - self.start_time) // 100)
            self.score += time_bonus
            # Perfect flag bonus
            if self.flags_placed == MINE_COUNT:
                self.score += 500
            # Lives bonus
            self.score += self.lives * 200
    
    def toggle_flag(self, x, y):
        if self.game_over or self.game_won:
            return
        tile = self.grid[x][y]
        if not tile.is_revealed:
            if tile.is_flagged:
                tile.is_flagged = False
                self.flags_placed -= 1
                self.combo = 0  # Reset combo on flag remove
                # Cancel bonus for removing a correct flag
                if tile.is_mine:
                    self.score -= 50
            elif self.flags_placed < self.flag_limit:
                tile.is_flagged = True
                self.flags_placed += 1
                # Bonus for correct flag
                if tile.is_mine:
                    self.score += 50
                self.combo = 0  # Reset combo on flag
    
    def reveal_all_mines(self):
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                if self.grid[x][y].is_mine:
                    self.grid[x][y].is_revealed = True

# %%
from typing import Optional
from A2C import A2C  # Assuming A2C is defined in A2C.py

def get_tile_from_mouse(mx, my):
    if my < MARGIN or my >= MARGIN + GRID_SIZE * TILE_SIZE:
        return None, None
    if mx < (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2:
        return None, None
    if mx >= (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2 + GRID_SIZE * TILE_SIZE:
        return None, None
    
    offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
    grid_x = (mx - offset_x) // TILE_SIZE
    grid_y = (my - MARGIN) // TILE_SIZE
    
    if 0 <= grid_x < GRID_SIZE and 0 <= grid_y < GRID_SIZE:
        return int(grid_x), int(grid_y)
    
    return None, None

def draw_game(game, agent: Optional[A2C] = None):
    screen.fill(BG_COLOR)
    
    # Draw top panel
    pygame.draw.rect(screen, PANEL_COLOR, (0, 0, SCREEN_WIDTH, MARGIN))
    
    # Draw bottom panel
    pygame.draw.rect(screen, PANEL_COLOR, (0, SCREEN_HEIGHT - 80, SCREEN_WIDTH, 80))
    
    # Calculate grid offset for centering
    offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
    offset_y = MARGIN
    
    # Draw grid
    for x in range(GRID_SIZE):
        for y in range(GRID_SIZE):
            tile = game.grid[x][y]
            rect = pygame.Rect(offset_x + x * TILE_SIZE, offset_y + y * TILE_SIZE, TILE_SIZE, TILE_SIZE)
            
            # Draw border
            pygame.draw.rect(screen, BORDER_COLOR, rect, 3)
            
            # Shrink rect for inner tile
            inner_rect = rect.inflate(-6, -6)
            
            if tile.is_revealed:
                if tile.is_mine:
                    pygame.draw.rect(screen, MINE_COLOR, inner_rect)
                    # Draw mine circle
                    center = inner_rect.center
                    pygame.draw.circle(screen, (40, 40, 40), center, 20)
                    # Draw X if this mine was hit
                    if (x, y) in game.mines_hit:
                        pygame.draw.line(screen, (255, 255, 255), 
                                       (center[0] - 12, center[1] - 12), 
                                       (center[0] + 12, center[1] + 12), 4)
                        pygame.draw.line(screen, (255, 255, 255), 
                                       (center[0] + 12, center[1] - 12), 
                                       (center[0] - 12, center[1] + 12), 4)
                else:
                    pygame.draw.rect(screen, REVEALED_COLOR, inner_rect)
                    if tile.adjacent_mines > 0:
                        # Draw number
                        font = pygame.font.Font(None, 60)
                        text = font.render(str(tile.adjacent_mines), True, NUMBER_COLORS[tile.adjacent_mines])
                        text_rect = text.get_rect(center=inner_rect.center)
                        screen.blit(text, text_rect)
            else:
                if tile.hover:
                    pygame.draw.rect(screen, UNREVEALED_HOVER_COLOR, inner_rect)
                else:
                    pygame.draw.rect(screen, UNREVEALED_COLOR, inner_rect)
                
                if tile.is_flagged:
                    # Draw flag triangle
                    center_x, center_y = inner_rect.center
                    # Flag pole
                    pygame.draw.rect(screen, (60, 60, 60), (center_x - 2, center_y - 20, 4, 35))
                    # Flag triangle
                    flag_points = [
                        (center_x + 2, center_y - 18),
                        (center_x + 22, center_y - 8),
                        (center_x + 2, center_y + 2)
                    ]
                    pygame.draw.polygon(screen, FLAG_COLOR, flag_points)
                    pygame.draw.polygon(screen, (180, 30, 30), flag_points, 2)

    # Visualize Last Agent Action
    if agent is not None and agent.LAST_ACTION is not None:
        x, y, action_type = agent.LAST_ACTION
        
        offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
        offset_y = MARGIN
        
        action_x = offset_x + x * TILE_SIZE + TILE_SIZE // 2
        action_y = offset_y + y * TILE_SIZE + TILE_SIZE // 2
        
        # Blue circle for reveal, red for flag
        color = (100, 200, 255) if action_type == 0 else (255, 100, 100)
        pygame.draw.circle(screen, color, (action_x, action_y), TILE_SIZE // 2, 5)
    
    # Draw UI text
    font_large = pygame.font.Font(None, 48)
    font_medium = pygame.font.Font(None, 36)
    font_small = pygame.font.Font(None, 28)
    font_xsmall = pygame.font.Font(None, 20)
    
    # Calculate time
    if game.end_time:
        elapsed = (game.end_time - game.start_time) // 1000
    else:
        elapsed = (pygame.time.get_ticks() - game.start_time) // 1000
    
    if game.game_over:
        text = font_large.render("GAME OVER!", True, (235, 100, 95))
        screen.blit(text, (SCREEN_WIDTH // 2 - text.get_width() // 2, 30))
        score_text = font_medium.render(f"Final Score: {game.score}", True, (255, 200, 100))
        screen.blit(score_text, (SCREEN_WIDTH // 2 - score_text.get_width() // 2, 80))
    elif game.game_won:
        text = font_large.render("YOU WIN!", True, (90, 200, 110))
        screen.blit(text, (SCREEN_WIDTH // 2 - text.get_width() // 2, 30))
        score_text = font_medium.render(f"Final Score: {game.score}", True, (100, 255, 150))
        screen.blit(score_text, (SCREEN_WIDTH // 2 - score_text.get_width() // 2, 80))
        
        # Show achievements
        achievements = []
        if elapsed < 60:
            achievements.append("⚡ Speed Demon!")
        if game.max_combo >= 10:
            achievements.append("🔥 Combo Master!")
        if game.flags_placed == MINE_COUNT:
            achievements.append("🎯 Perfect Flags!")
        if game.lives == LIVES:
            achievements.append("💎 Flawless Victory!")
        
        y_pos = 120
        for achievement in achievements:
            ach_text = font_small.render(achievement, True, (255, 215, 0))
            screen.blit(ach_text, (SCREEN_WIDTH // 2 - ach_text.get_width() // 2, y_pos))
            y_pos += 30
    else:
        # Top left - Stats
        text1 = font_medium.render(f"Score: {game.score}", True, (255, 215, 0))
        text2 = font_medium.render(f"Time: {elapsed}s", True, (100, 200, 255))
        screen.blit(text1, (30, 30))
        screen.blit(text2, (30, 65))
        
        # Draw lives as hearts
        heart_y = 100
        for i in range(LIVES):
            heart_x = 40 + i * 35
            if i < game.lives:
                # Filled heart
                color = LIFE_COLOR
            else:
                # Empty heart
                color = (80, 80, 80)
            
            # Draw simple heart shape
            pygame.draw.circle(screen, color, (heart_x, heart_y), 10)
            pygame.draw.circle(screen, color, (heart_x + 14, heart_y), 10)
            heart_points = [
                (heart_x - 10, heart_y + 3),
                (heart_x + 7, heart_y + 20),
                (heart_x + 24, heart_y + 3)
            ]
            pygame.draw.polygon(screen, color, heart_points)
        
        # Top right - Game info
        mines_left = MINE_COUNT - game.flags_placed
        text3 = font_medium.render(f"Mines: {mines_left}", True, (240, 200, 120))
        text4 = font_medium.render(f"Flags: {game.flags_placed}/{FLAG_LIMIT}", True, (120, 180, 230))
        screen.blit(text3, (SCREEN_WIDTH - 200, 30))
        screen.blit(text4, (SCREEN_WIDTH - 200, 65))
        
        # Combo indicator
        if game.combo > 3:
            combo_text = font_medium.render(f"Combo x{game.combo}!", True, (255, 100, 255))
            yPos = 30 if agent is None else 5
            screen.blit(combo_text, (SCREEN_WIDTH // 2 - combo_text.get_width() // 2, yPos))

    # Display metrics for RL agent
    if agent is not None:
        metrics_y = 36
        metrics = [
            agent.printMetrics(["Win Rate"], True),
            agent.printMetrics(["Episodes", "Current Episode"], True),
            agent.printMetrics(["Highest Score"], True),
            agent.printMetrics(["Time Efficiency"], True),
            agent.printMetrics(["Left Click Avg", "Right Click Avg", ], True),
            agent.printMetrics(["Total Click Avg"], True),
            agent.printMetrics(["Game Conclusion History"], True)
        ]

        for metric in metrics:
            metric_text = font_xsmall.render(metric, True, (200, 200, 200))
            screen.blit(metric_text, (SCREEN_WIDTH // 2 - metric_text.get_width() // 2, metrics_y))
            metrics_y += metric_text.get_height()
    
    # Bottom instructions
    text1 = font_small.render("Left Click: Reveal", True, (200, 200, 200))
    text2 = font_small.render("Right Click: Flag", True, (200, 200, 200))
    text3 = font_small.render("R: Restart", True, (200, 200, 200))

    # Mouse control hints
    if agent is not None:
        text4 = font_small.render("Blue: Reveal", True, (100, 200, 255))
        text5 = font_small.render("Red: Flag", True, (255, 100, 100))
    
    screen.blit(text1, (30, SCREEN_HEIGHT - 50))
    screen.blit(text2, (250, SCREEN_HEIGHT - 50))
    screen.blit(text3, (450, SCREEN_HEIGHT - 50))
    screen.blit(text4, (SCREEN_WIDTH - 150, SCREEN_HEIGHT - 75))
    screen.blit(text5, (SCREEN_WIDTH - 150, SCREEN_HEIGHT - 25))

# %% [markdown]
# # Key Implementation Changes
#
# The initial proposal provided a strong foundation. The following changes were implemented during development to improve the training effectiveness and final performance of the Actor-Critic agent.

# %% [markdown]
# ## Enhanced Agent State ($S_t$)
#
# The agent's state representation was enhanced to provide a richer understanding of the environment. This allows the agent to make more intelligent decisions and prevents it from getting stuck in unproductive loops.
#
# The original proposed state included:
#
# - Visible Grid
# - Score
# - Lives
# - Flags
# - Combo
# - Game Status (active/won/lost)
#
# The final implementation was updated to these:
#
# - **Visible Grid:** The board state.
# - **Lives:** Tracks how many lives are left in the episode.
# - **Combo:** Tracks the real-time combo in the run.
# - **Flags:** Tracks how many flags are left allowed to be place on the board.
# - **Progress:** Tracks the ratio of revealed safe tiles to the total number of safe tiles.
# - **Interaction History:** Encodes how recently the agent has interacted with each tiles. Basically a history of actions.

# %% [markdown]
# ## Simplified Reward Function ($R_t$)
#
# The initial reward function, tied to the complex in-game score, proved to be a noisy signal that limited the agent's performance (resulting in a 5-13% win rate). Therefore, it was replaced with a simplified, sparse reward function to provide a clearer learning objective.
#
# The new function is based on four simple rules:
#
# - **Win Bonus:** A large positive reward of **+100** is given when the agent successfully clears all non-mine tiles. This defines the ultimate goal.
# - **Loss Penalty:** A large negative penalty of **-100** is given when the agent loses its last life or runs out of time. This clearly punishes failure.
# - **Progress Reward:** A small positive reward of **+1 is given for each new safe tile** the agent successfully reveals in a single turn. This encourages the agent to explore and clear the board.
# - **Efficiency Penalty:** A tiny negative penalty of **-0.1 is applied for every action taken**. This incentivizes the agent to win in as few steps as possible.

# %%
from A2C import A2C
import numpy as np

game = None
agent = None

def main():
    global SCREEN_WIDTH, SCREEN_HEIGHT, TILE_SIZE, screen, game, agent

    game = MinesweeperGame()
    agent = A2C(
        gridSize = GRID_SIZE,
        maxLives = LIVES,
        gameInstance = game,
        discountFactor = 0.999,
        betaEntropy = 0.015,
        lr = {
            0: 0.001,
            2000: 0.0005,
            5000: 0.0001,
		}
    )
    
    clock = pygame.time.Clock()
    running = True

    def clickHandler():
        mx, my = pygame.mouse.get_pos()
        gridX, gridY = get_tile_from_mouse(mx, my)
            
        if gridX is not None:
            if event.button == 1:  # Left click
                game.reveal_tile(gridX, gridY)
            elif event.button == 3:  # Right click
                game.toggle_flag(gridX, gridY)
        return

    def agentTurnLogic():
        global game, agent

        done = False
        elapsedTime = ((pygame.time.get_ticks() - game.start_time) / 1000)
        
        if not (game.game_over or game.game_won):
            
            # Encode Current State
            stateCurrent = agent._encodeState()
            
            # Agent Selects Action
            x, y, actionType, actionIdx, _ = agent.chooseAction(stateCurrent)
            
            # Update action history and interaction tracking
            agent.ACTION_HISTORY.append((x, y, actionType))
            if len(agent.ACTION_HISTORY) > agent.ACTION_HISTORY_SIZE:
                agent.ACTION_HISTORY.pop(0)
            
            agent.TILE_INTERACTION_HISTORY[(x, y)] = len(agent.ACTION_HISTORY)
            agent.LAST_ACTION = (x, y, actionType)
            
            # Store pre-action state to measure outcome
            livesOld = game.lives
            revealedOld = game.revealed_count
            reward = 0

            # Execute Action
            if actionType == 0:
                game.reveal_tile(x, y)
            else:
                game.toggle_flag(x, y)

            # -------------------------------
            # Simplified Reward Calculation
            # -------------------------------
            # Apply small "cost of living" penalty to encourage efficiency
            reward -= 0.1
            
            # Reward progress for revealing new safe tiles
            mine_hit = livesOld > game.lives
            if not mine_hit:
                newly_revealed = game.revealed_count - revealedOld
                if newly_revealed > 0:
                    reward += newly_revealed * 1.0

            # Check for game termination
            done = game.game_over or game.game_won
            if done:
                if game.game_won:
                    reward += 100  # Large bonus for winning
                else:
                    reward += -100 # Large penalty for losing
            
            # ------------------
            # Click Metric Update
            # ------------------
            if len(agent.CLICKS["left"]) < agent.EPISODES:
                agent.CLICKS["left"].append(0)
                agent.CLICKS["right"].append(0)
                agent.CLICKS["total"].append(0)

            agent.CLICKS["total"][agent.EPISODES - 1] += 1
            if actionType == 0:
                agent.CLICKS["left"][agent.EPISODES - 1] += 1
            else:
                agent.CLICKS["right"][agent.EPISODES - 1] += 1

            # Terminate if game is taking too long
            if elapsedTime > 45:
                game.game_over = True
                done = True
                if not game.game_won:
                    # Ensure loss penalty is applied on timeout
                    reward = -100
                print(log("Game terminated: Time limit exceeded"))

            # Reward clipping to prevent extreme values
            reward = np.clip(reward, -100, 100)
            
            # Get Next State and Train Agent
            stateNext = agent._encodeState()
            loss, tdError = agent.train(stateCurrent, actionIdx, reward, stateNext, done)
            
            # Print progress for debugging
            if agent.CLICKS["total"][agent.EPISODES - 1] % 10 == 0 or done:
                print(f"[Ep {agent.EPISODES}, Step {agent.CLICKS['total'][agent.EPISODES - 1]}] "
                    f"Score: {game.score} | Reward: {reward:.2f} | TD Error: {tdError:.2f} | "
                    f"Action: ({x}, {y}) {'Reveal' if actionType == 0 else 'Flag'} | "
                    f"Revealed: {game.revealed_count}/{GRID_SIZE * GRID_SIZE - game.total_mines}")

        # Reset game if episode is finished
        if game.game_over or game.game_won:
            draw_game(game, agent)
            pygame.display.flip()
            pygame.time.delay(1000)

            # Episode Checkpoint
            if agent.EPISODES % 100 == 0:
                if len(agent.GAME_CONCLUSIONS) >= 300:
                    last100WR = sum(agent.GAME_CONCLUSIONS[-100:]) / 100
                    last200WR = sum(agent.GAME_CONCLUSIONS[-200:-100]) / 100
                    last300WR = sum(agent.GAME_CONCLUSIONS[-300:-200]) / 100

                    print(log(f"\n[Win Rate Trend]:"))
                    print(log(f"  Episodes {agent.EPISODES-300}-{agent.EPISODES-200}: {last300WR:.1%}"))
                    print(log(f"  Episodes {agent.EPISODES-200}-{agent.EPISODES-100}: {last200WR:.1%}"))
                    print(log(f"  Episodes {agent.EPISODES-100}-{agent.EPISODES}: {last100WR:.1%}"))

                    if last100WR > last200WR:
                        print(log("  🟢 Improving trend"))
                    elif last100WR < last200WR:
                        print(log("  🟡 Declining trend - consider hyperparameter adjustment"))
                    else:
                        print(log("  🟡 Flat trend - agent may be stuck"))

            # Re-initialize the game and agent state for next episode
            game = MinesweeperGame()
            agent.endEpisode(game)

            # ----------------------------
            # Print Metrics
            # ----------------------------
            print(log(f"\n{'='*60}"))
            print(log(f"Episode {agent.EPISODES - 1} finished: {'WIN' if agent.GAME_CONCLUSIONS[-1] else 'LOSS'} | Score: {agent.SCORES[-1]}"))
            print(log(agent.printMetrics(asString = True)))
            print(log(f"{'='*60}\n"))

        return done

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.VIDEORESIZE:
                # Handle window resize
                SCREEN_WIDTH, SCREEN_HEIGHT = event.w, event.h
                screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT), pygame.RESIZABLE)
                
                # Recalculate tile size
                AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
                AVAILABLE_WIDTH = SCREEN_WIDTH - 40
                TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
                
            elif event.type == pygame.MOUSEBUTTONDOWN:
                clickHandler()
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_r:
                    game = MinesweeperGame()

        # Let the agent take its turn
        if agent is not None:
            gameDone = agentTurnLogic()

            # Stop after 300 episodes
            if agent.EPISODES > 300 and gameDone:
                saveModel(MODEL_NAME, agent)
                running = False

        # Update hover state
        mx, my = pygame.mouse.get_pos()
        hoverX, hoverY = get_tile_from_mouse(mx, my)
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                game.grid[x][y].hover = (x == hoverX and y == hoverY)
        
        draw_game(game, agent)
        pygame.display.flip()
        clock.tick(60)

    if AUTO_QUIT:
    	pygame.quit()

if __name__ == "__main__":
    main()
# Out:
# [Ep 1, Step 10] Score: 2440 | Reward: -100.00 | TD Error: -10.00 | Action: (6, 2) Reveal | Revealed: 49/59
#
# ============================================================
# Episode 1 finished: LOSS | Score: 2440
# Episodes: 1 | Win Rate: 0.00% | Highest Score: 2440.00 | Time Efficiency: 3.06 steps/sec | Left Click Avg: 5.00 c/g (1.53 c/s) | Right Click Avg: 5.00 c/g (1.53 c/s) | Total Click Avg: 10.00 c/g (3.06 c/s) | Game Conclusion History: 0 Wins, 1 Losses
# ============================================================
#
# [Ep 2, Step 10] Score: 1706 | Reward: -0.10 | TD Error: 0.33 | Action: (1, 1) Flag | Revealed: 50/59
# [Ep 2, Step 15] Score: 1711 | Reward: -100.00 | TD Error: -10.00 | Action: (0, 3) Reveal | Revealed: 53/59
#
# ============================================================
# Episode 2 finished: LOSS | Score: 1711
# Episodes: 2 | Win Rate: 0.00% | Highest Score: 2440.00 | Time Efficiency: 3.64 steps/sec | Left Click Avg: 7.50 c/g (2.18 c/s) | Right Click Avg: 5.00 c/g (1.45 c/s) | Total Click Avg: 12.50 c/g (3.64 c/s) | Game Conclusion History: 0 Wins, 2 Losses
# ============================================================
#
# [Ep 3, Step 10] Score: 3017 | Reward: -0.10 | TD Error: -0.09 | Action: (7, 7) Flag | Revealed: 57/59
# [Ep 3, Step 20] Score: 2972 | Reward: -0.10 | TD Error: 0.07 | Action: (7, 7) Flag | Revealed: 60/59
# [Ep 3, Step 26] Score: 4296 | Reward: 100.00 | TD Error: 10.00 | Action: (6, 7) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 3 finished: WIN | Score: 4296
# Episodes: 3 | Win Rate: 33.33% | Highest Score: 4296.00 | Time Efficiency: 4.60 steps/sec | Left Click Avg: 7.33 c/g (1.98 c/s) | Right Click Avg: 9.67 c/g (2.62 c/s) | Total Click Avg: 17.00 c/g (4.60 c/s) | Game Conclusion History: 1 Wins, 2 Losses
# ============================================================
#
# [Ep 4, Step 10] Score: 3470 | Reward: -0.10 | TD Error: -0.50 | Action: (7, 0) Reveal | Revealed: 58/59
# [Ep 4, Step 12] Score: 3420 | Reward: -100.00 | TD Error: -10.00 | Action: (5, 3) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 4 finished: LOSS | Score: 3420
# Episodes: 4 | Win Rate: 25.00% | Highest Score: 4296.00 | Time Efficiency: 4.67 steps/sec | Left Click Avg: 7.25 c/g (2.15 c/s) | Right Click Avg: 8.50 c/g (2.52 c/s) | Total Click Avg: 15.75 c/g (4.67 c/s) | Game Conclusion History: 1 Wins, 3 Losses
# ============================================================
#
# [Ep 5, Step 10] Score: 3560 | Reward: -0.10 | TD Error: 0.13 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 5, Step 15] Score: 3560 | Reward: -100.00 | TD Error: -10.00 | Action: (1, 2) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 5 finished: LOSS | Score: 3560
# Episodes: 5 | Win Rate: 20.00% | Highest Score: 4296.00 | Time Efficiency: 4.80 steps/sec | Left Click Avg: 7.00 c/g (2.15 c/s) | Right Click Avg: 8.60 c/g (2.64 c/s) | Total Click Avg: 15.60 c/g (4.80 c/s) | Game Conclusion History: 1 Wins, 4 Losses
# ============================================================
#
# [Ep 6, Step 10] Score: 2023 | Reward: -0.10 | TD Error: 0.66 | Action: (2, 2) Flag | Revealed: 53/59
# [Ep 6, Step 20] Score: 2028 | Reward: -0.10 | TD Error: -0.38 | Action: (7, 7) Flag | Revealed: 55/59
# [Ep 6, Step 30] Score: 2028 | Reward: -0.10 | TD Error: -0.11 | Action: (7, 7) Flag | Revealed: 56/59
# [Ep 6, Step 40] Score: 2028 | Reward: -0.10 | TD Error: 0.08 | Action: (7, 7) Flag | Revealed: 56/59
# [Ep 6, Step 50] Score: 2028 | Reward: -0.10 | TD Error: 0.08 | Action: (7, 7) Flag | Revealed: 56/59
# [Ep 6, Step 60] Score: 1988 | Reward: -100.00 | TD Error: -10.00 | Action: (4, 5) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 6 finished: LOSS | Score: 1988
# Episodes: 6 | Win Rate: 16.67% | Highest Score: 4296.00 | Time Efficiency: 4.93 steps/sec | Left Click Avg: 7.00 c/g (1.50 c/s) | Right Click Avg: 16.00 c/g (3.43 c/s) | Total Click Avg: 23.00 c/g (4.93 c/s) | Game Conclusion History: 1 Wins, 5 Losses
# ============================================================
#
# [Ep 7, Step 10] Score: 3367 | Reward: -0.10 | TD Error: 0.16 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 7, Step 13] Score: 3367 | Reward: -100.00 | TD Error: -10.00 | Action: (1, 6) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 7 finished: LOSS | Score: 3367
# Episodes: 7 | Win Rate: 14.29% | Highest Score: 4296.00 | Time Efficiency: 4.67 steps/sec | Left Click Avg: 6.86 c/g (1.49 c/s) | Right Click Avg: 14.71 c/g (3.19 c/s) | Total Click Avg: 21.57 c/g (4.67 c/s) | Game Conclusion History: 1 Wins, 6 Losses
# ============================================================
#
# [Ep 8, Step 10] Score: 2161 | Reward: -0.10 | TD Error: 2.47 | Action: (3, 7) Flag | Revealed: 56/59
# [Ep 8, Step 20] Score: 2186 | Reward: -0.10 | TD Error: 0.70 | Action: (3, 1) Flag | Revealed: 58/59
# [Ep 8, Step 25] Score: 3592 | Reward: 100.00 | TD Error: 10.00 | Action: (3, 0) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 8 finished: WIN | Score: 3592
# Episodes: 8 | Win Rate: 25.00% | Highest Score: 4296.00 | Time Efficiency: 4.58 steps/sec | Left Click Avg: 6.75 c/g (1.41 c/s) | Right Click Avg: 15.25 c/g (3.18 c/s) | Total Click Avg: 22.00 c/g (4.58 c/s) | Game Conclusion History: 2 Wins, 6 Losses
# ============================================================
#
# [Ep 9, Step 7] Score: 3420 | Reward: -100.00 | TD Error: -10.00 | Action: (5, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 9 finished: LOSS | Score: 3420
# Episodes: 9 | Win Rate: 22.22% | Highest Score: 4296.00 | Time Efficiency: 4.49 steps/sec | Left Click Avg: 6.56 c/g (1.45 c/s) | Right Click Avg: 13.78 c/g (3.04 c/s) | Total Click Avg: 20.33 c/g (4.49 c/s) | Game Conclusion History: 2 Wins, 7 Losses
# ============================================================
#
# [Ep 10, Step 10] Score: 3072 | Reward: 0.90 | TD Error: 0.36 | Action: (7, 7) Reveal | Revealed: 52/59
# [Ep 10, Step 20] Score: 3072 | Reward: -0.10 | TD Error: 0.60 | Action: (5, 1) Flag | Revealed: 53/59
# [Ep 10, Step 30] Score: 3237 | Reward: -0.10 | TD Error: -0.28 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 10, Step 40] Score: 3137 | Reward: -0.10 | TD Error: 4.65 | Action: (3, 2) Flag | Revealed: 55/59
# [Ep 10, Step 50] Score: 3147 | Reward: -0.10 | TD Error: -0.55 | Action: (5, 0) Flag | Revealed: 56/59
# [Ep 10, Step 60] Score: 3202 | Reward: -0.10 | TD Error: -0.42 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 10, Step 70] Score: 3152 | Reward: -0.10 | TD Error: -0.39 | Action: (5, 0) Flag | Revealed: 57/59
# [Ep 10, Step 80] Score: 3202 | Reward: -0.10 | TD Error: 0.19 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 10, Step 88] Score: 3162 | Reward: -100.00 | TD Error: -10.00 | Action: (3, 3) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 10 finished: LOSS | Score: 3162
# Episodes: 10 | Win Rate: 20.00% | Highest Score: 4296.00 | Time Efficiency: 4.88 steps/sec | Left Click Avg: 7.00 c/g (1.26 c/s) | Right Click Avg: 20.10 c/g (3.62 c/s) | Total Click Avg: 27.10 c/g (4.88 c/s) | Game Conclusion History: 2 Wins, 8 Losses
# ============================================================
#
# [Ep 11, Step 10] Score: 2825 | Reward: -0.10 | TD Error: -3.97 | Action: (4, 6) Reveal | Revealed: 51/59
# [Ep 11, Step 20] Score: 2860 | Reward: 0.90 | TD Error: -0.15 | Action: (6, 6) Reveal | Revealed: 56/59
# [Ep 11, Step 30] Score: 2910 | Reward: -0.10 | TD Error: 1.30 | Action: (6, 7) Flag | Revealed: 57/59
# [Ep 11, Step 38] Score: 2910 | Reward: -100.00 | TD Error: -10.00 | Action: (7, 6) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 11 finished: LOSS | Score: 2910
# Episodes: 11 | Win Rate: 18.18% | Highest Score: 4296.00 | Time Efficiency: 4.93 steps/sec | Left Click Avg: 7.36 c/g (1.29 c/s) | Right Click Avg: 20.73 c/g (3.64 c/s) | Total Click Avg: 28.09 c/g (4.93 c/s) | Game Conclusion History: 2 Wins, 9 Losses
# ============================================================
#
# [Ep 12, Step 8] Score: 3370 | Reward: -100.00 | TD Error: -10.00 | Action: (5, 5) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 12 finished: LOSS | Score: 3370
# Episodes: 12 | Win Rate: 16.67% | Highest Score: 4296.00 | Time Efficiency: 4.89 steps/sec | Left Click Avg: 7.08 c/g (1.31 c/s) | Right Click Avg: 19.33 c/g (3.58 c/s) | Total Click Avg: 26.42 c/g (4.89 c/s) | Game Conclusion History: 2 Wins, 10 Losses
# ============================================================
#
# [Ep 13, Step 10] Score: 15 | Reward: -0.10 | TD Error: 8.28 | Action: (1, 7) Flag | Revealed: 2/59
# [Ep 13, Step 20] Score: 2950 | Reward: -0.10 | TD Error: 2.55 | Action: (1, 7) Flag | Revealed: 55/59
# [Ep 13, Step 30] Score: 3050 | Reward: -0.10 | TD Error: -2.63 | Action: (5, 7) Flag | Revealed: 55/59
# [Ep 13, Step 40] Score: 2950 | Reward: -0.10 | TD Error: 4.48 | Action: (1, 7) Flag | Revealed: 55/59
# [Ep 13, Step 50] Score: 3060 | Reward: -0.10 | TD Error: 4.13 | Action: (5, 7) Flag | Revealed: 58/59
# [Ep 13, Step 60] Score: 3060 | Reward: -0.10 | TD Error: 5.24 | Action: (5, 7) Flag | Revealed: 58/59
# [Ep 13, Step 70] Score: 3060 | Reward: -0.10 | TD Error: 5.35 | Action: (5, 7) Flag | Revealed: 58/59
# [Ep 13, Step 80] Score: 3010 | Reward: -0.10 | TD Error: 4.98 | Action: (5, 7) Flag | Revealed: 58/59
# [Ep 13, Step 90] Score: 3010 | Reward: -0.10 | TD Error: 3.96 | Action: (5, 7) Flag | Revealed: 58/59
# [Ep 13, Step 97] Score: 2960 | Reward: -100.00 | TD Error: -10.00 | Action: (4, 2) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 13 finished: LOSS | Score: 2960
# Episodes: 13 | Win Rate: 15.38% | Highest Score: 4296.00 | Time Efficiency: 5.18 steps/sec | Left Click Avg: 7.31 c/g (1.19 c/s) | Right Click Avg: 24.54 c/g (3.99 c/s) | Total Click Avg: 31.85 c/g (5.18 c/s) | Game Conclusion History: 2 Wins, 11 Losses
# ============================================================
#
# [Ep 14, Step 10] Score: 2727 | Reward: -0.10 | TD Error: 0.46 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 20] Score: 2727 | Reward: -0.10 | TD Error: -0.09 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 30] Score: 2727 | Reward: -0.10 | TD Error: -0.07 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 40] Score: 2727 | Reward: -0.10 | TD Error: -0.14 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 50] Score: 2727 | Reward: -0.10 | TD Error: -0.13 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 60] Score: 2727 | Reward: -0.10 | TD Error: -0.11 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 70] Score: 2727 | Reward: -0.10 | TD Error: -0.11 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 80] Score: 2727 | Reward: -0.10 | TD Error: -0.11 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 14, Step 90] Score: 2784 | Reward: -0.10 | TD Error: 2.91 | Action: (4, 0) Flag | Revealed: 57/59
# [Ep 14, Step 91] Score: 2784 | Reward: -100.00 | TD Error: -10.00 | Action: (6, 2) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 14 finished: LOSS | Score: 2784
# Episodes: 14 | Win Rate: 14.29% | Highest Score: 4296.00 | Time Efficiency: 5.23 steps/sec | Left Click Avg: 7.36 c/g (1.07 c/s) | Right Click Avg: 28.71 c/g (4.17 c/s) | Total Click Avg: 36.07 c/g (5.23 c/s) | Game Conclusion History: 2 Wins, 12 Losses
# ============================================================
#
# [Ep 15, Step 10] Score: 3445 | Reward: -0.10 | TD Error: -4.26 | Action: (6, 5) Flag | Revealed: 54/59
# [Ep 15, Step 20] Score: 3500 | Reward: -0.10 | TD Error: -3.70 | Action: (6, 5) Flag | Revealed: 55/59
# [Ep 15, Step 30] Score: 3500 | Reward: -0.10 | TD Error: 6.58 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 40] Score: 3500 | Reward: -0.10 | TD Error: -6.04 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 50] Score: 3500 | Reward: -0.10 | TD Error: -6.21 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 60] Score: 3500 | Reward: -0.10 | TD Error: 5.67 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 70] Score: 3450 | Reward: -0.10 | TD Error: 6.15 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 80] Score: 3450 | Reward: -0.10 | TD Error: 6.62 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 90] Score: 3550 | Reward: -0.10 | TD Error: -6.62 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 100] Score: 3450 | Reward: -0.10 | TD Error: 7.06 | Action: (1, 5) Flag | Revealed: 55/59
# [Ep 15, Step 110] Score: 3565 | Reward: -0.10 | TD Error: -6.04 | Action: (1, 5) Flag | Revealed: 57/59
# [Ep 15, Step 120] Score: 3465 | Reward: -0.10 | TD Error: 5.51 | Action: (1, 5) Flag | Revealed: 57/59
# [Ep 15, Step 130] Score: 3465 | Reward: -0.10 | TD Error: 4.88 | Action: (1, 5) Flag | Revealed: 57/59
# [Ep 15, Step 140] Score: 3465 | Reward: -0.10 | TD Error: 4.35 | Action: (1, 5) Flag | Revealed: 57/59
# [Ep 15, Step 150] Score: 3415 | Reward: -0.10 | TD Error: 4.72 | Action: (1, 5) Flag | Revealed: 58/59
# [Ep 15, Step 157] Score: 3415 | Reward: -100.00 | TD Error: -10.00 | Action: (1, 5) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 15 finished: LOSS | Score: 3415
# Episodes: 15 | Win Rate: 13.33% | Highest Score: 4296.00 | Time Efficiency: 5.41 steps/sec | Left Click Avg: 7.27 c/g (0.89 c/s) | Right Click Avg: 36.87 c/g (4.52 c/s) | Total Click Avg: 44.13 c/g (5.41 c/s) | Game Conclusion History: 2 Wins, 13 Losses
# ============================================================
#
# [Ep 16, Step 1] Score: 13615 | Reward: 100.00 | TD Error: 10.00 | Action: (4, 7) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 16 finished: WIN | Score: 13615
# Episodes: 16 | Win Rate: 18.75% | Highest Score: 13615.00 | Time Efficiency: 5.37 steps/sec | Left Click Avg: 6.88 c/g (0.89 c/s) | Right Click Avg: 34.56 c/g (4.48 c/s) | Total Click Avg: 41.44 c/g (5.37 c/s) | Game Conclusion History: 3 Wins, 13 Losses
# ============================================================
#
# [Ep 17, Step 10] Score: 941 | Reward: -0.10 | TD Error: 0.26 | Action: (5, 0) Flag | Revealed: 27/59
# [Ep 17, Step 20] Score: 941 | Reward: -0.10 | TD Error: 1.20 | Action: (5, 0) Flag | Revealed: 27/59
# [Ep 17, Step 30] Score: 941 | Reward: -0.10 | TD Error: 0.37 | Action: (5, 0) Flag | Revealed: 27/59
# [Ep 17, Step 40] Score: 941 | Reward: -0.10 | TD Error: -0.57 | Action: (5, 0) Flag | Revealed: 27/59
# [Ep 17, Step 50] Score: 1597 | Reward: -0.10 | TD Error: -1.00 | Action: (5, 0) Flag | Revealed: 49/59
# [Ep 17, Step 60] Score: 1657 | Reward: -0.10 | TD Error: -2.64 | Action: (2, 4) Flag | Revealed: 50/59
# [Ep 17, Step 70] Score: 1667 | Reward: -0.10 | TD Error: 4.13 | Action: (4, 3) Flag | Revealed: 53/59
# [Ep 17, Step 80] Score: 1667 | Reward: -0.10 | TD Error: 0.02 | Action: (5, 0) Flag | Revealed: 53/59
# [Ep 17, Step 90] Score: 1667 | Reward: -0.10 | TD Error: -0.09 | Action: (5, 0) Flag | Revealed: 53/59
# [Ep 17, Step 100] Score: 1667 | Reward: -0.10 | TD Error: -0.16 | Action: (5, 0) Flag | Revealed: 53/59
# [Ep 17, Step 110] Score: 1717 | Reward: -0.10 | TD Error: -2.38 | Action: (6, 7) Flag | Revealed: 53/59
# [Ep 17, Step 120] Score: 1717 | Reward: -0.10 | TD Error: -0.36 | Action: (5, 0) Flag | Revealed: 53/59
# [Ep 17, Step 130] Score: 1727 | Reward: -0.10 | TD Error: -0.40 | Action: (7, 4) Flag | Revealed: 54/59
# [Ep 17, Step 140] Score: 1737 | Reward: -0.10 | TD Error: 0.07 | Action: (5, 0) Flag | Revealed: 55/59
# [Ep 17, Step 150] Score: 1742 | Reward: -0.10 | TD Error: -0.23 | Action: (5, 0) Flag | Revealed: 56/59
# [Ep 17, Step 160] Score: 1742 | Reward: -0.10 | TD Error: 0.07 | Action: (5, 0) Flag | Revealed: 56/59
# [Ep 17, Step 170] Score: 1757 | Reward: -0.10 | TD Error: -0.00 | Action: (5, 0) Flag | Revealed: 58/59
# [Ep 17, Step 180] Score: 1707 | Reward: -0.10 | TD Error: -0.22 | Action: (5, 0) Flag | Revealed: 58/59
# [Ep 17, Step 190] Score: 1657 | Reward: -0.10 | TD Error: -4.39 | Action: (2, 4) Reveal | Revealed: 59/59
# [Ep 17, Step 191] Score: 1657 | Reward: -100.00 | TD Error: -10.00 | Action: (6, 7) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 17 finished: LOSS | Score: 1657
# Episodes: 17 | Win Rate: 17.65% | Highest Score: 13615.00 | Time Efficiency: 5.68 steps/sec | Left Click Avg: 7.18 c/g (0.81 c/s) | Right Click Avg: 43.06 c/g (4.87 c/s) | Total Click Avg: 50.24 c/g (5.68 c/s) | Game Conclusion History: 3 Wins, 14 Losses
# ============================================================
#
# [Ep 18, Step 10] Score: 2537 | Reward: -0.10 | TD Error: -4.88 | Action: (4, 0) Flag | Revealed: 50/59
# [Ep 18, Step 20] Score: 2592 | Reward: -0.10 | TD Error: 6.71 | Action: (4, 0) Flag | Revealed: 51/59
# [Ep 18, Step 30] Score: 2592 | Reward: -0.10 | TD Error: -4.64 | Action: (4, 0) Flag | Revealed: 51/59
# [Ep 18, Step 40] Score: 2592 | Reward: -0.10 | TD Error: 5.46 | Action: (4, 0) Flag | Revealed: 51/59
# [Ep 18, Step 50] Score: 2592 | Reward: -0.10 | TD Error: 5.78 | Action: (4, 2) Flag | Revealed: 51/59
# [Ep 18, Step 60] Score: 2592 | Reward: -0.10 | TD Error: 7.09 | Action: (4, 2) Flag | Revealed: 52/59
# [Ep 18, Step 70] Score: 2642 | Reward: -0.10 | TD Error: -6.35 | Action: (4, 2) Flag | Revealed: 52/59
# [Ep 18, Step 80] Score: 2592 | Reward: -0.10 | TD Error: 8.74 | Action: (4, 2) Flag | Revealed: 52/59
# [Ep 18, Step 90] Score: 2592 | Reward: -0.10 | TD Error: 6.98 | Action: (4, 2) Flag | Revealed: 52/59
# [Ep 18, Step 100] Score: 2592 | Reward: -0.10 | TD Error: -6.20 | Action: (4, 0) Flag | Revealed: 52/59
# [Ep 18, Step 110] Score: 2592 | Reward: -0.10 | TD Error: 7.80 | Action: (4, 2) Flag | Revealed: 52/59
# [Ep 18, Step 120] Score: 2592 | Reward: -0.10 | TD Error: 3.84 | Action: (2, 6) Flag | Revealed: 52/59
# [Ep 18, Step 130] Score: 2662 | Reward: 0.90 | TD Error: -0.54 | Action: (3, 0) Reveal | Revealed: 54/59
# [Ep 18, Step 140] Score: 2612 | Reward: -0.10 | TD Error: 4.70 | Action: (4, 0) Flag | Revealed: 54/59
# [Ep 18, Step 150] Score: 2672 | Reward: -0.10 | TD Error: 2.44 | Action: (4, 0) Flag | Revealed: 57/59
# [Ep 18, Step 160] Score: 2672 | Reward: -0.10 | TD Error: -1.38 | Action: (4, 0) Flag | Revealed: 57/59
# [Ep 18, Step 170] Score: 2672 | Reward: -0.10 | TD Error: -1.18 | Action: (4, 0) Flag | Revealed: 57/59
# [Ep 18, Step 180] Score: 2672 | Reward: -0.10 | TD Error: -1.15 | Action: (4, 0) Flag | Revealed: 57/59
# [Ep 18, Step 190] Score: 2632 | Reward: -0.10 | TD Error: -1.06 | Action: (4, 0) Flag | Revealed: 58/59
# [Ep 18, Step 191] Score: 2632 | Reward: -100.00 | TD Error: -10.00 | Action: (4, 1) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 18 finished: LOSS | Score: 2632
# Episodes: 18 | Win Rate: 16.67% | Highest Score: 13615.00 | Time Efficiency: 5.94 steps/sec | Left Click Avg: 7.44 c/g (0.76 c/s) | Right Click Avg: 50.61 c/g (5.18 c/s) | Total Click Avg: 58.06 c/g (5.94 c/s) | Game Conclusion History: 3 Wins, 15 Losses
# ============================================================
#
# [Ep 19, Step 10] Score: 3555 | Reward: -0.10 | TD Error: -3.92 | Action: (1, 7) Flag | Revealed: 55/59
# [Ep 19, Step 20] Score: 3555 | Reward: -0.10 | TD Error: -3.71 | Action: (1, 7) Flag | Revealed: 55/59
# [Ep 19, Step 30] Score: 3505 | Reward: -0.10 | TD Error: 3.03 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 19, Step 40] Score: 3605 | Reward: -0.10 | TD Error: -1.36 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 19, Step 50] Score: 3605 | Reward: -0.10 | TD Error: -2.10 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 19, Step 60] Score: 3555 | Reward: -0.10 | TD Error: 2.23 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 19, Step 70] Score: 3560 | Reward: -0.10 | TD Error: -5.54 | Action: (7, 6) Flag | Revealed: 57/59
# [Ep 19, Step 80] Score: 3560 | Reward: -0.10 | TD Error: 6.01 | Action: (2, 7) Flag | Revealed: 58/59
# [Ep 19, Step 90] Score: 3565 | Reward: -0.10 | TD Error: 5.72 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 100] Score: 3565 | Reward: -0.10 | TD Error: 4.45 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 110] Score: 3615 | Reward: -0.10 | TD Error: -4.55 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 120] Score: 3615 | Reward: -0.10 | TD Error: -3.78 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 130] Score: 3515 | Reward: -0.10 | TD Error: 3.61 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 140] Score: 3565 | Reward: -0.10 | TD Error: -2.59 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 150] Score: 3565 | Reward: -0.10 | TD Error: -2.76 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 160] Score: 3565 | Reward: -0.10 | TD Error: 2.67 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 170] Score: 3565 | Reward: -0.10 | TD Error: 2.80 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 180] Score: 3565 | Reward: -0.10 | TD Error: 2.82 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 190] Score: 3565 | Reward: -0.10 | TD Error: 2.82 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 200] Score: 3565 | Reward: -0.10 | TD Error: 2.83 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 210] Score: 3565 | Reward: -0.10 | TD Error: 2.83 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 220] Score: 3565 | Reward: -0.10 | TD Error: 2.84 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 230] Score: 3565 | Reward: -0.10 | TD Error: 2.83 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 240] Score: 3565 | Reward: -0.10 | TD Error: 2.86 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 250] Score: 3565 | Reward: -0.10 | TD Error: 2.60 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 260] Score: 3615 | Reward: -0.10 | TD Error: -3.02 | Action: (2, 7) Flag | Revealed: 59/59
# [Ep 19, Step 270] Score: 3570 | Reward: -0.10 | TD Error: 2.66 | Action: (2, 7) Flag | Revealed: 60/59
# [Ep 19, Step 280] Score: 3570 | Reward: -0.10 | TD Error: 2.55 | Action: (2, 7) Flag | Revealed: 60/59
# [Ep 19, Step 290] Score: 3620 | Reward: -0.10 | TD Error: 2.49 | Action: (2, 7) Flag | Revealed: 60/59
# [Ep 19, Step 300] Score: 3620 | Reward: -0.10 | TD Error: -2.51 | Action: (2, 7) Flag | Revealed: 60/59
# [Ep 19, Step 307] Score: 3570 | Reward: -100.00 | TD Error: -10.00 | Action: (2, 7) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 19 finished: LOSS | Score: 3570
# Episodes: 19 | Win Rate: 15.79% | Highest Score: 13615.00 | Time Efficiency: 6.30 steps/sec | Left Click Avg: 7.42 c/g (0.66 c/s) | Right Click Avg: 63.74 c/g (5.64 c/s) | Total Click Avg: 71.16 c/g (6.30 c/s) | Game Conclusion History: 3 Wins, 16 Losses
# ============================================================
#
# [Ep 20, Step 10] Score: 656 | Reward: 0.90 | TD Error: -0.56 | Action: (6, 4) Reveal | Revealed: 24/59
# [Ep 20, Step 20] Score: 2023 | Reward: -0.10 | TD Error: -10.00 | Action: (1, 4) Reveal | Revealed: 59/59
# [Ep 20, Step 25] Score: 2023 | Reward: -100.00 | TD Error: -10.00 | Action: (7, 4) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 20 finished: LOSS | Score: 2023
# Episodes: 20 | Win Rate: 15.00% | Highest Score: 13615.00 | Time Efficiency: 6.29 steps/sec | Left Click Avg: 7.45 c/g (0.68 c/s) | Right Click Avg: 61.40 c/g (5.61 c/s) | Total Click Avg: 68.85 c/g (6.29 c/s) | Game Conclusion History: 3 Wins, 17 Losses
# ============================================================
#
# [Ep 21, Step 10] Score: 3836 | Reward: -0.10 | TD Error: 3.28 | Action: (1, 2) Flag | Revealed: 59/59
# [Ep 21, Step 20] Score: 3886 | Reward: -0.10 | TD Error: -5.10 | Action: (1, 2) Flag | Revealed: 59/59
# [Ep 21, Step 30] Score: 3886 | Reward: -0.10 | TD Error: -5.50 | Action: (1, 2) Flag | Revealed: 59/59
# [Ep 21, Step 40] Score: 3886 | Reward: -0.10 | TD Error: -5.81 | Action: (1, 2) Flag | Revealed: 59/59
# [Ep 21, Step 50] Score: 3936 | Reward: -0.10 | TD Error: -10.00 | Action: (0, 4) Flag | Revealed: 59/59
# [Ep 21, Step 60] Score: 3936 | Reward: -0.10 | TD Error: -10.00 | Action: (2, 2) Reveal | Revealed: 60/59
# [Ep 21, Step 70] Score: 3936 | Reward: -0.10 | TD Error: 0.27 | Action: (1, 2) Flag | Revealed: 60/59
# [Ep 21, Step 80] Score: 3936 | Reward: -0.10 | TD Error: -0.37 | Action: (1, 2) Flag | Revealed: 60/59
# [Ep 21, Step 90] Score: 3886 | Reward: -0.10 | TD Error: 1.54 | Action: (1, 2) Flag | Revealed: 60/59
# [Ep 21, Step 100] Score: 3886 | Reward: -0.10 | TD Error: 1.57 | Action: (1, 2) Flag | Revealed: 60/59
# [Ep 21, Step 105] Score: 4968 | Reward: 100.00 | TD Error: 10.00 | Action: (1, 2) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 21 finished: WIN | Score: 4968
# Episodes: 21 | Win Rate: 19.05% | Highest Score: 13615.00 | Time Efficiency: 6.37 steps/sec | Left Click Avg: 7.33 c/g (0.66 c/s) | Right Click Avg: 63.24 c/g (5.70 c/s) | Total Click Avg: 70.57 c/g (6.37 c/s) | Game Conclusion History: 4 Wins, 17 Losses
# ============================================================
#
# [Ep 22, Step 10] Score: 15 | Reward: -0.10 | TD Error: 9.15 | Action: (1, 7) Flag | Revealed: 2/59
# [Ep 22, Step 20] Score: 1706 | Reward: -0.10 | TD Error: 2.73 | Action: (7, 3) Flag | Revealed: 40/59
# [Ep 22, Step 30] Score: 1716 | Reward: -0.10 | TD Error: 1.81 | Action: (7, 3) Flag | Revealed: 41/59
# [Ep 22, Step 40] Score: 1797 | Reward: -0.10 | TD Error: -2.26 | Action: (7, 3) Flag | Revealed: 48/59
# [Ep 22, Step 50] Score: 1802 | Reward: -0.10 | TD Error: 2.06 | Action: (7, 3) Flag | Revealed: 49/59
# [Ep 22, Step 60] Score: 1802 | Reward: -0.10 | TD Error: 1.77 | Action: (7, 3) Flag | Revealed: 49/59
# [Ep 22, Step 70] Score: 1802 | Reward: -0.10 | TD Error: -1.08 | Action: (7, 3) Flag | Revealed: 50/59
# [Ep 22, Step 80] Score: 1807 | Reward: -0.10 | TD Error: 1.18 | Action: (7, 3) Flag | Revealed: 51/59
# [Ep 22, Step 90] Score: 1807 | Reward: -0.10 | TD Error: 0.82 | Action: (7, 3) Flag | Revealed: 51/59
# [Ep 22, Step 100] Score: 1807 | Reward: -0.10 | TD Error: -0.65 | Action: (7, 3) Flag | Revealed: 51/59
# [Ep 22, Step 110] Score: 1807 | Reward: -0.10 | TD Error: -0.35 | Action: (7, 3) Flag | Revealed: 51/59
# [Ep 22, Step 120] Score: 1807 | Reward: -0.10 | TD Error: 0.18 | Action: (7, 3) Flag | Revealed: 51/59
# [Ep 22, Step 130] Score: 1862 | Reward: -0.10 | TD Error: -0.04 | Action: (7, 3) Flag | Revealed: 52/59
# [Ep 22, Step 140] Score: 1862 | Reward: -0.10 | TD Error: 0.77 | Action: (7, 3) Flag | Revealed: 52/59
# [Ep 22, Step 150] Score: 1867 | Reward: -0.10 | TD Error: -0.80 | Action: (7, 3) Flag | Revealed: 53/59
# [Ep 22, Step 160] Score: 1867 | Reward: -0.10 | TD Error: -1.15 | Action: (7, 3) Flag | Revealed: 53/59
# [Ep 22, Step 170] Score: 1867 | Reward: -0.10 | TD Error: -1.62 | Action: (7, 3) Flag | Revealed: 53/59
# [Ep 22, Step 180] Score: 1902 | Reward: 3.90 | TD Error: 0.36 | Action: (5, 5) Reveal | Revealed: 57/59
# [Ep 22, Step 190] Score: 1902 | Reward: -0.10 | TD Error: 1.00 | Action: (7, 3) Flag | Revealed: 57/59
# [Ep 22, Step 200] Score: 1902 | Reward: -0.10 | TD Error: 0.71 | Action: (7, 3) Flag | Revealed: 57/59
# [Ep 22, Step 206] Score: 1907 | Reward: -100.00 | TD Error: -10.00 | Action: (5, 7) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 22 finished: LOSS | Score: 1907
# Episodes: 22 | Win Rate: 18.18% | Highest Score: 13615.00 | Time Efficiency: 6.52 steps/sec | Left Click Avg: 7.68 c/g (0.65 c/s) | Right Click Avg: 69.05 c/g (5.87 c/s) | Total Click Avg: 76.73 c/g (6.52 c/s) | Game Conclusion History: 4 Wins, 18 Losses
# ============================================================
#
# [Ep 23, Step 10] Score: 1416 | Reward: -0.10 | TD Error: -0.01 | Action: (5, 0) Flag | Revealed: 33/59
# [Ep 23, Step 20] Score: 1808 | Reward: -0.10 | TD Error: 0.21 | Action: (7, 1) Flag | Revealed: 51/59
# [Ep 23, Step 30] Score: 1808 | Reward: -0.10 | TD Error: -0.67 | Action: (7, 1) Flag | Revealed: 51/59
# [Ep 23, Step 40] Score: 1808 | Reward: -0.10 | TD Error: 0.46 | Action: (7, 1) Flag | Revealed: 51/59
# [Ep 23, Step 50] Score: 1808 | Reward: -0.10 | TD Error: -0.16 | Action: (7, 1) Flag | Revealed: 51/59
# [Ep 23, Step 60] Score: 1898 | Reward: -0.10 | TD Error: -0.61 | Action: (4, 0) Flag | Revealed: 55/59
# [Ep 23, Step 70] Score: 1953 | Reward: -0.10 | TD Error: -0.32 | Action: (4, 0) Flag | Revealed: 56/59
# [Ep 23, Step 80] Score: 1903 | Reward: -0.10 | TD Error: -1.75 | Action: (4, 2) Flag | Revealed: 57/59
# [Ep 23, Step 90] Score: 1853 | Reward: -0.10 | TD Error: -0.25 | Action: (4, 2) Flag | Revealed: 57/59
# [Ep 23, Step 100] Score: 1903 | Reward: -0.10 | TD Error: 7.64 | Action: (6, 2) Flag | Revealed: 57/59
# [Ep 23, Step 110] Score: 1903 | Reward: -0.10 | TD Error: 1.49 | Action: (4, 2) Flag | Revealed: 57/59
# [Ep 23, Step 120] Score: 1853 | Reward: -0.10 | TD Error: -2.40 | Action: (4, 2) Flag | Revealed: 58/59
# [Ep 23, Step 130] Score: 1853 | Reward: -0.10 | TD Error: 5.87 | Action: (0, 5) Flag | Revealed: 58/59
# [Ep 23, Step 140] Score: 1853 | Reward: -0.10 | TD Error: 1.79 | Action: (4, 2) Flag | Revealed: 58/59
# [Ep 23, Step 150] Score: 1853 | Reward: -0.10 | TD Error: 1.61 | Action: (4, 2) Flag | Revealed: 58/59
# [Ep 23, Step 160] Score: 1808 | Reward: -0.10 | TD Error: -1.62 | Action: (4, 2) Flag | Revealed: 59/59
# [Ep 23, Step 165] Score: 1868 | Reward: -100.00 | TD Error: 8.67 | Action: (0, 5) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 23 finished: LOSS | Score: 1868
# Episodes: 23 | Win Rate: 17.39% | Highest Score: 13615.00 | Time Efficiency: 6.62 steps/sec | Left Click Avg: 7.87 c/g (0.65 c/s) | Right Click Avg: 72.70 c/g (5.97 c/s) | Total Click Avg: 80.57 c/g (6.62 c/s) | Game Conclusion History: 4 Wins, 19 Losses
# ============================================================
#
# [Ep 24, Step 10] Score: 2047 | Reward: -0.10 | TD Error: -10.00 | Action: (1, 7) Flag | Revealed: 42/59
# [Ep 24, Step 20] Score: 2239 | Reward: -0.10 | TD Error: -1.94 | Action: (1, 7) Flag | Revealed: 53/59
# [Ep 24, Step 30] Score: 2239 | Reward: -0.10 | TD Error: 2.30 | Action: (1, 7) Flag | Revealed: 53/59
# [Ep 24, Step 40] Score: 2254 | Reward: -0.10 | TD Error: 0.50 | Action: (1, 7) Flag | Revealed: 55/59
# [Ep 24, Step 50] Score: 2254 | Reward: -0.10 | TD Error: 0.52 | Action: (1, 7) Flag | Revealed: 55/59
# [Ep 24, Step 60] Score: 2254 | Reward: -0.10 | TD Error: 3.83 | Action: (0, 0) Flag | Revealed: 55/59
# [Ep 24, Step 70] Score: 2254 | Reward: -0.10 | TD Error: -1.98 | Action: (5, 5) Flag | Revealed: 55/59
# [Ep 24, Step 80] Score: 2254 | Reward: -0.10 | TD Error: -0.65 | Action: (1, 7) Flag | Revealed: 55/59
# [Ep 24, Step 90] Score: 2254 | Reward: -0.10 | TD Error: 0.32 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 24, Step 100] Score: 2254 | Reward: -0.10 | TD Error: 0.10 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 24, Step 110] Score: 2254 | Reward: -0.10 | TD Error: -0.03 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 24, Step 111] Score: 2254 | Reward: -100.00 | TD Error: -10.00 | Action: (4, 6) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 24 finished: LOSS | Score: 2254
# Episodes: 24 | Win Rate: 16.67% | Highest Score: 13615.00 | Time Efficiency: 6.67 steps/sec | Left Click Avg: 7.83 c/g (0.64 c/s) | Right Click Avg: 74.00 c/g (6.03 c/s) | Total Click Avg: 81.83 c/g (6.67 c/s) | Game Conclusion History: 4 Wins, 20 Losses
# ============================================================
#
# [Ep 25, Step 10] Score: 3550 | Reward: -0.10 | TD Error: 7.34 | Action: (4, 2) Flag | Revealed: 56/59
# [Ep 25, Step 20] Score: 3565 | Reward: -0.10 | TD Error: 5.09 | Action: (4, 2) Flag | Revealed: 58/59
# [Ep 25, Step 30] Score: 3630 | Reward: -0.10 | TD Error: -4.57 | Action: (4, 2) Flag | Revealed: 59/59
# [Ep 25, Step 31] Score: 5004 | Reward: 100.00 | TD Error: 10.00 | Action: (6, 2) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 25 finished: WIN | Score: 5004
# Episodes: 25 | Win Rate: 20.00% | Highest Score: 13615.00 | Time Efficiency: 6.66 steps/sec | Left Click Avg: 7.76 c/g (0.65 c/s) | Right Click Avg: 72.04 c/g (6.02 c/s) | Total Click Avg: 79.80 c/g (6.66 c/s) | Game Conclusion History: 5 Wins, 20 Losses
# ============================================================
#
# [Ep 26, Step 10] Score: 2450 | Reward: -0.10 | TD Error: 0.44 | Action: (7, 1) Flag | Revealed: 45/59
# [Ep 26, Step 20] Score: 2450 | Reward: -0.10 | TD Error: 0.87 | Action: (7, 1) Flag | Revealed: 45/59
# [Ep 26, Step 30] Score: 2450 | Reward: -0.10 | TD Error: 1.86 | Action: (7, 1) Flag | Revealed: 45/59
# [Ep 26, Step 40] Score: 2450 | Reward: -0.10 | TD Error: -2.42 | Action: (7, 1) Flag | Revealed: 46/59
# [Ep 26, Step 50] Score: 2455 | Reward: -0.10 | TD Error: -2.53 | Action: (7, 1) Flag | Revealed: 48/59
# [Ep 26, Step 60] Score: 2460 | Reward: -0.10 | TD Error: 3.03 | Action: (7, 1) Flag | Revealed: 49/59
# [Ep 26, Step 70] Score: 2460 | Reward: -0.10 | TD Error: 2.89 | Action: (7, 1) Flag | Revealed: 49/59
# [Ep 26, Step 80] Score: 2470 | Reward: -0.10 | TD Error: -2.80 | Action: (7, 1) Flag | Revealed: 50/59
# [Ep 26, Step 90] Score: 2420 | Reward: -0.10 | TD Error: 1.88 | Action: (7, 1) Flag | Revealed: 50/59
# [Ep 26, Step 100] Score: 2420 | Reward: -0.10 | TD Error: 1.42 | Action: (7, 1) Flag | Revealed: 50/59
# [Ep 26, Step 110] Score: 2420 | Reward: -0.10 | TD Error: -2.30 | Action: (4, 0) Flag | Revealed: 50/59
# [Ep 26, Step 111] Score: 2420 | Reward: -100.00 | TD Error: -10.00 | Action: (6, 3) Reveal | Revealed: 51/59
#
# ============================================================
# Episode 26 finished: LOSS | Score: 2420
# Episodes: 26 | Win Rate: 19.23% | Highest Score: 13615.00 | Time Efficiency: 6.70 steps/sec | Left Click Avg: 7.73 c/g (0.64 c/s) | Right Click Avg: 73.27 c/g (6.06 c/s) | Total Click Avg: 81.00 c/g (6.70 c/s) | Game Conclusion History: 5 Wins, 21 Losses
# ============================================================
#
# [Ep 27, Step 10] Score: 10 | Reward: 0.90 | TD Error: 0.71 | Action: (5, 0) Reveal | Revealed: 2/59
# [Ep 27, Step 20] Score: 10 | Reward: -0.10 | TD Error: 5.66 | Action: (1, 7) Flag | Revealed: 2/59
# [Ep 27, Step 30] Score: 15 | Reward: -0.10 | TD Error: -5.03 | Action: (1, 7) Flag | Revealed: 3/59
# [Ep 27, Step 40] Score: 20 | Reward: -0.10 | TD Error: -4.59 | Action: (1, 7) Flag | Revealed: 4/59
# [Ep 27, Step 50] Score: 20 | Reward: -0.10 | TD Error: 3.40 | Action: (7, 1) Flag | Revealed: 4/59
# [Ep 27, Step 60] Score: 20 | Reward: -0.10 | TD Error: 3.46 | Action: (1, 7) Flag | Revealed: 4/59
# [Ep 27, Step 70] Score: 2636 | Reward: -0.10 | TD Error: -10.00 | Action: (4, 4) Flag | Revealed: 51/59
# [Ep 27, Step 80] Score: 2636 | Reward: -0.10 | TD Error: 0.33 | Action: (4, 0) Flag | Revealed: 53/59
# [Ep 27, Step 90] Score: 2636 | Reward: -100.00 | TD Error: -10.00 | Action: (4, 0) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 27 finished: LOSS | Score: 2636
# Episodes: 27 | Win Rate: 18.52% | Highest Score: 13615.00 | Time Efficiency: 6.74 steps/sec | Left Click Avg: 7.74 c/g (0.64 c/s) | Right Click Avg: 73.59 c/g (6.10 c/s) | Total Click Avg: 81.33 c/g (6.74 c/s) | Game Conclusion History: 5 Wins, 22 Losses
# ============================================================
#
# [Ep 28, Step 10] Score: 2537 | Reward: -0.10 | TD Error: -6.21 | Action: (0, 0) Flag | Revealed: 47/59
# [Ep 28, Step 20] Score: 2537 | Reward: -0.10 | TD Error: 2.49 | Action: (1, 2) Flag | Revealed: 47/59
# [Ep 28, Step 30] Score: 2587 | Reward: -0.10 | TD Error: -2.28 | Action: (1, 2) Flag | Revealed: 47/59
# [Ep 28, Step 40] Score: 2587 | Reward: -0.10 | TD Error: 3.41 | Action: (1, 2) Flag | Revealed: 47/59
# [Ep 28, Step 50] Score: 2587 | Reward: -0.10 | TD Error: 4.73 | Action: (1, 2) Flag | Revealed: 47/59
# [Ep 28, Step 60] Score: 2597 | Reward: 0.90 | TD Error: -0.99 | Action: (0, 4) Reveal | Revealed: 48/59
# [Ep 28, Step 70] Score: 2597 | Reward: -0.10 | TD Error: -4.85 | Action: (1, 2) Flag | Revealed: 48/59
# [Ep 28, Step 80] Score: 2597 | Reward: -0.10 | TD Error: -4.83 | Action: (1, 2) Flag | Revealed: 48/59
# [Ep 28, Step 90] Score: 2597 | Reward: -0.10 | TD Error: -4.83 | Action: (1, 2) Flag | Revealed: 48/59
# [Ep 28, Step 100] Score: 2622 | Reward: -0.10 | TD Error: -4.23 | Action: (1, 2) Flag | Revealed: 52/59
# [Ep 28, Step 110] Score: 2622 | Reward: -0.10 | TD Error: -4.25 | Action: (1, 2) Flag | Revealed: 52/59
# [Ep 28, Step 120] Score: 2622 | Reward: -0.10 | TD Error: 1.87 | Action: (1, 2) Flag | Revealed: 53/59
# [Ep 28, Step 130] Score: 2622 | Reward: -0.10 | TD Error: -0.13 | Action: (1, 2) Flag | Revealed: 54/59
# [Ep 28, Step 140] Score: 2572 | Reward: -0.10 | TD Error: 2.75 | Action: (1, 5) Flag | Revealed: 54/59
# [Ep 28, Step 150] Score: 2622 | Reward: -0.10 | TD Error: 0.63 | Action: (1, 2) Flag | Revealed: 54/59
# [Ep 28, Step 160] Score: 2622 | Reward: -0.10 | TD Error: 0.56 | Action: (1, 2) Flag | Revealed: 54/59
# [Ep 28, Step 170] Score: 2622 | Reward: -0.10 | TD Error: 0.53 | Action: (1, 2) Flag | Revealed: 54/59
# [Ep 28, Step 173] Score: 2622 | Reward: -100.00 | TD Error: -10.00 | Action: (1, 4) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 28 finished: LOSS | Score: 2622
# Episodes: 28 | Win Rate: 17.86% | Highest Score: 13615.00 | Time Efficiency: 6.79 steps/sec | Left Click Avg: 7.75 c/g (0.62 c/s) | Right Click Avg: 76.86 c/g (6.17 c/s) | Total Click Avg: 84.61 c/g (6.79 c/s) | Game Conclusion History: 5 Wins, 23 Losses
# ============================================================
#
# [Ep 29, Step 10] Score: 3500 | Reward: -0.10 | TD Error: -2.56 | Action: (7, 3) Flag | Revealed: 55/59
# [Ep 29, Step 20] Score: 3500 | Reward: -0.10 | TD Error: 2.69 | Action: (7, 3) Flag | Revealed: 55/59
# [Ep 29, Step 30] Score: 3550 | Reward: -0.10 | TD Error: 3.26 | Action: (7, 3) Flag | Revealed: 56/59
# [Ep 29, Step 40] Score: 3550 | Reward: -0.10 | TD Error: 3.86 | Action: (7, 3) Flag | Revealed: 56/59
# [Ep 29, Step 50] Score: 3550 | Reward: -0.10 | TD Error: -2.32 | Action: (7, 3) Flag | Revealed: 57/59
# [Ep 29, Step 60] Score: 3610 | Reward: -0.10 | TD Error: -0.63 | Action: (7, 3) Flag | Revealed: 58/59
# [Ep 29, Step 70] Score: 3610 | Reward: -0.10 | TD Error: -1.13 | Action: (7, 3) Flag | Revealed: 58/59
# [Ep 29, Step 80] Score: 3610 | Reward: -0.10 | TD Error: -1.15 | Action: (7, 3) Flag | Revealed: 58/59
# [Ep 29, Step 90] Score: 3610 | Reward: -0.10 | TD Error: -0.12 | Action: (7, 3) Flag | Revealed: 58/59
# [Ep 29, Step 100] Score: 3560 | Reward: -0.10 | TD Error: -1.10 | Action: (7, 3) Flag | Revealed: 58/59
# [Ep 29, Step 110] Score: 3510 | Reward: -0.10 | TD Error: 1.09 | Action: (7, 3) Flag | Revealed: 58/59
# [Ep 29, Step 112] Score: 3510 | Reward: -100.00 | TD Error: -10.00 | Action: (0, 7) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 29 finished: LOSS | Score: 3510
# Episodes: 29 | Win Rate: 17.24% | Highest Score: 13615.00 | Time Efficiency: 6.82 steps/sec | Left Click Avg: 7.66 c/g (0.61 c/s) | Right Click Avg: 77.90 c/g (6.21 c/s) | Total Click Avg: 85.55 c/g (6.82 c/s) | Game Conclusion History: 5 Wins, 24 Losses
# ============================================================
#
# [Ep 30, Step 10] Score: 2355 | Reward: -0.10 | TD Error: -5.30 | Action: (4, 2) Flag | Revealed: 55/59
# [Ep 30, Step 20] Score: 2370 | Reward: -0.10 | TD Error: 6.13 | Action: (4, 2) Flag | Revealed: 56/59
# [Ep 30, Step 30] Score: 2370 | Reward: -0.10 | TD Error: 6.56 | Action: (4, 2) Flag | Revealed: 56/59
# [Ep 30, Step 40] Score: 2370 | Reward: -0.10 | TD Error: 6.55 | Action: (4, 2) Flag | Revealed: 56/59
# [Ep 30, Step 50] Score: 2425 | Reward: -0.10 | TD Error: 5.56 | Action: (4, 2) Flag | Revealed: 57/59
# [Ep 30, Step 60] Score: 2425 | Reward: -0.10 | TD Error: -4.61 | Action: (4, 2) Flag | Revealed: 58/59
# [Ep 30, Step 70] Score: 2435 | Reward: -0.10 | TD Error: -5.76 | Action: (4, 3) Flag | Revealed: 59/59
# [Ep 30, Step 75] Score: 3513 | Reward: 100.00 | TD Error: 10.00 | Action: (7, 4) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 30 finished: WIN | Score: 3513
# Episodes: 30 | Win Rate: 20.00% | Highest Score: 13615.00 | Time Efficiency: 6.84 steps/sec | Left Click Avg: 7.70 c/g (0.62 c/s) | Right Click Avg: 77.50 c/g (6.22 c/s) | Total Click Avg: 85.20 c/g (6.84 c/s) | Game Conclusion History: 6 Wins, 24 Losses
# ============================================================
#
# [Ep 31, Step 10] Score: 1860 | Reward: -0.10 | TD Error: -4.65 | Action: (7, 1) Flag | Revealed: 39/59
# [Ep 31, Step 20] Score: 1865 | Reward: -0.10 | TD Error: -5.03 | Action: (7, 1) Flag | Revealed: 40/59
# [Ep 31, Step 30] Score: 1865 | Reward: -0.10 | TD Error: 3.84 | Action: (7, 1) Flag | Revealed: 41/59
# [Ep 31, Step 40] Score: 1865 | Reward: -0.10 | TD Error: 4.01 | Action: (7, 1) Flag | Revealed: 41/59
# [Ep 31, Step 50] Score: 1865 | Reward: -0.10 | TD Error: 4.09 | Action: (7, 1) Flag | Revealed: 41/59
# [Ep 31, Step 60] Score: 2132 | Reward: -0.10 | TD Error: 9.95 | Action: (0, 0) Flag | Revealed: 55/59
# [Ep 31, Step 70] Score: 2132 | Reward: -0.10 | TD Error: 6.98 | Action: (0, 0) Flag | Revealed: 55/59
# [Ep 31, Step 80] Score: 2132 | Reward: -0.10 | TD Error: 6.33 | Action: (0, 0) Flag | Revealed: 55/59
# [Ep 31, Step 90] Score: 2192 | Reward: -0.10 | TD Error: 7.13 | Action: (0, 0) Flag | Revealed: 56/59
# [Ep 31, Step 100] Score: 2142 | Reward: -0.10 | TD Error: 6.58 | Action: (0, 0) Flag | Revealed: 57/59
# [Ep 31, Step 103] Score: 2142 | Reward: -100.00 | TD Error: -10.00 | Action: (0, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 31 finished: LOSS | Score: 2142
# Episodes: 31 | Win Rate: 19.35% | Highest Score: 13615.00 | Time Efficiency: 6.87 steps/sec | Left Click Avg: 7.71 c/g (0.62 c/s) | Right Click Avg: 78.06 c/g (6.25 c/s) | Total Click Avg: 85.77 c/g (6.87 c/s) | Game Conclusion History: 6 Wins, 25 Losses
# ============================================================
#
# [Ep 32, Step 10] Score: 1751 | Reward: -0.10 | TD Error: 4.20 | Action: (7, 1) Flag | Revealed: 37/59
# [Ep 32, Step 20] Score: 1761 | Reward: -0.10 | TD Error: -5.48 | Action: (7, 1) Flag | Revealed: 38/59
# [Ep 32, Step 30] Score: 1761 | Reward: -0.10 | TD Error: 4.96 | Action: (7, 1) Flag | Revealed: 38/59
# [Ep 32, Step 40] Score: 1761 | Reward: -0.10 | TD Error: 4.74 | Action: (7, 1) Flag | Revealed: 38/59
# [Ep 32, Step 50] Score: 1761 | Reward: -0.10 | TD Error: 4.60 | Action: (7, 1) Flag | Revealed: 38/59
# [Ep 32, Step 60] Score: 1771 | Reward: -0.10 | TD Error: 4.48 | Action: (7, 1) Flag | Revealed: 40/59
# [Ep 32, Step 70] Score: 1771 | Reward: -0.10 | TD Error: 4.44 | Action: (7, 1) Flag | Revealed: 40/59
# [Ep 32, Step 80] Score: 1888 | Reward: -0.10 | TD Error: 4.82 | Action: (7, 1) Flag | Revealed: 49/59
# [Ep 32, Step 90] Score: 1888 | Reward: -0.10 | TD Error: 5.15 | Action: (7, 1) Flag | Revealed: 49/59
# [Ep 32, Step 100] Score: 1958 | Reward: -0.10 | TD Error: -4.17 | Action: (7, 1) Flag | Revealed: 52/59
# [Ep 32, Step 110] Score: 1958 | Reward: -0.10 | TD Error: -3.43 | Action: (7, 1) Flag | Revealed: 52/59
# [Ep 32, Step 120] Score: 1908 | Reward: -0.10 | TD Error: 2.95 | Action: (7, 1) Flag | Revealed: 52/59
# [Ep 32, Step 130] Score: 1918 | Reward: -0.10 | TD Error: 2.71 | Action: (7, 1) Flag | Revealed: 53/59
# [Ep 32, Step 140] Score: 1918 | Reward: -0.10 | TD Error: 2.85 | Action: (7, 1) Flag | Revealed: 53/59
# [Ep 32, Step 150] Score: 1918 | Reward: -0.10 | TD Error: 2.89 | Action: (7, 1) Flag | Revealed: 53/59
# [Ep 32, Step 160] Score: 1918 | Reward: -0.10 | TD Error: 2.90 | Action: (7, 1) Flag | Revealed: 53/59
# [Ep 32, Step 170] Score: 1918 | Reward: -0.10 | TD Error: 2.80 | Action: (7, 1) Flag | Revealed: 53/59
# [Ep 32, Step 180] Score: 1918 | Reward: -0.10 | TD Error: 3.06 | Action: (7, 1) Flag | Revealed: 53/59
# [Ep 32, Step 190] Score: 1968 | Reward: -0.10 | TD Error: -1.61 | Action: (7, 1) Flag | Revealed: 54/59
# [Ep 32, Step 200] Score: 1973 | Reward: -0.10 | TD Error: 1.20 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 32, Step 210] Score: 1973 | Reward: -0.10 | TD Error: 1.30 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 32, Step 220] Score: 1973 | Reward: -0.10 | TD Error: 1.38 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 32, Step 230] Score: 1973 | Reward: -0.10 | TD Error: 1.39 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 32, Step 240] Score: 1973 | Reward: -0.10 | TD Error: 1.39 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 32, Step 250] Score: 1973 | Reward: -0.10 | TD Error: 1.38 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 32, Step 260] Score: 1983 | Reward: -0.10 | TD Error: 1.20 | Action: (7, 1) Flag | Revealed: 56/59
# [Ep 32, Step 270] Score: 1983 | Reward: -0.10 | TD Error: 0.89 | Action: (7, 1) Flag | Revealed: 56/59
# [Ep 32, Step 280] Score: 1983 | Reward: -0.10 | TD Error: -0.42 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 32, Step 290] Score: 1983 | Reward: -0.10 | TD Error: 0.34 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 32, Step 300] Score: 1983 | Reward: -0.10 | TD Error: 0.51 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 32, Step 310] Score: 1983 | Reward: -0.10 | TD Error: 0.49 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 32, Step 320] Score: 1983 | Reward: -0.10 | TD Error: 0.36 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 32, Step 330] Score: 1983 | Reward: -0.10 | TD Error: 0.46 | Action: (7, 1) Flag | Revealed: 57/59
# [Ep 32, Step 340] Score: 1938 | Reward: -0.10 | TD Error: -0.90 | Action: (7, 1) Flag | Revealed: 58/59
# [Ep 32, Step 348] Score: 1938 | Reward: -100.00 | TD Error: -10.00 | Action: (6, 4) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 32 finished: LOSS | Score: 1938
# Episodes: 32 | Win Rate: 18.75% | Highest Score: 13615.00 | Time Efficiency: 6.96 steps/sec | Left Click Avg: 7.91 c/g (0.59 c/s) | Right Click Avg: 86.06 c/g (6.37 c/s) | Total Click Avg: 93.97 c/g (6.96 c/s) | Game Conclusion History: 6 Wins, 26 Losses
# ============================================================
#
# [Ep 33, Step 10] Score: 1135 | Reward: -0.10 | TD Error: -0.65 | Action: (7, 1) Flag | Revealed: 30/59
# [Ep 33, Step 20] Score: 1135 | Reward: -0.10 | TD Error: 0.59 | Action: (7, 1) Flag | Revealed: 30/59
# [Ep 33, Step 30] Score: 1135 | Reward: -0.10 | TD Error: 0.89 | Action: (7, 1) Flag | Revealed: 30/59
# [Ep 33, Step 40] Score: 1135 | Reward: -0.10 | TD Error: 1.03 | Action: (7, 1) Flag | Revealed: 30/59
# [Ep 33, Step 50] Score: 1135 | Reward: -0.10 | TD Error: 1.08 | Action: (7, 1) Flag | Revealed: 30/59
# [Ep 33, Step 60] Score: 1135 | Reward: -0.10 | TD Error: 1.09 | Action: (7, 1) Flag | Revealed: 30/59
# [Ep 33, Step 70] Score: 1135 | Reward: -0.10 | TD Error: -1.71 | Action: (7, 1) Flag | Revealed: 30/59
# [Ep 33, Step 80] Score: 1135 | Reward: -0.10 | TD Error: -1.65 | Action: (7, 1) Flag | Revealed: 31/59
# [Ep 33, Step 90] Score: 1135 | Reward: -0.10 | TD Error: -1.58 | Action: (7, 1) Flag | Revealed: 31/59
# [Ep 33, Step 100] Score: 1546 | Reward: -0.10 | TD Error: 0.98 | Action: (7, 1) Flag | Revealed: 48/59
# [Ep 33, Step 110] Score: 1596 | Reward: -0.10 | TD Error: 0.29 | Action: (7, 3) Flag | Revealed: 48/59
# [Ep 33, Step 120] Score: 1596 | Reward: -0.10 | TD Error: -0.06 | Action: (7, 3) Flag | Revealed: 48/59
# [Ep 33, Step 130] Score: 1601 | Reward: -0.10 | TD Error: -0.52 | Action: (7, 3) Flag | Revealed: 49/59
# [Ep 33, Step 140] Score: 1551 | Reward: -0.10 | TD Error: 0.22 | Action: (7, 1) Flag | Revealed: 50/59
# [Ep 33, Step 150] Score: 1591 | Reward: -0.10 | TD Error: -0.02 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 33, Step 151] Score: 1591 | Reward: -100.00 | TD Error: -3.61 | Action: (4, 2) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 33 finished: LOSS | Score: 1591
# ...
# Game terminated: Time limit exceeded
# [Ep 290, Step 526] Score: 2450 | Reward: -100.00 | TD Error: -10.00 | Action: (3, 6) Flag | Revealed: 48/59
#
# ============================================================
# Episode 290 finished: LOSS | Score: 2450
# Episodes: 290 | Win Rate: 11.03% | Highest Score: 56850.00 | Time Efficiency: 9.59 steps/sec | Left Click Avg: 7.72 c/g (0.46 c/s) | Right Click Avg: 152.92 c/g (9.12 c/s) | Total Click Avg: 160.64 c/g (9.59 c/s) | Game Conclusion History: 32 Wins, 258 Losses
# ============================================================
#
# [Ep 291, Step 6] Score: 3692 | Reward: -100.00 | TD Error: -10.00 | Action: (1, 7) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 291 finished: LOSS | Score: 3692
# Episodes: 291 | Win Rate: 11.00% | Highest Score: 56850.00 | Time Efficiency: 9.58 steps/sec | Left Click Avg: 7.71 c/g (0.46 c/s) | Right Click Avg: 152.40 c/g (9.12 c/s) | Total Click Avg: 160.11 c/g (9.58 c/s) | Game Conclusion History: 32 Wins, 259 Losses
# ============================================================
#
# [Ep 292, Step 7] Score: 2950 | Reward: -100.00 | TD Error: -10.00 | Action: (7, 7) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 292 finished: LOSS | Score: 2950
# Episodes: 292 | Win Rate: 10.96% | Highest Score: 56850.00 | Time Efficiency: 9.58 steps/sec | Left Click Avg: 7.71 c/g (0.46 c/s) | Right Click Avg: 151.88 c/g (9.12 c/s) | Total Click Avg: 159.59 c/g (9.58 c/s) | Game Conclusion History: 32 Wins, 260 Losses
# ============================================================
#
# [Ep 293, Step 10] Score: 0 | Reward: -0.10 | TD Error: -6.18 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 20] Score: 0 | Reward: -0.10 | TD Error: -5.50 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 30] Score: 0 | Reward: -0.10 | TD Error: -5.37 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 40] Score: 0 | Reward: -0.10 | TD Error: -5.33 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 50] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 60] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 70] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 80] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 90] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 100] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 110] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 120] Score: 0 | Reward: -0.10 | TD Error: -5.31 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 130] Score: 0 | Reward: -0.10 | TD Error: -5.32 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 140] Score: 0 | Reward: -0.10 | TD Error: -5.32 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 150] Score: 0 | Reward: -0.10 | TD Error: -5.32 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 160] Score: 0 | Reward: -0.10 | TD Error: -5.32 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 170] Score: 0 | Reward: -0.10 | TD Error: -5.32 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 180] Score: 0 | Reward: -0.10 | TD Error: -5.33 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 293, Step 185] Score: 3221 | Reward: -100.00 | TD Error: -10.00 | Action: (6, 7) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 293 finished: LOSS | Score: 3221
# Episodes: 293 | Win Rate: 10.92% | Highest Score: 56850.00 | Time Efficiency: 9.59 steps/sec | Left Click Avg: 7.69 c/g (0.46 c/s) | Right Click Avg: 151.98 c/g (9.13 c/s) | Total Click Avg: 159.68 c/g (9.59 c/s) | Game Conclusion History: 32 Wins, 261 Losses
# ============================================================
#
# [Ep 294, Step 10] Score: 2990 | Reward: -0.10 | TD Error: -3.65 | Action: (5, 1) Flag | Revealed: 53/59
# [Ep 294, Step 20] Score: 3025 | Reward: 0.90 | TD Error: -4.33 | Action: (7, 2) Reveal | Revealed: 57/59
# [Ep 294, Step 26] Score: 3025 | Reward: -100.00 | TD Error: 10.00 | Action: (5, 5) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 294 finished: LOSS | Score: 3025
# Episodes: 294 | Win Rate: 10.88% | Highest Score: 56850.00 | Time Efficiency: 9.59 steps/sec | Left Click Avg: 7.70 c/g (0.46 c/s) | Right Click Avg: 151.52 c/g (9.12 c/s) | Total Click Avg: 159.22 c/g (9.59 c/s) | Game Conclusion History: 32 Wins, 262 Losses
# ============================================================
#
# [Ep 295, Step 10] Score: 3122 | Reward: -0.10 | TD Error: -10.00 | Action: (6, 5) Flag | Revealed: 57/59
# [Ep 295, Step 18] Score: 3132 | Reward: -100.00 | TD Error: 3.81 | Action: (6, 3) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 295 finished: LOSS | Score: 3132
# Episodes: 295 | Win Rate: 10.85% | Highest Score: 56850.00 | Time Efficiency: 9.59 steps/sec | Left Click Avg: 7.71 c/g (0.47 c/s) | Right Click Avg: 151.04 c/g (9.12 c/s) | Total Click Avg: 158.74 c/g (9.59 c/s) | Game Conclusion History: 32 Wins, 263 Losses
# ============================================================
#
# [Ep 296, Step 10] Score: 2009 | Reward: -0.10 | TD Error: -1.35 | Action: (2, 6) Reveal | Revealed: 54/59
# [Ep 296, Step 13] Score: 2059 | Reward: -100.00 | TD Error: -10.00 | Action: (2, 0) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 296 finished: LOSS | Score: 2059
# Episodes: 296 | Win Rate: 10.81% | Highest Score: 56850.00 | Time Efficiency: 9.58 steps/sec | Left Click Avg: 7.70 c/g (0.47 c/s) | Right Click Avg: 150.55 c/g (9.12 c/s) | Total Click Avg: 158.25 c/g (9.58 c/s) | Game Conclusion History: 32 Wins, 264 Losses
# ============================================================
#
# [Ep 297, Step 10] Score: 3337 | Reward: -100.00 | TD Error: -10.00 | Action: (7, 2) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 297 finished: LOSS | Score: 3337
# Episodes: 297 | Win Rate: 10.77% | Highest Score: 56850.00 | Time Efficiency: 9.58 steps/sec | Left Click Avg: 7.69 c/g (0.47 c/s) | Right Click Avg: 150.06 c/g (9.11 c/s) | Total Click Avg: 157.75 c/g (9.58 c/s) | Game Conclusion History: 32 Wins, 265 Losses
# ============================================================
#
# [Ep 298, Step 10] Score: 5 | Reward: -0.10 | TD Error: -6.15 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 20] Score: 55 | Reward: -0.10 | TD Error: 5.44 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 30] Score: 55 | Reward: -0.10 | TD Error: 5.83 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 40] Score: 55 | Reward: -0.10 | TD Error: 5.97 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 50] Score: 55 | Reward: -0.10 | TD Error: 6.01 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 60] Score: 55 | Reward: -0.10 | TD Error: 6.03 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 70] Score: 55 | Reward: -0.10 | TD Error: 6.03 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 80] Score: 55 | Reward: -0.10 | TD Error: 6.03 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 298, Step 90] Score: 3841 | Reward: -0.10 | TD Error: -10.00 | Action: (5, 7) Reveal | Revealed: 59/59
# [Ep 298, Step 92] Score: 4970 | Reward: 100.00 | TD Error: 10.00 | Action: (4, 0) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 298 finished: WIN | Score: 4970
# Episodes: 298 | Win Rate: 11.07% | Highest Score: 56850.00 | Time Efficiency: 9.58 steps/sec | Left Click Avg: 7.68 c/g (0.47 c/s) | Right Click Avg: 149.85 c/g (9.12 c/s) | Total Click Avg: 157.53 c/g (9.58 c/s) | Game Conclusion History: 33 Wins, 265 Losses
# ============================================================
#
# [Ep 299, Step 10] Score: 55 | Reward: -0.10 | TD Error: -6.82 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 299, Step 20] Score: 10 | Reward: 0.90 | TD Error: -0.88 | Action: (5, 1) Reveal | Revealed: 2/59
# [Ep 299, Step 30] Score: 110 | Reward: -0.10 | TD Error: -6.30 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 40] Score: 110 | Reward: -0.10 | TD Error: -6.80 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 50] Score: 110 | Reward: -0.10 | TD Error: -6.98 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 60] Score: 110 | Reward: -0.10 | TD Error: -7.04 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 70] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 80] Score: 110 | Reward: -0.10 | TD Error: -7.07 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 90] Score: 110 | Reward: -0.10 | TD Error: -7.07 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 100] Score: 110 | Reward: -0.10 | TD Error: -7.07 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 110] Score: 110 | Reward: -0.10 | TD Error: -7.07 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 120] Score: 110 | Reward: -0.10 | TD Error: -7.07 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 130] Score: 110 | Reward: -0.10 | TD Error: -7.07 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 140] Score: 110 | Reward: -0.10 | TD Error: -7.07 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 150] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 160] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 170] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 180] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 190] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 200] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 210] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 220] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 230] Score: 110 | Reward: -0.10 | TD Error: -7.06 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 240] Score: 110 | Reward: -0.10 | TD Error: -7.05 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 250] Score: 110 | Reward: -0.10 | TD Error: -7.05 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 260] Score: 110 | Reward: -0.10 | TD Error: -7.05 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 270] Score: 110 | Reward: -0.10 | TD Error: -7.05 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 299, Step 280] Score: 60 | Reward: -0.10 | TD Error: 3.93 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 290] Score: 60 | Reward: -0.10 | TD Error: 4.84 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 300] Score: 60 | Reward: -0.10 | TD Error: 5.14 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 310] Score: 60 | Reward: -0.10 | TD Error: 5.24 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 320] Score: 60 | Reward: -0.10 | TD Error: 5.28 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 330] Score: 60 | Reward: -0.10 | TD Error: 5.29 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 340] Score: 60 | Reward: -0.10 | TD Error: 5.30 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 350] Score: 60 | Reward: -0.10 | TD Error: 5.31 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 360] Score: 60 | Reward: -0.10 | TD Error: 5.31 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 370] Score: 60 | Reward: -0.10 | TD Error: 5.32 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 380] Score: 60 | Reward: -0.10 | TD Error: 5.33 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 390] Score: 60 | Reward: -0.10 | TD Error: 5.33 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 400] Score: 60 | Reward: -0.10 | TD Error: 5.34 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 410] Score: 60 | Reward: -0.10 | TD Error: 5.34 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 420] Score: 60 | Reward: -0.10 | TD Error: -5.26 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 430] Score: 60 | Reward: -0.10 | TD Error: -5.63 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 440] Score: 60 | Reward: -0.10 | TD Error: -5.76 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 450] Score: 60 | Reward: -0.10 | TD Error: -5.81 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 460] Score: 60 | Reward: -0.10 | TD Error: -5.84 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 470] Score: 60 | Reward: -0.10 | TD Error: 5.58 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 480] Score: 60 | Reward: -0.10 | TD Error: 6.00 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 490] Score: 60 | Reward: -0.10 | TD Error: -6.33 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 500] Score: 60 | Reward: -0.10 | TD Error: -6.21 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 510] Score: 60 | Reward: -0.10 | TD Error: -6.11 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 520] Score: 60 | Reward: -0.10 | TD Error: -6.08 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 530] Score: 60 | Reward: -0.10 | TD Error: -6.07 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 540] Score: 60 | Reward: -0.10 | TD Error: -6.06 | Action: (3, 6) Flag | Revealed: 3/59
# [Ep 299, Step 550] Score: 60 | Reward: -0.10 | TD Error: -6.06 | Action: (3, 6) Flag | Revealed: 3/59
# Game terminated: Time limit exceeded
# [Ep 299, Step 551] Score: 60 | Reward: -100.00 | TD Error: -10.00 | Action: (3, 6) Flag | Revealed: 3/59
#
# ============================================================
# Episode 299 finished: LOSS | Score: 60
# Episodes: 299 | Win Rate: 11.04% | Highest Score: 56850.00 | Time Efficiency: 9.61 steps/sec | Left Click Avg: 7.67 c/g (0.46 c/s) | Right Click Avg: 151.18 c/g (9.14 c/s) | Total Click Avg: 158.85 c/g (9.61 c/s) | Game Conclusion History: 33 Wins, 266 Losses
# ============================================================
#
# [Ep 300, Step 10] Score: 0 | Reward: -0.10 | TD Error: -8.13 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 300, Step 20] Score: 0 | Reward: -0.10 | TD Error: -7.25 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 300, Step 30] Score: 0 | Reward: -0.10 | TD Error: -7.08 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 300, Step 40] Score: 0 | Reward: -0.10 | TD Error: -7.02 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 300, Step 50] Score: 0 | Reward: -0.10 | TD Error: -7.00 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 300, Step 60] Score: 0 | Reward: -0.10 | TD Error: -7.00 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 300, Step 70] Score: 0 | Reward: -0.10 | TD Error: -6.99 | Action: (4, 6) Flag | Revealed: 1/59
# [Ep 300, Step 80] Score: 0 | Reward: -0.10 | TD Error: 6.97 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 300, Step 90] Score: 0 | Reward: -0.10 | TD Error: 7.03 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 300, Step 100] Score: 0 | Reward: -0.10 | TD Error: 7.11 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 300, Step 110] Score: 0 | Reward: -0.10 | TD Error: 7.15 | Action: (4, 6) Flag | Revealed: 2/59
# [Ep 300, Step 120] Score: 1987 | Reward: 17.90 | TD Error: -10.00 | Action: (6, 0) Reveal | Revealed: 55/59
# [Ep 300, Step 126] Score: 1992 | Reward: -100.00 | TD Error: -10.00 | Action: (5, 4) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 300 finished: LOSS | Score: 1992
# Episodes: 300 | Win Rate: 11.00% | Highest Score: 56850.00 | Time Efficiency: 9.61 steps/sec | Left Click Avg: 7.66 c/g (0.46 c/s) | Right Click Avg: 151.08 c/g (9.15 c/s) | Total Click Avg: 158.74 c/g (9.61 c/s) | Game Conclusion History: 33 Wins, 267 Losses
# ============================================================
#
#
# Saving progress to ./models\a2c_model_20251011_173431...
# Progress saved successfully.

# %%
# pygame.quit()

# %%
# saveModel(MODEL_NAME, agent)
