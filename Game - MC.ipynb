# %%
# %pip install pygame
# %pip install numpy
# %pip install tensorflow

# %%
import random
import numpy as np
import tensorflow as tf

# Set a specific integer for reproducibility
SEED_VALUE = 20250506

# 1. Set seed for Python's built-in random module
random.seed(SEED_VALUE)

# 2. Set seed for NumPy operations
np.random.seed(SEED_VALUE)

# 3. Set seed for TensorFlow (affects weight initialization and some GPU operations)
tf.random.set_seed(SEED_VALUE)
# Note: You might also need to set some environment variables for complete determinism

# %%
import pygame
from datetime import datetime

pygame.init()

# ----------------
# Constants
# ----------------
DISPLAY_INFO = pygame.display.Info()
MONITOR_WIDTH = DISPLAY_INFO.current_w
MONITOR_HEIGHT = DISPLAY_INFO.current_h

SCREEN_WIDTH = int(MONITOR_WIDTH * 0.6)
SCREEN_HEIGHT = int(MONITOR_HEIGHT * 0.8)

GRID_SIZE = 8
AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
AVAILABLE_WIDTH = SCREEN_WIDTH - 40

TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
MARGIN = 150

MINE_COUNT = 5
FLAG_LIMIT = 5
MAX_LIVES = 3

FILE_NAME = f"{datetime.now().strftime('%Y%m%d_%H%M%S')}"
LOG_NAME = f"mc_logs_{FILE_NAME}.txt"
MODEL_NAME = f"mc_model_{FILE_NAME}"

AUTO_QUIT = False
# Out:
# e:\Files\School Files\Reinforcement Learning\Project\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import os
import json
from datetime import datetime
from MC import MonteCarlo

def saveModel(modelName: str, agent: MonteCarlo):
    """Saves the agent's model weights and training metrics."""
    modelsDir = "./models"
    if not os.path.exists(modelsDir):
        os.makedirs(modelsDir)
    
    filePath = os.path.join(modelsDir, modelName)
    weightsPath = f'{filePath}_qnetwork.weights.h5'
    metricsPath = f'{filePath}_metrics.json'
    
    print(f"\nSaving progress to {filePath}...")
    
    # Save network
    agent.qNetwork.save_weights(weightsPath)
    
    # Prepare metrics data
    metricsData = {
        "EPISODES": agent.EPISODES,
        "ELAPSED_TIME": agent.ELAPSED_TIME,
        "GAME_CONCLUSIONS": agent.GAME_CONCLUSIONS,
        "WIN_RATE": agent.WIN_RATE,
        "HIGHEST_SCORE": agent.HIGHEST_SCORE,
        "SCORES": agent.SCORES,
        "TIME_EFFICIENCY": agent.TIME_EFFICIENCY,
        "CLICKS": agent.CLICKS,
        "EPSILON": agent.epsilon,
    }
    
    with open(metricsPath, 'w') as f:
        json.dump(metricsData, f, indent=4)
        
    print("Progress saved successfully.")

def loadModel(modelName: str, agent: MonteCarlo) -> MonteCarlo:
    """Loads the agent's model weights and training metrics."""
    filePath = os.path.join("./models", modelName)
    weightsPath = f'{filePath}_qnetwork.weights.h5'
    metricsPath = f'{filePath}_metrics.json'
    
    if os.path.exists(weightsPath) and os.path.exists(metricsPath):
        print(f"\nLoading progress from {filePath}...")
        
        agent.qNetwork.load_weights(weightsPath)
        
        with open(metricsPath, 'r') as f:
            metricsData = json.load(f)
        
        agent.EPISODES = metricsData.get("EPISODES", 1)
        agent.ELAPSED_TIME = metricsData.get("ELAPSED_TIME", [])
        agent.GAME_CONCLUSIONS = metricsData.get("GAME_CONCLUSIONS", [])
        agent.WIN_RATE = metricsData.get("WIN_RATE", 0.0)
        agent.HIGHEST_SCORE = metricsData.get("HIGHEST_SCORE", 0)
        agent.SCORES = metricsData.get("SCORES", [])
        agent.TIME_EFFICIENCY = metricsData.get("TIME_EFFICIENCY", 0.0)
        agent.CLICKS = metricsData.get("CLICKS", {"left": [], "right": [], "total": []})
        agent.epsilon = metricsData.get("EPSILON", agent.EPSILON_START)
        
        if isinstance(agent.LR, dict):
            currentLR = agent.optimizer.learning_rate.numpy()
            newLR = currentLR
            
            for milestone in sorted(agent.LR.keys()):
                if agent.EPISODES >= milestone:
                    newLR = agent.LR[milestone]
            
            if newLR != currentLR:
                print(f"[LR Scheduler] Loaded at Episode {agent.EPISODES}: Setting learning rate to {newLR:.6f}")
                agent.optimizer.learning_rate.assign(newLR)
        
        print("Progress loaded successfully.")
    else:
        print("\nNo saved progress found. Starting a new training run.")
        
    return agent

def log(string: str) -> str:
    if not os.path.exists("logs"):
        os.makedirs("logs")

    logName = os.path.join("logs", LOG_NAME)

    if not os.path.exists(logName):
        with open(logName, "w") as f:
            f.write(f"Log created on {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
            f.write("="*50 + "\n")

    with open(logName, "a") as f:
        f.write(string + "\n")

    return string

# %%
import pygame
import random

pygame.init()

display_info = pygame.display.Info()
MONITOR_WIDTH = display_info.current_w
MONITOR_HEIGHT = display_info.current_h

SCREEN_WIDTH = int(MONITOR_WIDTH * 0.6)
SCREEN_HEIGHT = int(MONITOR_HEIGHT * 0.8)

GRID_SIZE = 8
AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
AVAILABLE_WIDTH = SCREEN_WIDTH - 40

TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
MARGIN = 150

MINE_COUNT = 5
FLAG_LIMIT = 5
LIVES = 3

# Colors
BG_COLOR = (40, 44, 52)
PANEL_COLOR = (30, 34, 42)
UNREVEALED_COLOR = (58, 95, 135)
UNREVEALED_HOVER_COLOR = (75, 115, 160)
REVEALED_COLOR = (220, 220, 225)
MINE_COLOR = (215, 95, 95)
FLAG_COLOR = (255, 50, 50)
BORDER_COLOR = (20, 20, 25)
LIFE_COLOR = (255, 80, 80)

NUMBER_COLORS = {
    1: (45, 85, 165),
    2: (60, 145, 70),
    3: (185, 60, 60),
    4: (35, 60, 135),
    5: (150, 50, 50),
    6: (50, 140, 140),
    7: (40, 40, 40),
    8: (100, 100, 100)
}

screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT), pygame.RESIZABLE)
pygame.display.set_caption("Minesweeper RL - Monte Carlo")

class Tile:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.is_mine = False
        self.is_revealed = False
        self.is_flagged = False
        self.adjacent_mines = 0
        self.hover = False

class MinesweeperGame:
    def __init__(self):
        self.grid = [[Tile(x, y) for y in range(GRID_SIZE)] for x in range(GRID_SIZE)]
        self.game_over = False
        self.game_won = False
        self.flags_placed = 0
        self.flag_limit = FLAG_LIMIT
        self.revealed_count = 0
        self.score = 0
        self.start_time = pygame.time.get_ticks()
        self.end_time = None
        self.combo = 0
        self.max_combo = 0
        self.lives = LIVES
        self.total_mines = MINE_COUNT
        self.mines_hit = []
        self.setup_mines()
        self.calculate_adjacent_mines()
    
    def setup_mines(self):
        mines_placed = 0
        while mines_placed < self.total_mines:
            x = random.randint(0, GRID_SIZE - 1)
            y = random.randint(0, GRID_SIZE - 1)
            if not self.grid[x][y].is_mine:
                self.grid[x][y].is_mine = True
                mines_placed += 1
    
    def calculate_adjacent_mines(self):
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                if not self.grid[x][y].is_mine:
                    count = 0
                    for dx in [-1, 0, 1]:
                        for dy in [-1, 0, 1]:
                            if dx == 0 and dy == 0:
                                continue
                            nx, ny = x + dx, y + dy
                            if 0 <= nx < GRID_SIZE and 0 <= ny < GRID_SIZE:
                                if self.grid[nx][ny].is_mine:
                                    count += 1
                    self.grid[x][y].adjacent_mines = count
    
    def reveal_tile(self, x, y):
        if self.game_over or self.game_won:
            return
        
        tile = self.grid[x][y]
        if tile.is_revealed or tile.is_flagged:
            return
        
        tile.is_revealed = True
        self.revealed_count += 1
        
        if tile.is_mine:
            self.lives -= 1
            self.combo = 0
            self.mines_hit.append((x, y))
            
            if self.lives <= 0:
                self.game_over = True
                self.end_time = pygame.time.get_ticks()
                self.reveal_all_mines()
            return
        
        if tile.adjacent_mines == 0:
            self.score += 10
            self.combo += 1
        else:
            self.score += tile.adjacent_mines * 5
            self.combo += 1
        
        if self.combo > 5:
            self.score += self.combo * 2
        
        self.max_combo = max(self.max_combo, self.combo)
        
        if tile.adjacent_mines == 0:
            for dx in [-1, 0, 1]:
                for dy in [-1, 0, 1]:
                    if dx == 0 and dy == 0:
                        continue
                    nx, ny = x + dx, y + dy
                    if 0 <= nx < GRID_SIZE and 0 <= ny < GRID_SIZE:
                        self.reveal_tile(nx, ny)
        
        non_mine_tiles = GRID_SIZE * GRID_SIZE - self.total_mines
        safe_tiles_revealed = self.revealed_count - len(self.mines_hit)
        
        if safe_tiles_revealed == non_mine_tiles:
            self.game_won = True
            self.end_time = pygame.time.get_ticks()
            time_bonus = max(0, 1000 - (self.end_time - self.start_time) // 100)
            self.score += time_bonus
            if self.flags_placed == MINE_COUNT:
                self.score += 500
            self.score += self.lives * 200
    
    def toggle_flag(self, x, y):
        if self.game_over or self.game_won:
            return
        tile = self.grid[x][y]
        if not tile.is_revealed:
            if tile.is_flagged:
                tile.is_flagged = False
                self.flags_placed -= 1
                self.combo = 0
                if tile.is_mine:
                    self.score -= 50
            elif self.flags_placed < self.flag_limit:
                tile.is_flagged = True
                self.flags_placed += 1
                if tile.is_mine:
                    self.score += 50
                self.combo = 0
    
    def reveal_all_mines(self):
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                if self.grid[x][y].is_mine:
                    self.grid[x][y].is_revealed = True

# %%
from typing import Optional
from MC import MonteCarlo

def get_tile_from_mouse(mx, my):
    if my < MARGIN or my >= MARGIN + GRID_SIZE * TILE_SIZE:
        return None, None
    if mx < (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2:
        return None, None
    if mx >= (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2 + GRID_SIZE * TILE_SIZE:
        return None, None
    
    offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
    grid_x = (mx - offset_x) // TILE_SIZE
    grid_y = (my - MARGIN) // TILE_SIZE
    
    if 0 <= grid_x < GRID_SIZE and 0 <= grid_y < GRID_SIZE:
        return int(grid_x), int(grid_y)
    
    return None, None

def draw_game(game, agent: Optional[MonteCarlo] = None):
    screen.fill(BG_COLOR)
    
    pygame.draw.rect(screen, PANEL_COLOR, (0, 0, SCREEN_WIDTH, MARGIN))
    pygame.draw.rect(screen, PANEL_COLOR, (0, SCREEN_HEIGHT - 80, SCREEN_WIDTH, 80))
    
    offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
    offset_y = MARGIN
    
    for x in range(GRID_SIZE):
        for y in range(GRID_SIZE):
            tile = game.grid[x][y]
            rect = pygame.Rect(offset_x + x * TILE_SIZE, offset_y + y * TILE_SIZE, TILE_SIZE, TILE_SIZE)
            
            pygame.draw.rect(screen, BORDER_COLOR, rect, 3)
            inner_rect = rect.inflate(-6, -6)
            
            if tile.is_revealed:
                if tile.is_mine:
                    pygame.draw.rect(screen, MINE_COLOR, inner_rect)
                    center = inner_rect.center
                    pygame.draw.circle(screen, (40, 40, 40), center, 20)
                    if (x, y) in game.mines_hit:
                        pygame.draw.line(screen, (255, 255, 255), 
                                       (center[0] - 12, center[1] - 12), 
                                       (center[0] + 12, center[1] + 12), 4)
                        pygame.draw.line(screen, (255, 255, 255), 
                                       (center[0] + 12, center[1] - 12), 
                                       (center[0] - 12, center[1] + 12), 4)
                else:
                    pygame.draw.rect(screen, REVEALED_COLOR, inner_rect)
                    if tile.adjacent_mines > 0:
                        font = pygame.font.Font(None, 60)
                        text = font.render(str(tile.adjacent_mines), True, NUMBER_COLORS[tile.adjacent_mines])
                        text_rect = text.get_rect(center=inner_rect.center)
                        screen.blit(text, text_rect)
            else:
                if tile.hover:
                    pygame.draw.rect(screen, UNREVEALED_HOVER_COLOR, inner_rect)
                else:
                    pygame.draw.rect(screen, UNREVEALED_COLOR, inner_rect)
                
                if tile.is_flagged:
                    center_x, center_y = inner_rect.center
                    pygame.draw.rect(screen, (60, 60, 60), (center_x - 2, center_y - 20, 4, 35))
                    flag_points = [
                        (center_x + 2, center_y - 18),
                        (center_x + 22, center_y - 8),
                        (center_x + 2, center_y + 2)
                    ]
                    pygame.draw.polygon(screen, FLAG_COLOR, flag_points)
                    pygame.draw.polygon(screen, (180, 30, 30), flag_points, 2)

    if agent is not None and agent.LAST_ACTION is not None:
        x, y, action_type = agent.LAST_ACTION
        
        offset_x = (SCREEN_WIDTH - GRID_SIZE * TILE_SIZE) // 2
        offset_y = MARGIN
        
        action_x = offset_x + x * TILE_SIZE + TILE_SIZE // 2
        action_y = offset_y + y * TILE_SIZE + TILE_SIZE // 2
        
        color = (100, 200, 255) if action_type == 0 else (255, 100, 100)
        pygame.draw.circle(screen, color, (action_x, action_y), TILE_SIZE // 2, 5)
    
    font_large = pygame.font.Font(None, 48)
    font_medium = pygame.font.Font(None, 36)
    font_small = pygame.font.Font(None, 28)
    font_xsmall = pygame.font.Font(None, 20)
    
    if game.end_time:
        elapsed = (game.end_time - game.start_time) // 1000
    else:
        elapsed = (pygame.time.get_ticks() - game.start_time) // 1000
    
    if game.game_over:
        text = font_large.render("GAME OVER!", True, (235, 100, 95))
        screen.blit(text, (SCREEN_WIDTH // 2 - text.get_width() // 2, 30))
        score_text = font_medium.render(f"Final Score: {game.score}", True, (255, 200, 100))
        screen.blit(score_text, (SCREEN_WIDTH // 2 - score_text.get_width() // 2, 80))
    elif game.game_won:
        text = font_large.render("YOU WIN!", True, (90, 200, 110))
        screen.blit(text, (SCREEN_WIDTH // 2 - text.get_width() // 2, 30))
        score_text = font_medium.render(f"Final Score: {game.score}", True, (100, 255, 150))
        screen.blit(score_text, (SCREEN_WIDTH // 2 - score_text.get_width() // 2, 80))
    else:
        text1 = font_medium.render(f"Score: {game.score}", True, (255, 215, 0))
        text2 = font_medium.render(f"Time: {elapsed}s", True, (100, 200, 255))
        screen.blit(text1, (30, 30))
        screen.blit(text2, (30, 65))
        
        heart_y = 100
        for i in range(LIVES):
            heart_x = 40 + i * 35
            if i < game.lives:
                color = LIFE_COLOR
            else:
                color = (80, 80, 80)
            
            pygame.draw.circle(screen, color, (heart_x, heart_y), 10)
            pygame.draw.circle(screen, color, (heart_x + 14, heart_y), 10)
            heart_points = [
                (heart_x - 10, heart_y + 3),
                (heart_x + 7, heart_y + 20),
                (heart_x + 24, heart_y + 3)
            ]
            pygame.draw.polygon(screen, color, heart_points)
        
        mines_left = MINE_COUNT - game.flags_placed
        text3 = font_medium.render(f"Mines: {mines_left}", True, (240, 200, 120))
        text4 = font_medium.render(f"Flags: {game.flags_placed}/{FLAG_LIMIT}", True, (120, 180, 230))
        screen.blit(text3, (SCREEN_WIDTH - 200, 30))
        screen.blit(text4, (SCREEN_WIDTH - 200, 65))
        
        if game.combo > 3:
            combo_text = font_medium.render(f"Combo x{game.combo}!", True, (255, 100, 255))
            yPos = 30 if agent is None else 5
            screen.blit(combo_text, (SCREEN_WIDTH // 2 - combo_text.get_width() // 2, yPos))

    if agent is not None:
        metrics_y = 36
        metrics = [
            agent.printMetrics(["Win Rate"], True),
            agent.printMetrics(["Episodes", "Current Episode"], True),
            agent.printMetrics(["Highest Score"], True),
            agent.printMetrics(["Time Efficiency"], True),
            agent.printMetrics(["Left Click Avg", "Right Click Avg"], True),
            agent.printMetrics(["Total Click Avg"], True),
            agent.printMetrics(["Game Conclusion History"], True)
        ]

        for metric in metrics:
            metric_text = font_xsmall.render(metric, True, (200, 200, 200))
            screen.blit(metric_text, (SCREEN_WIDTH // 2 - metric_text.get_width() // 2, metrics_y))
            metrics_y += metric_text.get_height()
    
    text1 = font_small.render("Left Click: Reveal", True, (200, 200, 200))
    text2 = font_small.render("Right Click: Flag", True, (200, 200, 200))
    text3 = font_small.render("R: Restart", True, (200, 200, 200))

    if agent is not None:
        text4 = font_small.render("Blue: Reveal", True, (100, 200, 255))
        text5 = font_small.render("Red: Flag", True, (255, 100, 100))
        screen.blit(text4, (SCREEN_WIDTH - 150, SCREEN_HEIGHT - 75))
        screen.blit(text5, (SCREEN_WIDTH - 150, SCREEN_HEIGHT - 25))
    
    screen.blit(text1, (30, SCREEN_HEIGHT - 50))
    screen.blit(text2, (250, SCREEN_HEIGHT - 50))
    screen.blit(text3, (450, SCREEN_HEIGHT - 50))

# %% [markdown]
# # Key Implementation Changes
#
# The initial proposal provided a strong foundation. The following changes were implemented during development to improve the training effectiveness and final performance of the Actor-Critic agent.

# %% [markdown]
# ## Enhanced Agent State ($S_t$)
#
# The agent's state representation was enhanced to provide a richer understanding of the environment. This allows the agent to make more intelligent decisions and prevents it from getting stuck in unproductive loops.
#
# The original proposed state included:
#
# - Visible Grid
# - Score
# - Lives
# - Flags
# - Combo
# - Game Status (active/won/lost)
#
# The final implementation was updated to these:
#
# - **Visible Grid:** The board state.
# - **Lives:** Tracks how many lives are left in the episode.
# - **Combo:** Tracks the real-time combo in the run.
# - **Flags:** Tracks how many flags are left allowed to be place on the board.
# - **Progress:** Tracks the ratio of revealed safe tiles to the total number of safe tiles.
# - **Interaction History:** Encodes how recently the agent has interacted with each tiles. Basically a history of actions.

# %% [markdown]
# ## Simplified Reward Function ($R_t$)
#
# The initial reward function, tied to the complex in-game score, proved to be a noisy signal that limited the agent's performance (resulting in a 5-13% win rate). Therefore, it was replaced with a simplified, sparse reward function to provide a clearer learning objective.
#
# The new function is based on four simple rules:
#
# - **Win Bonus:** A large positive reward of **+100** is given when the agent successfully clears all non-mine tiles. This defines the ultimate goal.
# - **Loss Penalty:** A large negative penalty of **-100** is given when the agent loses its last life or runs out of time. This clearly punishes failure.
# - **Progress Reward:** A small positive reward of **+1 is given for each new safe tile** the agent successfully reveals in a single turn. This encourages the agent to explore and clear the board.
# - **Efficiency Penalty:** A tiny negative penalty of **-0.1 is applied for every action taken**. This incentivizes the agent to win in as few steps as possible.

# %%
from MC import MonteCarlo
import numpy as np

game = None
agent = None

def main():
    global SCREEN_WIDTH, SCREEN_HEIGHT, TILE_SIZE, screen, game, agent

    game = MinesweeperGame()
    agent = MonteCarlo(
        gridSize=GRID_SIZE,
        maxLives=LIVES,
        gameInstance=game,
        discountFactor=0.99,
        lr={
            0: 0.001,
            2000: 0.0005,
            5000: 0.0001,
        },
        epsilonStart=1.0,
        epsilonEnd=0.01,
        epsilonDecay=0.995
    )
    
    clock = pygame.time.Clock()
    running = True

    def clickHandler():
        mx, my = pygame.mouse.get_pos()
        gridX, gridY = get_tile_from_mouse(mx, my)
            
        if gridX is not None:
            if event.button == 1:
                game.reveal_tile(gridX, gridY)
            elif event.button == 3:
                game.toggle_flag(gridX, gridY)
        return

    def agentTurnLogic():
        global game, agent

        done = False
        elapsedTime = ((pygame.time.get_ticks() - game.start_time) / 1000)
        
        if not (game.game_over or game.game_won):
            
            stateCurrent = agent._encodeState()
            x, y, actionType, actionIdx, _ = agent.chooseAction(stateCurrent)
            
            agent.ACTION_HISTORY.append((x, y, actionType))
            if len(agent.ACTION_HISTORY) > agent.ACTION_HISTORY_SIZE:
                agent.ACTION_HISTORY.pop(0)
            
            agent.TILE_INTERACTION_HISTORY[(x, y)] = len(agent.ACTION_HISTORY)
            agent.LAST_ACTION = (x, y, actionType)
            
            livesOld = game.lives
            revealedOld = game.revealed_count
            reward = 0

            if actionType == 0:
                game.reveal_tile(x, y)
            else:
                game.toggle_flag(x, y)

            # Simplified Reward Calculation
            reward -= 0.1
            
            mine_hit = livesOld > game.lives
            if not mine_hit:
                newly_revealed = game.revealed_count - revealedOld
                if newly_revealed > 0:
                    reward += newly_revealed * 1.0

            done = game.game_over or game.game_won
            if done:
                if game.game_won:
                    reward += 100
                else:
                    reward += -100
            
            if len(agent.CLICKS["left"]) < agent.EPISODES:
                agent.CLICKS["left"].append(0)
                agent.CLICKS["right"].append(0)
                agent.CLICKS["total"].append(0)

            agent.CLICKS["total"][agent.EPISODES - 1] += 1
            if actionType == 0:
                agent.CLICKS["left"][agent.EPISODES - 1] += 1
            else:
                agent.CLICKS["right"][agent.EPISODES - 1] += 1

            if elapsedTime > 45:
                game.game_over = True
                done = True
                if not game.game_won:
                    reward = -100
                print(log("Game terminated: Time limit exceeded"))

            reward = np.clip(reward, -100, 100)
            
            # Store transition in episode memory (MC specific)
            agent.storeTransition(stateCurrent, actionIdx, reward)
            
            if agent.CLICKS["total"][agent.EPISODES - 1] % 10 == 0 or done:
                print(f"[Ep {agent.EPISODES}, Step {agent.CLICKS['total'][agent.EPISODES - 1]}] "
                    f"Score: {game.score} | Reward: {reward:.2f} | "
                    f"Epsilon: {agent.epsilon:.4f} | "
                    f"Action: ({x}, {y}) {'Reveal' if actionType == 0 else 'Flag'} | "
                    f"Revealed: {game.revealed_count}/{GRID_SIZE * GRID_SIZE - game.total_mines}")

        if game.game_over or game.game_won:
            # Train the agent on the complete episode (MC specific)
            loss = agent.train()
            
            draw_game(game, agent)
            pygame.display.flip()
            pygame.time.delay(1000)

            game = MinesweeperGame()
            agent.endEpisode(game)

            loss_str = f"{loss:.4f}" if loss is not None else "N/A"
            print(log(f"\n{'='*60}"))
            print(log(f"Episode {agent.EPISODES - 1} finished: {'WIN' if agent.GAME_CONCLUSIONS[-1] else 'LOSS'} | Score: {agent.SCORES[-1]} | Loss: {loss_str}"))
            print(log(agent.printMetrics(asString=True)))
            print(log(f"{'='*60}\n"))

        return done

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.VIDEORESIZE:
                SCREEN_WIDTH, SCREEN_HEIGHT = event.w, event.h
                screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT), pygame.RESIZABLE)
                
                AVAILABLE_HEIGHT = SCREEN_HEIGHT - 230
                AVAILABLE_WIDTH = SCREEN_WIDTH - 40
                TILE_SIZE = min(AVAILABLE_HEIGHT // GRID_SIZE, AVAILABLE_WIDTH // GRID_SIZE)
                
            elif event.type == pygame.MOUSEBUTTONDOWN:
                clickHandler()
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_r:
                    game = MinesweeperGame()

        if agent is not None:
            gameDone = agentTurnLogic()

            # Stop after 300 episodes
            if agent.EPISODES > 300 and gameDone:
                saveModel(MODEL_NAME, agent)
                running = False
                return

        mx, my = pygame.mouse.get_pos()
        hoverX, hoverY = get_tile_from_mouse(mx, my)
        for x in range(GRID_SIZE):
            for y in range(GRID_SIZE):
                game.grid[x][y].hover = (x == hoverX and y == hoverY)
        
        draw_game(game, agent)
        pygame.display.flip()
        clock.tick(60)

    if AUTO_QUIT:
        pygame.quit()

if __name__ == "__main__":
    main()
# Out:
# [Ep 1, Step 10] Score: 2752 | Reward: -0.10 | Epsilon: 1.0000 | Action: (7, 4) Flag | Revealed: 50/59
# [Ep 1, Step 20] Score: 2812 | Reward: -0.10 | Epsilon: 1.0000 | Action: (6, 4) Reveal | Revealed: 53/59
# [Ep 1, Step 30] Score: 2832 | Reward: -0.10 | Epsilon: 1.0000 | Action: (6, 2) Flag | Revealed: 57/59
# [Ep 1, Step 31] Score: 2832 | Reward: -100.00 | Epsilon: 1.0000 | Action: (6, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 1 finished: LOSS | Score: 2832 | Loss: 1.2244
# Episodes: 1 | Win Rate: 0.00% | Highest Score: 2832.00 | Time Efficiency: 5.21 steps/sec | Left Click Avg: 14.00 c/g (2.35 c/s) | Right Click Avg: 17.00 c/g (2.86 c/s) | Total Click Avg: 31.00 c/g (5.21 c/s) | Game Conclusion History: 0 Wins, 1 Losses
# ============================================================
#
# [Ep 2, Step 10] Score: 1640 | Reward: -0.10 | Epsilon: 0.9950 | Action: (2, 3) Flag | Revealed: 46/59
# [Ep 2, Step 20] Score: 1715 | Reward: 0.90 | Epsilon: 0.9950 | Action: (3, 7) Reveal | Revealed: 51/59
# [Ep 2, Step 30] Score: 1765 | Reward: -0.10 | Epsilon: 0.9950 | Action: (3, 4) Flag | Revealed: 57/59
# [Ep 2, Step 40] Score: 1790 | Reward: -0.10 | Epsilon: 0.9950 | Action: (2, 5) Flag | Revealed: 59/59
# [Ep 2, Step 41] Score: 1790 | Reward: -100.00 | Epsilon: 0.9950 | Action: (3, 4) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 2 finished: LOSS | Score: 1790 | Loss: 1.0688
# Episodes: 2 | Win Rate: 0.00% | Highest Score: 2832.00 | Time Efficiency: 6.35 steps/sec | Left Click Avg: 16.50 c/g (2.91 c/s) | Right Click Avg: 19.50 c/g (3.44 c/s) | Total Click Avg: 36.00 c/g (6.35 c/s) | Game Conclusion History: 0 Wins, 2 Losses
# ============================================================
#
# [Ep 3, Step 10] Score: 2617 | Reward: -0.10 | Epsilon: 0.9900 | Action: (7, 4) Flag | Revealed: 49/59
# [Ep 3, Step 20] Score: 2642 | Reward: 1.90 | Epsilon: 0.9900 | Action: (7, 0) Reveal | Revealed: 53/59
# [Ep 3, Step 28] Score: 2727 | Reward: -100.00 | Epsilon: 0.9900 | Action: (7, 2) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 3 finished: LOSS | Score: 2727 | Loss: 1.0708
# Episodes: 3 | Win Rate: 0.00% | Highest Score: 2832.00 | Time Efficiency: 6.79 steps/sec | Left Click Avg: 14.33 c/g (2.92 c/s) | Right Click Avg: 19.00 c/g (3.87 c/s) | Total Click Avg: 33.33 c/g (6.79 c/s) | Game Conclusion History: 0 Wins, 3 Losses
# ============================================================
#
# [Ep 4, Step 10] Score: 2260 | Reward: -0.10 | Epsilon: 0.9851 | Action: (3, 6) Flag | Revealed: 56/59
# [Ep 4, Step 18] Score: 3426 | Reward: 100.00 | Epsilon: 0.9851 | Action: (7, 1) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 4 finished: WIN | Score: 3426 | Loss: 0.8475
# Episodes: 4 | Win Rate: 25.00% | Highest Score: 3426.00 | Time Efficiency: 6.79 steps/sec | Left Click Avg: 13.00 c/g (2.99 c/s) | Right Click Avg: 16.50 c/g (3.80 c/s) | Total Click Avg: 29.50 c/g (6.79 c/s) | Game Conclusion History: 1 Wins, 3 Losses
# ============================================================
#
# [Ep 5, Step 9] Score: 3667 | Reward: -100.00 | Epsilon: 0.9801 | Action: (2, 6) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 5 finished: LOSS | Score: 3667 | Loss: 1.4030
# Episodes: 5 | Win Rate: 20.00% | Highest Score: 3667.00 | Time Efficiency: 6.61 steps/sec | Left Click Avg: 11.80 c/g (3.07 c/s) | Right Click Avg: 13.60 c/g (3.54 c/s) | Total Click Avg: 25.40 c/g (6.61 c/s) | Game Conclusion History: 1 Wins, 4 Losses
# ============================================================
#
# [Ep 6, Step 10] Score: 2032 | Reward: -0.10 | Epsilon: 0.9752 | Action: (5, 7) Flag | Revealed: 53/59
# [Ep 6, Step 20] Score: 2002 | Reward: 0.90 | Epsilon: 0.9752 | Action: (0, 1) Reveal | Revealed: 57/59
# [Ep 6, Step 28] Score: 1962 | Reward: -100.00 | Epsilon: 0.9752 | Action: (2, 2) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 6 finished: LOSS | Score: 1962 | Loss: 0.9348
# Episodes: 6 | Win Rate: 16.67% | Highest Score: 3667.00 | Time Efficiency: 6.14 steps/sec | Left Click Avg: 11.50 c/g (2.73 c/s) | Right Click Avg: 14.33 c/g (3.41 c/s) | Total Click Avg: 25.83 c/g (6.14 c/s) | Game Conclusion History: 1 Wins, 5 Losses
# ============================================================
#
# [Ep 7, Step 10] Score: 3525 | Reward: -0.10 | Epsilon: 0.9704 | Action: (7, 1) Flag | Revealed: 55/59
# [Ep 7, Step 20] Score: 3480 | Reward: -100.00 | Epsilon: 0.9704 | Action: (7, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 7 finished: LOSS | Score: 3480 | Loss: 0.3392
# Episodes: 7 | Win Rate: 14.29% | Highest Score: 3667.00 | Time Efficiency: 6.01 steps/sec | Left Click Avg: 10.71 c/g (2.58 c/s) | Right Click Avg: 14.29 c/g (3.43 c/s) | Total Click Avg: 25.00 c/g (6.01 c/s) | Game Conclusion History: 1 Wins, 6 Losses
# ============================================================
#
# [Ep 8, Step 10] Score: 2139 | Reward: 0.90 | Epsilon: 0.9655 | Action: (2, 2) Reveal | Revealed: 58/59
# [Ep 8, Step 20] Score: 2154 | Reward: -0.10 | Epsilon: 0.9655 | Action: (3, 7) Flag | Revealed: 59/59
# [Ep 8, Step 22] Score: 2154 | Reward: -100.00 | Epsilon: 0.9655 | Action: (4, 3) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 8 finished: LOSS | Score: 2154 | Loss: 1.7603
# Episodes: 8 | Win Rate: 12.50% | Highest Score: 3667.00 | Time Efficiency: 5.69 steps/sec | Left Click Avg: 10.38 c/g (2.40 c/s) | Right Click Avg: 14.25 c/g (3.29 c/s) | Total Click Avg: 24.62 c/g (5.69 c/s) | Game Conclusion History: 1 Wins, 7 Losses
# ============================================================
#
# [Ep 9, Step 10] Score: 3307 | Reward: -0.10 | Epsilon: 0.9607 | Action: (7, 3) Flag | Revealed: 56/59
# [Ep 9, Step 18] Score: 3367 | Reward: -100.00 | Epsilon: 0.9607 | Action: (7, 3) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 9 finished: LOSS | Score: 3367 | Loss: 1.3200
# Episodes: 9 | Win Rate: 11.11% | Highest Score: 3667.00 | Time Efficiency: 5.58 steps/sec | Left Click Avg: 10.00 c/g (2.33 c/s) | Right Click Avg: 13.89 c/g (3.24 c/s) | Total Click Avg: 23.89 c/g (5.58 c/s) | Game Conclusion History: 1 Wins, 8 Losses
# ============================================================
#
# [Ep 10, Step 10] Score: 2960 | Reward: 0.90 | Epsilon: 0.9559 | Action: (5, 2) Reveal | Revealed: 52/59
# [Ep 10, Step 19] Score: 2865 | Reward: -100.00 | Epsilon: 0.9559 | Action: (6, 2) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 10 finished: LOSS | Score: 2865 | Loss: 0.8571
# Episodes: 10 | Win Rate: 10.00% | Highest Score: 3667.00 | Time Efficiency: 5.58 steps/sec | Left Click Avg: 9.80 c/g (2.34 c/s) | Right Click Avg: 13.60 c/g (3.24 c/s) | Total Click Avg: 23.40 c/g (5.58 c/s) | Game Conclusion History: 1 Wins, 9 Losses
# ============================================================
#
# [Ep 11, Step 10] Score: 2355 | Reward: 43.90 | Epsilon: 0.9511 | Action: (0, 1) Reveal | Revealed: 48/59
# [Ep 11, Step 16] Score: 2360 | Reward: -100.00 | Epsilon: 0.9511 | Action: (0, 6) Reveal | Revealed: 52/59
#
# ============================================================
# Episode 11 finished: LOSS | Score: 2360 | Loss: 1.4131
# Episodes: 11 | Win Rate: 9.09% | Highest Score: 3667.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 9.73 c/g (2.37 c/s) | Right Click Avg: 13.00 c/g (3.17 c/s) | Total Click Avg: 22.73 c/g (5.54 c/s) | Game Conclusion History: 1 Wins, 10 Losses
# ============================================================
#
# [Ep 12, Step 10] Score: 3322 | Reward: 0.90 | Epsilon: 0.9464 | Action: (2, 5) Reveal | Revealed: 57/59
# [Ep 12, Step 17] Score: 3377 | Reward: -100.00 | Epsilon: 0.9464 | Action: (0, 3) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 12 finished: LOSS | Score: 3377 | Loss: 1.3228
# Episodes: 12 | Win Rate: 8.33% | Highest Score: 3667.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 9.58 c/g (2.39 c/s) | Right Click Avg: 12.67 c/g (3.15 c/s) | Total Click Avg: 22.25 c/g (5.54 c/s) | Game Conclusion History: 1 Wins, 11 Losses
# ============================================================
#
# [Ep 13, Step 10] Score: 3196 | Reward: -0.10 | Epsilon: 0.9416 | Action: (0, 5) Flag | Revealed: 52/59
# [Ep 13, Step 20] Score: 3256 | Reward: -100.00 | Epsilon: 0.9416 | Action: (4, 2) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 13 finished: LOSS | Score: 3256 | Loss: 0.8637
# Episodes: 13 | Win Rate: 7.69% | Highest Score: 3667.00 | Time Efficiency: 5.59 steps/sec | Left Click Avg: 9.38 c/g (2.38 c/s) | Right Click Avg: 12.69 c/g (3.21 c/s) | Total Click Avg: 22.08 c/g (5.59 c/s) | Game Conclusion History: 1 Wins, 12 Losses
# ============================================================
#
# [Ep 14, Step 8] Score: 0 | Reward: -100.00 | Epsilon: 0.9369 | Action: (4, 0) Reveal | Revealed: 3/59
#
# ============================================================
# Episode 14 finished: LOSS | Score: 0 | Loss: 2.8965
# Episodes: 14 | Win Rate: 7.14% | Highest Score: 3667.00 | Time Efficiency: 5.54 steps/sec | Left Click Avg: 8.93 c/g (2.35 c/s) | Right Click Avg: 12.14 c/g (3.19 c/s) | Total Click Avg: 21.07 c/g (5.54 c/s) | Game Conclusion History: 1 Wins, 13 Losses
# ============================================================
#
# [Ep 15, Step 10] Score: 3171 | Reward: -0.10 | Epsilon: 0.9322 | Action: (3, 3) Flag | Revealed: 52/59
# [Ep 15, Step 20] Score: 3336 | Reward: -0.10 | Epsilon: 0.9322 | Action: (1, 1) Flag | Revealed: 55/59
# [Ep 15, Step 30] Score: 3261 | Reward: 0.90 | Epsilon: 0.9322 | Action: (5, 2) Reveal | Revealed: 60/59
# [Ep 15, Step 37] Score: 4506 | Reward: 100.00 | Epsilon: 0.9322 | Action: (1, 1) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 15 finished: WIN | Score: 4506 | Loss: 0.8146
# Episodes: 15 | Win Rate: 13.33% | Highest Score: 4506.00 | Time Efficiency: 5.57 steps/sec | Left Click Avg: 9.20 c/g (2.32 c/s) | Right Click Avg: 12.93 c/g (3.25 c/s) | Total Click Avg: 22.13 c/g (5.57 c/s) | Game Conclusion History: 2 Wins, 13 Losses
# ============================================================
#
# [Ep 16, Step 10] Score: 3332 | Reward: -0.10 | Epsilon: 0.9276 | Action: (7, 6) Flag | Revealed: 55/59
# [Ep 16, Step 19] Score: 3397 | Reward: -100.00 | Epsilon: 0.9276 | Action: (0, 0) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 16 finished: LOSS | Score: 3397 | Loss: 1.0980
# Episodes: 16 | Win Rate: 12.50% | Highest Score: 4506.00 | Time Efficiency: 5.60 steps/sec | Left Click Avg: 8.94 c/g (2.28 c/s) | Right Click Avg: 13.00 c/g (3.32 c/s) | Total Click Avg: 21.94 c/g (5.60 c/s) | Game Conclusion History: 2 Wins, 14 Losses
# ============================================================
#
# [Ep 17, Step 10] Score: 1006 | Reward: -0.10 | Epsilon: 0.9229 | Action: (3, 2) Flag | Revealed: 30/59
# [Ep 17, Step 17] Score: 1672 | Reward: -100.00 | Epsilon: 0.9229 | Action: (6, 5) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 17 finished: LOSS | Score: 1672 | Loss: 0.8588
# Episodes: 17 | Win Rate: 11.76% | Highest Score: 4506.00 | Time Efficiency: 5.63 steps/sec | Left Click Avg: 9.00 c/g (2.34 c/s) | Right Click Avg: 12.65 c/g (3.29 c/s) | Total Click Avg: 21.65 c/g (5.63 c/s) | Game Conclusion History: 2 Wins, 15 Losses
# ============================================================
#
# [Ep 18, Step 10] Score: 472 | Reward: -0.10 | Epsilon: 0.9183 | Action: (3, 0) Flag | Revealed: 19/59
# [Ep 18, Step 20] Score: 1759 | Reward: -0.10 | Epsilon: 0.9183 | Action: (2, 6) Reveal | Revealed: 53/59
# [Ep 18, Step 30] Score: 1734 | Reward: -0.10 | Epsilon: 0.9183 | Action: (0, 0) Flag | Revealed: 56/59
# [Ep 18, Step 32] Score: 1734 | Reward: -100.00 | Epsilon: 0.9183 | Action: (2, 1) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 18 finished: LOSS | Score: 1734 | Loss: 1.2560
# Episodes: 18 | Win Rate: 11.11% | Highest Score: 4506.00 | Time Efficiency: 5.63 steps/sec | Left Click Avg: 9.33 c/g (2.36 c/s) | Right Click Avg: 12.89 c/g (3.26 c/s) | Total Click Avg: 22.22 c/g (5.63 c/s) | Game Conclusion History: 2 Wins, 16 Losses
# ============================================================
#
# [Ep 19, Step 10] Score: 3226 | Reward: 0.90 | Epsilon: 0.9137 | Action: (6, 7) Reveal | Revealed: 56/59
# [Ep 19, Step 13] Score: 3226 | Reward: -100.00 | Epsilon: 0.9137 | Action: (6, 6) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 19 finished: LOSS | Score: 3226 | Loss: 0.9587
# Episodes: 19 | Win Rate: 10.53% | Highest Score: 4506.00 | Time Efficiency: 5.62 steps/sec | Left Click Avg: 9.16 c/g (2.37 c/s) | Right Click Avg: 12.58 c/g (3.26 c/s) | Total Click Avg: 21.74 c/g (5.62 c/s) | Game Conclusion History: 2 Wins, 17 Losses
# ============================================================
#
# [Ep 20, Step 10] Score: 1952 | Reward: -0.10 | Epsilon: 0.9092 | Action: (0, 5) Flag | Revealed: 54/59
# [Ep 20, Step 20] Score: 2022 | Reward: -0.10 | Epsilon: 0.9092 | Action: (4, 5) Reveal | Revealed: 58/59
# [Ep 20, Step 23] Score: 4483 | Reward: 100.00 | Epsilon: 0.9092 | Action: (6, 6) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 20 finished: WIN | Score: 4483 | Loss: 1.4224
# Episodes: 20 | Win Rate: 15.00% | Highest Score: 4506.00 | Time Efficiency: 5.68 steps/sec | Left Click Avg: 9.10 c/g (2.37 c/s) | Right Click Avg: 12.70 c/g (3.31 c/s) | Total Click Avg: 21.80 c/g (5.68 c/s) | Game Conclusion History: 3 Wins, 17 Losses
# ============================================================
#
# [Ep 21, Step 10] Score: 3712 | Reward: 0.90 | Epsilon: 0.9046 | Action: (1, 2) Reveal | Revealed: 57/59
# [Ep 21, Step 20] Score: 3762 | Reward: -0.10 | Epsilon: 0.9046 | Action: (0, 3) Flag | Revealed: 59/59
# [Ep 21, Step 27] Score: 3722 | Reward: -100.00 | Epsilon: 0.9046 | Action: (0, 4) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 21 finished: LOSS | Score: 3722 | Loss: 0.8866
# Episodes: 21 | Win Rate: 14.29% | Highest Score: 4506.00 | Time Efficiency: 5.75 steps/sec | Left Click Avg: 8.95 c/g (2.34 c/s) | Right Click Avg: 13.10 c/g (3.42 c/s) | Total Click Avg: 22.05 c/g (5.75 c/s) | Game Conclusion History: 3 Wins, 18 Losses
# ============================================================
#
# [Ep 22, Step 10] Score: 1711 | Reward: 0.90 | Epsilon: 0.9001 | Action: (6, 6) Reveal | Revealed: 40/59
# [Ep 22, Step 20] Score: 1997 | Reward: -0.10 | Epsilon: 0.9001 | Action: (6, 4) Flag | Revealed: 53/59
# [Ep 22, Step 30] Score: 1962 | Reward: -0.10 | Epsilon: 0.9001 | Action: (6, 4) Flag | Revealed: 57/59
# [Ep 22, Step 31] Score: 1962 | Reward: -100.00 | Epsilon: 0.9001 | Action: (5, 7) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 22 finished: LOSS | Score: 1962 | Loss: 0.8558
# Episodes: 22 | Win Rate: 13.64% | Highest Score: 4506.00 | Time Efficiency: 5.80 steps/sec | Left Click Avg: 9.23 c/g (2.38 c/s) | Right Click Avg: 13.23 c/g (3.42 c/s) | Total Click Avg: 22.45 c/g (5.80 c/s) | Game Conclusion History: 3 Wins, 19 Losses
# ============================================================
#
# [Ep 23, Step 10] Score: 1712 | Reward: 29.90 | Epsilon: 0.8956 | Action: (4, 5) Reveal | Revealed: 52/59
# [Ep 23, Step 20] Score: 1832 | Reward: 0.90 | Epsilon: 0.8956 | Action: (5, 2) Reveal | Revealed: 54/59
# [Ep 23, Step 30] Score: 1862 | Reward: -0.10 | Epsilon: 0.8956 | Action: (4, 4) Flag | Revealed: 59/59
# [Ep 23, Step 32] Score: 3212 | Reward: 100.00 | Epsilon: 0.8956 | Action: (4, 4) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 23 finished: WIN | Score: 3212 | Loss: 1.0868
# Episodes: 23 | Win Rate: 17.39% | Highest Score: 4506.00 | Time Efficiency: 5.86 steps/sec | Left Click Avg: 9.35 c/g (2.40 c/s) | Right Click Avg: 13.52 c/g (3.47 c/s) | Total Click Avg: 22.87 c/g (5.86 c/s) | Game Conclusion History: 4 Wins, 19 Losses
# ============================================================
#
# [Ep 24, Step 8] Score: 2191 | Reward: -100.00 | Epsilon: 0.8911 | Action: (3, 5) Reveal | Revealed: 46/59
#
# ============================================================
# Episode 24 finished: LOSS | Score: 2191 | Loss: 1.0049
# Episodes: 24 | Win Rate: 16.67% | Highest Score: 4506.00 | Time Efficiency: 5.82 steps/sec | Left Click Avg: 9.17 c/g (2.40 c/s) | Right Click Avg: 13.08 c/g (3.42 c/s) | Total Click Avg: 22.25 c/g (5.82 c/s) | Game Conclusion History: 4 Wins, 20 Losses
# ============================================================
#
# [Ep 25, Step 10] Score: 3680 | Reward: -0.10 | Epsilon: 0.8867 | Action: (6, 3) Flag | Revealed: 58/59
# [Ep 25, Step 17] Score: 4879 | Reward: 100.00 | Epsilon: 0.8867 | Action: (7, 3) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 25 finished: WIN | Score: 4879 | Loss: 1.2161
# Episodes: 25 | Win Rate: 20.00% | Highest Score: 4879.00 | Time Efficiency: 5.78 steps/sec | Left Click Avg: 9.08 c/g (2.38 c/s) | Right Click Avg: 12.96 c/g (3.40 c/s) | Total Click Avg: 22.04 c/g (5.78 c/s) | Game Conclusion History: 5 Wins, 20 Losses
# ============================================================
#
# [Ep 26, Step 10] Score: 2621 | Reward: 0.90 | Epsilon: 0.8822 | Action: (7, 3) Reveal | Revealed: 52/59
# [Ep 26, Step 20] Score: 2686 | Reward: 0.90 | Epsilon: 0.8822 | Action: (0, 4) Reveal | Revealed: 55/59
# [Ep 26, Step 30] Score: 2776 | Reward: -0.10 | Epsilon: 0.8822 | Action: (6, 3) Reveal | Revealed: 60/59
# [Ep 26, Step 32] Score: 2726 | Reward: -100.00 | Epsilon: 0.8822 | Action: (6, 5) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 26 finished: LOSS | Score: 2726 | Loss: 0.9417
# Episodes: 26 | Win Rate: 19.23% | Highest Score: 4879.00 | Time Efficiency: 5.79 steps/sec | Left Click Avg: 9.35 c/g (2.41 c/s) | Right Click Avg: 13.08 c/g (3.38 c/s) | Total Click Avg: 22.42 c/g (5.79 c/s) | Game Conclusion History: 5 Wins, 21 Losses
# ============================================================
#
# [Ep 27, Step 10] Score: 3550 | Reward: -0.10 | Epsilon: 0.8778 | Action: (1, 4) Reveal | Revealed: 58/59
# [Ep 27, Step 19] Score: 3565 | Reward: -100.00 | Epsilon: 0.8778 | Action: (7, 7) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 27 finished: LOSS | Score: 3565 | Loss: 2.8479
# Episodes: 27 | Win Rate: 18.52% | Highest Score: 4879.00 | Time Efficiency: 5.75 steps/sec | Left Click Avg: 9.33 c/g (2.41 c/s) | Right Click Avg: 12.96 c/g (3.35 c/s) | Total Click Avg: 22.30 c/g (5.75 c/s) | Game Conclusion History: 5 Wins, 22 Losses
# ============================================================
#
# [Ep 28, Step 10] Score: 2597 | Reward: -0.10 | Epsilon: 0.8734 | Action: (1, 0) Flag | Revealed: 48/59
# [Ep 28, Step 20] Score: 2617 | Reward: 0.90 | Epsilon: 0.8734 | Action: (2, 1) Reveal | Revealed: 52/59
# [Ep 28, Step 29] Score: 2577 | Reward: -100.00 | Epsilon: 0.8734 | Action: (0, 2) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 28 finished: LOSS | Score: 2577 | Loss: 0.6153
# Episodes: 28 | Win Rate: 17.86% | Highest Score: 4879.00 | Time Efficiency: 5.76 steps/sec | Left Click Avg: 9.36 c/g (2.39 c/s) | Right Click Avg: 13.18 c/g (3.37 c/s) | Total Click Avg: 22.54 c/g (5.76 c/s) | Game Conclusion History: 5 Wins, 23 Losses
# ============================================================
#
# [Ep 29, Step 10] Score: 3207 | Reward: 0.90 | Epsilon: 0.8691 | Action: (6, 4) Reveal | Revealed: 54/59
# [Ep 29, Step 19] Score: 3137 | Reward: -100.00 | Epsilon: 0.8691 | Action: (5, 4) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 29 finished: LOSS | Score: 3137 | Loss: 1.5935
# Episodes: 29 | Win Rate: 17.24% | Highest Score: 4879.00 | Time Efficiency: 5.77 steps/sec | Left Click Avg: 9.41 c/g (2.42 c/s) | Right Click Avg: 13.00 c/g (3.35 c/s) | Total Click Avg: 22.41 c/g (5.77 c/s) | Game Conclusion History: 5 Wins, 24 Losses
# ============================================================
#
# [Ep 30, Step 10] Score: 3302 | Reward: -0.10 | Epsilon: 0.8647 | Action: (5, 3) Flag | Revealed: 57/59
# [Ep 30, Step 11] Score: 3302 | Reward: -100.00 | Epsilon: 0.8647 | Action: (5, 2) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 30 finished: LOSS | Score: 3302 | Loss: 2.2220
# Episodes: 30 | Win Rate: 16.67% | Highest Score: 4879.00 | Time Efficiency: 5.76 steps/sec | Left Click Avg: 9.33 c/g (2.44 c/s) | Right Click Avg: 12.70 c/g (3.32 c/s) | Total Click Avg: 22.03 c/g (5.76 c/s) | Game Conclusion History: 5 Wins, 25 Losses
# ============================================================
#
# [Ep 31, Step 10] Score: 1622 | Reward: -0.10 | Epsilon: 0.8604 | Action: (6, 0) Flag | Revealed: 40/59
# [Ep 31, Step 16] Score: 1843 | Reward: -100.00 | Epsilon: 0.8604 | Action: (0, 0) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 31 finished: LOSS | Score: 1843 | Loss: 0.8387
# Episodes: 31 | Win Rate: 16.13% | Highest Score: 4879.00 | Time Efficiency: 5.77 steps/sec | Left Click Avg: 9.29 c/g (2.46 c/s) | Right Click Avg: 12.55 c/g (3.32 c/s) | Total Click Avg: 21.84 c/g (5.77 c/s) | Game Conclusion History: 5 Wins, 26 Losses
# ============================================================
#
# [Ep 32, Step 10] Score: 2022 | Reward: -0.10 | Epsilon: 0.8561 | Action: (2, 0) Flag | Revealed: 48/59
# [Ep 32, Step 20] Score: 2027 | Reward: -0.10 | Epsilon: 0.8561 | Action: (4, 0) Flag | Revealed: 49/59
# [Ep 32, Step 30] Score: 2097 | Reward: -0.10 | Epsilon: 0.8561 | Action: (4, 2) Flag | Revealed: 52/59
# [Ep 32, Step 40] Score: 2037 | Reward: 0.90 | Epsilon: 0.8561 | Action: (3, 2) Reveal | Revealed: 59/59
# [Ep 32, Step 50] Score: 1987 | Reward: -0.10 | Epsilon: 0.8561 | Action: (5, 3) Flag | Revealed: 59/59
# [Ep 32, Step 60] Score: 2137 | Reward: -0.10 | Epsilon: 0.8561 | Action: (5, 3) Flag | Revealed: 59/59
# [Ep 32, Step 69] Score: 2047 | Reward: -100.00 | Epsilon: 0.8561 | Action: (5, 3) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 32 finished: LOSS | Score: 2047 | Loss: 0.8311
# Episodes: 32 | Win Rate: 15.62% | Highest Score: 4879.00 | Time Efficiency: 5.94 steps/sec | Left Click Avg: 9.53 c/g (2.43 c/s) | Right Click Avg: 13.78 c/g (3.51 c/s) | Total Click Avg: 23.31 c/g (5.94 c/s) | Game Conclusion History: 5 Wins, 27 Losses
# ============================================================
#
# [Ep 33, Step 10] Score: 1637 | Reward: 21.90 | Epsilon: 0.8518 | Action: (4, 6) Reveal | Revealed: 49/59
# [Ep 33, Step 18] Score: 1592 | Reward: -100.00 | Epsilon: 0.8518 | Action: (2, 5) Reveal | Revealed: 53/59
#
# ============================================================
# Episode 33 finished: LOSS | Score: 1592 | Loss: 0.7069
# Episodes: 33 | Win Rate: 15.15% | Highest Score: 4879.00 | Time Efficiency: 5.93 steps/sec | Left Click Avg: 9.52 c/g (2.44 c/s) | Right Click Avg: 13.64 c/g (3.50 c/s) | Total Click Avg: 23.15 c/g (5.93 c/s) | Game Conclusion History: 5 Wins, 28 Losses
# ============================================================
#
# [Ep 34, Step 10] Score: 2320 | Reward: -0.10 | Epsilon: 0.8475 | Action: (1, 0) Flag | Revealed: 47/59
# [Ep 34, Step 17] Score: 2335 | Reward: -100.00 | Epsilon: 0.8475 | Action: (4, 2) Reveal | Revealed: 53/59
#
# ============================================================
# Episode 34 finished: LOSS | Score: 2335 | Loss: 1.7708
# Episodes: 34 | Win Rate: 14.71% | Highest Score: 4879.00 | Time Efficiency: 5.95 steps/sec | Left Click Avg: 9.56 c/g (2.47 c/s) | Right Click Avg: 13.41 c/g (3.47 c/s) | Total Click Avg: 22.97 c/g (5.95 c/s) | Game Conclusion History: 5 Wins, 29 Losses
# ============================================================
#
# [Ep 35, Step 10] Score: 2900 | Reward: -0.10 | Epsilon: 0.8433 | Action: (7, 0) Reveal | Revealed: 50/59
# [Ep 35, Step 20] Score: 2865 | Reward: 0.90 | Epsilon: 0.8433 | Action: (7, 4) Reveal | Revealed: 54/59
# [Ep 35, Step 21] Score: 2865 | Reward: -100.00 | Epsilon: 0.8433 | Action: (4, 0) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 35 finished: LOSS | Score: 2865 | Loss: 0.8732
# Episodes: 35 | Win Rate: 14.29% | Highest Score: 4879.00 | Time Efficiency: 5.97 steps/sec | Left Click Avg: 9.51 c/g (2.48 c/s) | Right Click Avg: 13.40 c/g (3.49 c/s) | Total Click Avg: 22.91 c/g (5.97 c/s) | Game Conclusion History: 5 Wins, 30 Losses
# ============================================================
#
# [Ep 36, Step 8] Score: 3642 | Reward: -100.00 | Epsilon: 0.8391 | Action: (0, 5) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 36 finished: LOSS | Score: 3642 | Loss: 0.8803
# Episodes: 36 | Win Rate: 13.89% | Highest Score: 4879.00 | Time Efficiency: 5.95 steps/sec | Left Click Avg: 9.39 c/g (2.48 c/s) | Right Click Avg: 13.11 c/g (3.47 c/s) | Total Click Avg: 22.50 c/g (5.95 c/s) | Game Conclusion History: 5 Wins, 31 Losses
# ============================================================
#
# [Ep 37, Step 10] Score: 3067 | Reward: -0.10 | Epsilon: 0.8349 | Action: (6, 1) Reveal | Revealed: 54/59
# [Ep 37, Step 11] Score: 3067 | Reward: -100.00 | Epsilon: 0.8349 | Action: (5, 0) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 37 finished: LOSS | Score: 3067 | Loss: 4.2245
# Episodes: 37 | Win Rate: 13.51% | Highest Score: 4879.00 | Time Efficiency: 5.94 steps/sec | Left Click Avg: 9.32 c/g (2.50 c/s) | Right Click Avg: 12.86 c/g (3.45 c/s) | Total Click Avg: 22.19 c/g (5.94 c/s) | Game Conclusion History: 5 Wins, 32 Losses
# ============================================================
#
# [Ep 38, Step 10] Score: 3465 | Reward: -0.10 | Epsilon: 0.8307 | Action: (2, 6) Flag | Revealed: 57/59
# [Ep 38, Step 20] Score: 3425 | Reward: -0.10 | Epsilon: 0.8307 | Action: (2, 6) Flag | Revealed: 59/59
# [Ep 38, Step 22] Score: 3425 | Reward: -100.00 | Epsilon: 0.8307 | Action: (7, 0) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 38 finished: LOSS | Score: 3425 | Loss: 1.4136
# Episodes: 38 | Win Rate: 13.16% | Highest Score: 4879.00 | Time Efficiency: 5.96 steps/sec | Left Click Avg: 9.29 c/g (2.50 c/s) | Right Click Avg: 12.89 c/g (3.46 c/s) | Total Click Avg: 22.18 c/g (5.96 c/s) | Game Conclusion History: 5 Wins, 33 Losses
# ============================================================
#
# [Ep 39, Step 9] Score: 5169 | Reward: 100.00 | Epsilon: 0.8266 | Action: (0, 1) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 39 finished: WIN | Score: 5169 | Loss: 0.6439
# Episodes: 39 | Win Rate: 15.38% | Highest Score: 5169.00 | Time Efficiency: 5.93 steps/sec | Left Click Avg: 9.15 c/g (2.49 c/s) | Right Click Avg: 12.69 c/g (3.45 c/s) | Total Click Avg: 21.85 c/g (5.93 c/s) | Game Conclusion History: 6 Wins, 33 Losses
# ============================================================
#
# [Ep 40, Step 10] Score: 2995 | Reward: 0.90 | Epsilon: 0.8224 | Action: (0, 4) Reveal | Revealed: 53/59
# [Ep 40, Step 20] Score: 3015 | Reward: -100.00 | Epsilon: 0.8224 | Action: (0, 6) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 40 finished: LOSS | Score: 3015 | Loss: 1.0173
# Episodes: 40 | Win Rate: 15.00% | Highest Score: 5169.00 | Time Efficiency: 5.94 steps/sec | Left Click Avg: 9.15 c/g (2.50 c/s) | Right Click Avg: 12.65 c/g (3.45 c/s) | Total Click Avg: 21.80 c/g (5.94 c/s) | Game Conclusion History: 6 Wins, 34 Losses
# ============================================================
#
# [Ep 41, Step 10] Score: 2151 | Reward: -0.10 | Epsilon: 0.8183 | Action: (7, 3) Reveal | Revealed: 44/59
# [Ep 41, Step 20] Score: 2226 | Reward: -0.10 | Epsilon: 0.8183 | Action: (3, 0) Flag | Revealed: 54/59
# [Ep 41, Step 27] Score: 2226 | Reward: -100.00 | Epsilon: 0.8183 | Action: (3, 3) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 41 finished: LOSS | Score: 2226 | Loss: 1.0913
# Episodes: 41 | Win Rate: 14.63% | Highest Score: 5169.00 | Time Efficiency: 5.98 steps/sec | Left Click Avg: 9.17 c/g (2.50 c/s) | Right Click Avg: 12.76 c/g (3.48 c/s) | Total Click Avg: 21.93 c/g (5.98 c/s) | Game Conclusion History: 6 Wins, 35 Losses
# ============================================================
#
# [Ep 42, Step 10] Score: 3137 | Reward: 0.90 | Epsilon: 0.8142 | Action: (0, 2) Reveal | Revealed: 53/59
# [Ep 42, Step 20] Score: 3187 | Reward: -0.10 | Epsilon: 0.8142 | Action: (0, 0) Flag | Revealed: 53/59
# [Ep 42, Step 30] Score: 3147 | Reward: -0.10 | Epsilon: 0.8142 | Action: (0, 0) Flag | Revealed: 54/59
# [Ep 42, Step 40] Score: 3107 | Reward: 0.90 | Epsilon: 0.8142 | Action: (7, 6) Reveal | Revealed: 57/59
# [Ep 42, Step 41] Score: 3107 | Reward: -100.00 | Epsilon: 0.8142 | Action: (6, 6) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 42 finished: LOSS | Score: 3107 | Loss: 0.8198
# Episodes: 42 | Win Rate: 14.29% | Highest Score: 5169.00 | Time Efficiency: 6.04 steps/sec | Left Click Avg: 9.21 c/g (2.49 c/s) | Right Click Avg: 13.17 c/g (3.55 c/s) | Total Click Avg: 22.38 c/g (6.04 c/s) | Game Conclusion History: 6 Wins, 36 Losses
# ============================================================
#
# [Ep 43, Step 10] Score: 2440 | Reward: -0.10 | Epsilon: 0.8102 | Action: (0, 3) Reveal | Revealed: 47/59
# [Ep 43, Step 17] Score: 2580 | Reward: -100.00 | Epsilon: 0.8102 | Action: (2, 0) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 43 finished: LOSS | Score: 2580 | Loss: 1.2988
# Episodes: 43 | Win Rate: 13.95% | Highest Score: 5169.00 | Time Efficiency: 6.03 steps/sec | Left Click Avg: 9.23 c/g (2.50 c/s) | Right Click Avg: 13.02 c/g (3.53 c/s) | Total Click Avg: 22.26 c/g (6.03 c/s) | Game Conclusion History: 6 Wins, 37 Losses
# ============================================================
#
# [Ep 44, Step 10] Score: 2262 | Reward: -0.10 | Epsilon: 0.8061 | Action: (7, 4) Flag | Revealed: 44/59
# [Ep 44, Step 20] Score: 2357 | Reward: -0.10 | Epsilon: 0.8061 | Action: (2, 1) Flag | Revealed: 50/59
# [Ep 44, Step 30] Score: 2377 | Reward: -0.10 | Epsilon: 0.8061 | Action: (1, 3) Flag | Revealed: 52/59
# [Ep 44, Step 37] Score: 2442 | Reward: -100.00 | Epsilon: 0.8061 | Action: (4, 2) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 44 finished: LOSS | Score: 2442 | Loss: 0.4881
# Episodes: 44 | Win Rate: 13.64% | Highest Score: 5169.00 | Time Efficiency: 6.09 steps/sec | Left Click Avg: 9.27 c/g (2.50 c/s) | Right Click Avg: 13.32 c/g (3.59 c/s) | Total Click Avg: 22.59 c/g (6.09 c/s) | Game Conclusion History: 6 Wins, 38 Losses
# ============================================================
#
# [Ep 45, Step 10] Score: 505 | Reward: 0.90 | Epsilon: 0.8021 | Action: (6, 4) Reveal | Revealed: 21/59
# [Ep 45, Step 20] Score: 1620 | Reward: 0.90 | Epsilon: 0.8021 | Action: (6, 0) Reveal | Revealed: 53/59
# [Ep 45, Step 25] Score: 1575 | Reward: -100.00 | Epsilon: 0.8021 | Action: (2, 4) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 45 finished: LOSS | Score: 1575 | Loss: 4.7947
# Episodes: 45 | Win Rate: 13.33% | Highest Score: 5169.00 | Time Efficiency: 6.11 steps/sec | Left Click Avg: 9.36 c/g (2.53 c/s) | Right Click Avg: 13.29 c/g (3.59 c/s) | Total Click Avg: 22.64 c/g (6.11 c/s) | Game Conclusion History: 6 Wins, 39 Losses
# ============================================================
#
# [Ep 46, Step 10] Score: 2133 | Reward: -0.10 | Epsilon: 0.7981 | Action: (2, 7) Flag | Revealed: 50/59
# [Ep 46, Step 20] Score: 2153 | Reward: -0.10 | Epsilon: 0.7981 | Action: (3, 7) Flag | Revealed: 55/59
# [Ep 46, Step 24] Score: 2163 | Reward: -100.00 | Epsilon: 0.7981 | Action: (0, 7) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 46 finished: LOSS | Score: 2163 | Loss: 0.7939
# Episodes: 46 | Win Rate: 13.04% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 9.43 c/g (2.55 c/s) | Right Click Avg: 13.24 c/g (3.58 c/s) | Total Click Avg: 22.67 c/g (6.13 c/s) | Game Conclusion History: 6 Wins, 40 Losses
# ============================================================
#
# [Ep 47, Step 10] Score: 3500 | Reward: -0.10 | Epsilon: 0.7941 | Action: (1, 7) Flag | Revealed: 54/59
# [Ep 47, Step 20] Score: 3520 | Reward: -0.10 | Epsilon: 0.7941 | Action: (0, 5) Flag | Revealed: 57/59
# [Ep 47, Step 28] Score: 3475 | Reward: -100.00 | Epsilon: 0.7941 | Action: (5, 5) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 47 finished: LOSS | Score: 3475 | Loss: 0.5683
# Episodes: 47 | Win Rate: 12.77% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 9.40 c/g (2.53 c/s) | Right Click Avg: 13.38 c/g (3.60 c/s) | Total Click Avg: 22.79 c/g (6.13 c/s) | Game Conclusion History: 6 Wins, 41 Losses
# ============================================================
#
# [Ep 48, Step 10] Score: 2762 | Reward: -0.10 | Epsilon: 0.7901 | Action: (1, 7) Flag | Revealed: 56/59
# [Ep 48, Step 17] Score: 2722 | Reward: -100.00 | Epsilon: 0.7901 | Action: (1, 6) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 48 finished: LOSS | Score: 2722 | Loss: 0.8329
# Episodes: 48 | Win Rate: 12.50% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 9.35 c/g (2.53 c/s) | Right Click Avg: 13.31 c/g (3.60 c/s) | Total Click Avg: 22.67 c/g (6.13 c/s) | Game Conclusion History: 6 Wins, 42 Losses
# ============================================================
#
# [Ep 49, Step 10] Score: 3342 | Reward: -0.10 | Epsilon: 0.7862 | Action: (7, 4) Flag | Revealed: 54/59
# [Ep 49, Step 20] Score: 3402 | Reward: -0.10 | Epsilon: 0.7862 | Action: (7, 4) Flag | Revealed: 58/59
# [Ep 49, Step 30] Score: 3412 | Reward: -0.10 | Epsilon: 0.7862 | Action: (5, 2) Flag | Revealed: 60/59
# [Ep 49, Step 34] Score: 4662 | Reward: 100.00 | Epsilon: 0.7862 | Action: (5, 2) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 49 finished: WIN | Score: 4662 | Loss: 1.4144
# Episodes: 49 | Win Rate: 14.29% | Highest Score: 5169.00 | Time Efficiency: 6.16 steps/sec | Left Click Avg: 9.35 c/g (2.52 c/s) | Right Click Avg: 13.55 c/g (3.65 c/s) | Total Click Avg: 22.90 c/g (6.16 c/s) | Game Conclusion History: 7 Wins, 42 Losses
# ============================================================
#
# [Ep 50, Step 10] Score: 2758 | Reward: 5.90 | Epsilon: 0.7822 | Action: (7, 2) Reveal | Revealed: 54/59
# [Ep 50, Step 20] Score: 2818 | Reward: -0.10 | Epsilon: 0.7822 | Action: (5, 0) Flag | Revealed: 57/59
# [Ep 50, Step 26] Score: 2828 | Reward: -100.00 | Epsilon: 0.7822 | Action: (5, 2) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 50 finished: LOSS | Score: 2828 | Loss: 1.2077
# Episodes: 50 | Win Rate: 14.00% | Highest Score: 5169.00 | Time Efficiency: 6.19 steps/sec | Left Click Avg: 9.32 c/g (2.51 c/s) | Right Click Avg: 13.64 c/g (3.68 c/s) | Total Click Avg: 22.96 c/g (6.19 c/s) | Game Conclusion History: 7 Wins, 43 Losses
# ============================================================
#
# [Ep 51, Step 10] Score: 3637 | Reward: -100.00 | Epsilon: 0.7783 | Action: (7, 7) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 51 finished: LOSS | Score: 3637 | Loss: 0.6581
# Episodes: 51 | Win Rate: 13.73% | Highest Score: 5169.00 | Time Efficiency: 6.16 steps/sec | Left Click Avg: 9.22 c/g (2.50 c/s) | Right Click Avg: 13.49 c/g (3.66 c/s) | Total Click Avg: 22.71 c/g (6.16 c/s) | Game Conclusion History: 7 Wins, 44 Losses
# ============================================================
#
# [Ep 52, Step 10] Score: 3412 | Reward: 0.90 | Epsilon: 0.7744 | Action: (7, 2) Reveal | Revealed: 58/59
# [Ep 52, Step 13] Score: 3412 | Reward: -100.00 | Epsilon: 0.7744 | Action: (3, 6) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 52 finished: LOSS | Score: 3412 | Loss: 0.5327
# Episodes: 52 | Win Rate: 13.46% | Highest Score: 5169.00 | Time Efficiency: 6.15 steps/sec | Left Click Avg: 9.17 c/g (2.51 c/s) | Right Click Avg: 13.35 c/g (3.65 c/s) | Total Click Avg: 22.52 c/g (6.15 c/s) | Game Conclusion History: 7 Wins, 45 Losses
# ============================================================
#
# [Ep 53, Step 5] Score: 3297 | Reward: -100.00 | Epsilon: 0.7705 | Action: (6, 7) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 53 finished: LOSS | Score: 3297 | Loss: 3.7851
# Episodes: 53 | Win Rate: 13.21% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 9.09 c/g (2.51 c/s) | Right Click Avg: 13.09 c/g (3.62 c/s) | Total Click Avg: 22.19 c/g (6.13 c/s) | Game Conclusion History: 7 Wins, 46 Losses
# ============================================================
#
# [Ep 54, Step 10] Score: 3475 | Reward: -0.10 | Epsilon: 0.7667 | Action: (1, 1) Flag | Revealed: 58/59
# [Ep 54, Step 19] Score: 3485 | Reward: -100.00 | Epsilon: 0.7667 | Action: (2, 0) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 54 finished: LOSS | Score: 3485 | Loss: 0.2677
# Episodes: 54 | Win Rate: 12.96% | Highest Score: 5169.00 | Time Efficiency: 6.14 steps/sec | Left Click Avg: 9.11 c/g (2.53 c/s) | Right Click Avg: 13.02 c/g (3.61 c/s) | Total Click Avg: 22.13 c/g (6.14 c/s) | Game Conclusion History: 7 Wins, 47 Losses
# ============================================================
#
# [Ep 55, Step 10] Score: 3010 | Reward: -0.10 | Epsilon: 0.7629 | Action: (5, 2) Flag | Revealed: 53/59
# [Ep 55, Step 12] Score: 3010 | Reward: -100.00 | Epsilon: 0.7629 | Action: (1, 1) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 55 finished: LOSS | Score: 3010 | Loss: 1.8699
# Episodes: 55 | Win Rate: 12.73% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 9.04 c/g (2.52 c/s) | Right Click Avg: 12.91 c/g (3.61 c/s) | Total Click Avg: 21.95 c/g (6.13 c/s) | Game Conclusion History: 7 Wins, 48 Losses
# ============================================================
#
# [Ep 56, Step 10] Score: 2612 | Reward: 0.90 | Epsilon: 0.7590 | Action: (1, 4) Reveal | Revealed: 52/59
# [Ep 56, Step 15] Score: 2682 | Reward: -100.00 | Epsilon: 0.7590 | Action: (4, 5) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 56 finished: LOSS | Score: 2682 | Loss: 1.1114
# Episodes: 56 | Win Rate: 12.50% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 9.07 c/g (2.55 c/s) | Right Click Avg: 12.75 c/g (3.58 c/s) | Total Click Avg: 21.82 c/g (6.13 c/s) | Game Conclusion History: 7 Wins, 49 Losses
# ============================================================
#
# [Ep 57, Step 9] Score: 3580 | Reward: -100.00 | Epsilon: 0.7553 | Action: (5, 5) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 57 finished: LOSS | Score: 3580 | Loss: 0.4601
# Episodes: 57 | Win Rate: 12.28% | Highest Score: 5169.00 | Time Efficiency: 6.12 steps/sec | Left Click Avg: 9.02 c/g (2.56 c/s) | Right Click Avg: 12.58 c/g (3.56 c/s) | Total Click Avg: 21.60 c/g (6.12 c/s) | Game Conclusion History: 7 Wins, 50 Losses
# ============================================================
#
# [Ep 58, Step 10] Score: 2186 | Reward: -0.10 | Epsilon: 0.7515 | Action: (3, 7) Flag | Revealed: 46/59
# [Ep 58, Step 13] Score: 2368 | Reward: -100.00 | Epsilon: 0.7515 | Action: (3, 4) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 58 finished: LOSS | Score: 2368 | Loss: 0.9621
# Episodes: 58 | Win Rate: 12.07% | Highest Score: 5169.00 | Time Efficiency: 6.11 steps/sec | Left Click Avg: 9.00 c/g (2.56 c/s) | Right Click Avg: 12.45 c/g (3.54 c/s) | Total Click Avg: 21.45 c/g (6.11 c/s) | Game Conclusion History: 7 Wins, 51 Losses
# ============================================================
#
# [Ep 59, Step 10] Score: 65 | Reward: -0.10 | Epsilon: 0.7477 | Action: (2, 6) Flag | Revealed: 4/59
# [Ep 59, Step 20] Score: 1683 | Reward: -0.10 | Epsilon: 0.7477 | Action: (3, 7) Flag | Revealed: 54/59
# [Ep 59, Step 24] Score: 1733 | Reward: -100.00 | Epsilon: 0.7477 | Action: (6, 2) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 59 finished: LOSS | Score: 1733 | Loss: 0.8087
# Episodes: 59 | Win Rate: 11.86% | Highest Score: 5169.00 | Time Efficiency: 6.12 steps/sec | Left Click Avg: 9.02 c/g (2.57 c/s) | Right Click Avg: 12.47 c/g (3.55 c/s) | Total Click Avg: 21.49 c/g (6.12 c/s) | Game Conclusion History: 7 Wins, 52 Losses
# ============================================================
#
# [Ep 60, Step 10] Score: 2656 | Reward: -0.10 | Epsilon: 0.7440 | Action: (4, 7) Flag | Revealed: 50/59
# [Ep 60, Step 16] Score: 2726 | Reward: -100.00 | Epsilon: 0.7440 | Action: (0, 6) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 60 finished: LOSS | Score: 2726 | Loss: 1.1031
# Episodes: 60 | Win Rate: 11.67% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 9.03 c/g (2.59 c/s) | Right Click Avg: 12.37 c/g (3.54 c/s) | Total Click Avg: 21.40 c/g (6.13 c/s) | Game Conclusion History: 7 Wins, 53 Losses
# ============================================================
#
# [Ep 61, Step 10] Score: 3206 | Reward: -0.10 | Epsilon: 0.7403 | Action: (5, 2) Flag | Revealed: 53/59
# [Ep 61, Step 19] Score: 3261 | Reward: -100.00 | Epsilon: 0.7403 | Action: (6, 2) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 61 finished: LOSS | Score: 3261 | Loss: 0.2780
# Episodes: 61 | Win Rate: 11.48% | Highest Score: 5169.00 | Time Efficiency: 6.13 steps/sec | Left Click Avg: 8.98 c/g (2.58 c/s) | Right Click Avg: 12.38 c/g (3.55 c/s) | Total Click Avg: 21.36 c/g (6.13 c/s) | Game Conclusion History: 7 Wins, 54 Losses
# ============================================================
#
# [Ep 62, Step 5] Score: 5546 | Reward: 100.00 | Epsilon: 0.7366 | Action: (7, 2) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 62 finished: WIN | Score: 5546 | Loss: 0.4476
# Episodes: 62 | Win Rate: 12.90% | Highest Score: 5546.00 | Time Efficiency: 6.11 steps/sec | Left Click Avg: 8.89 c/g (2.58 c/s) | Right Click Avg: 12.21 c/g (3.54 c/s) | Total Click Avg: 21.10 c/g (6.11 c/s) | Game Conclusion History: 8 Wins, 54 Losses
# ============================================================
#
# [Ep 63, Step 10] Score: 3372 | Reward: 0.90 | Epsilon: 0.7329 | Action: (7, 7) Reveal | Revealed: 56/59
# [Ep 63, Step 11] Score: 3372 | Reward: -100.00 | Epsilon: 0.7329 | Action: (6, 6) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 63 finished: LOSS | Score: 3372 | Loss: 0.4087
# Episodes: 63 | Win Rate: 12.70% | Highest Score: 5546.00 | Time Efficiency: 6.11 steps/sec | Left Click Avg: 8.84 c/g (2.58 c/s) | Right Click Avg: 12.10 c/g (3.53 c/s) | Total Click Avg: 20.94 c/g (6.11 c/s) | Game Conclusion History: 8 Wins, 55 Losses
# ============================================================
#
# [Ep 64, Step 10] Score: 2955 | Reward: -0.10 | Epsilon: 0.7292 | Action: (1, 2) Flag | Revealed: 52/59
# [Ep 64, Step 18] Score: 2860 | Reward: -100.00 | Epsilon: 0.7292 | Action: (1, 5) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 64 finished: LOSS | Score: 2860 | Loss: 0.2840
# Episodes: 64 | Win Rate: 12.50% | Highest Score: 5546.00 | Time Efficiency: 6.11 steps/sec | Left Click Avg: 8.81 c/g (2.58 c/s) | Right Click Avg: 12.08 c/g (3.53 c/s) | Total Click Avg: 20.89 c/g (6.11 c/s) | Game Conclusion History: 8 Wins, 56 Losses
# ============================================================
#
# [Ep 65, Step 10] Score: 3052 | Reward: -0.10 | Epsilon: 0.7256 | Action: (4, 5) Reveal | Revealed: 53/59
# [Ep 65, Step 17] Score: 3117 | Reward: -100.00 | Epsilon: 0.7256 | Action: (0, 1) Reveal | Revealed: 56/59
#
# ============================================================
# Episode 65 finished: LOSS | Score: 3117 | Loss: 3.5083
# Episodes: 65 | Win Rate: 12.31% | Highest Score: 5546.00 | Time Efficiency: 6.11 steps/sec | Left Click Avg: 8.77 c/g (2.57 c/s) | Right Click Avg: 12.06 c/g (3.54 c/s) | Total Click Avg: 20.83 c/g (6.11 c/s) | Game Conclusion History: 8 Wins, 57 Losses
# ============================================================
#
# [Ep 66, Step 10] Score: 2641 | Reward: -0.10 | Epsilon: 0.7219 | Action: (4, 2) Reveal | Revealed: 49/59
# [Ep 66, Step 19] Score: 2641 | Reward: -100.00 | Epsilon: 0.7219 | Action: (3, 1) Reveal | Revealed: 50/59
#
# ============================================================
# Episode 66 finished: LOSS | Score: 2641 | Loss: 1.3437
# Episodes: 66 | Win Rate: 12.12% | Highest Score: 5546.00 | Time Efficiency: 6.12 steps/sec | Left Click Avg: 8.70 c/g (2.56 c/s) | Right Click Avg: 12.11 c/g (3.56 c/s) | Total Click Avg: 20.80 c/g (6.12 c/s) | Game Conclusion History: 8 Wins, 58 Losses
# ============================================================
#
# [Ep 67, Step 10] Score: 2033 | Reward: -0.10 | Epsilon: 0.7183 | Action: (3, 1) Flag | Revealed: 50/59
# [Ep 67, Step 20] Score: 1988 | Reward: -0.10 | Epsilon: 0.7183 | Action: (3, 5) Reveal | Revealed: 52/59
# [Ep 67, Step 30] Score: 2068 | Reward: -0.10 | Epsilon: 0.7183 | Action: (0, 3) Flag | Revealed: 57/59
# [Ep 67, Step 40] Score: 2088 | Reward: -0.10 | Epsilon: 0.7183 | Action: (0, 3) Flag | Revealed: 59/59
# [Ep 67, Step 50] Score: 2088 | Reward: -0.10 | Epsilon: 0.7183 | Action: (0, 3) Flag | Revealed: 59/59
# [Ep 67, Step 60] Score: 2038 | Reward: -100.00 | Epsilon: 0.7183 | Action: (3, 1) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 67 finished: LOSS | Score: 2038 | Loss: 0.8522
# Episodes: 67 | Win Rate: 11.94% | Highest Score: 5546.00 | Time Efficiency: 6.20 steps/sec | Left Click Avg: 8.76 c/g (2.54 c/s) | Right Click Avg: 12.63 c/g (3.66 c/s) | Total Click Avg: 21.39 c/g (6.20 c/s) | Game Conclusion History: 8 Wins, 59 Losses
# ============================================================
#
# [Ep 68, Step 10] Score: 15 | Reward: 0.90 | Epsilon: 0.7147 | Action: (1, 3) Reveal | Revealed: 1/59
# [Ep 68, Step 20] Score: 2030 | Reward: -0.10 | Epsilon: 0.7147 | Action: (1, 7) Reveal | Revealed: 43/59
# [Ep 68, Step 30] Score: 2015 | Reward: 0.90 | Epsilon: 0.7147 | Action: (0, 7) Reveal | Revealed: 48/59
# [Ep 68, Step 40] Score: 2045 | Reward: -0.10 | Epsilon: 0.7147 | Action: (2, 4) Flag | Revealed: 53/59
# [Ep 68, Step 47] Score: 2100 | Reward: -100.00 | Epsilon: 0.7147 | Action: (1, 4) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 68 finished: LOSS | Score: 2100 | Loss: 0.8947
# Episodes: 68 | Win Rate: 11.76% | Highest Score: 5546.00 | Time Efficiency: 6.25 steps/sec | Left Click Avg: 8.88 c/g (2.55 c/s) | Right Click Avg: 12.88 c/g (3.70 c/s) | Total Click Avg: 21.76 c/g (6.25 c/s) | Game Conclusion History: 8 Wins, 60 Losses
# ============================================================
#
# [Ep 69, Step 10] Score: 3132 | Reward: -0.10 | Epsilon: 0.7112 | Action: (0, 2) Flag | Revealed: 55/59
# [Ep 69, Step 16] Score: 3142 | Reward: -100.00 | Epsilon: 0.7112 | Action: (0, 0) Reveal | Revealed: 58/59
#
# ============================================================
# ...
#
# ============================================================
# Episode 284 finished: LOSS | Score: 1867 | Loss: 0.5085
# Episodes: 284 | Win Rate: 9.51% | Highest Score: 37650.00 | Time Efficiency: 7.25 steps/sec | Left Click Avg: 8.98 c/g (2.42 c/s) | Right Click Avg: 17.94 c/g (4.83 c/s) | Total Click Avg: 26.92 c/g (7.25 c/s) | Game Conclusion History: 27 Wins, 257 Losses
# ============================================================
#
# [Ep 285, Step 10] Score: 1155 | Reward: 0.90 | Epsilon: 0.2409 | Action: (1, 6) Reveal | Revealed: 35/59
# [Ep 285, Step 20] Score: 1710 | Reward: 0.90 | Epsilon: 0.2409 | Action: (4, 4) Reveal | Revealed: 56/59
# [Ep 285, Step 30] Score: 1770 | Reward: -0.10 | Epsilon: 0.2409 | Action: (4, 3) Flag | Revealed: 57/59
# [Ep 285, Step 34] Score: 1770 | Reward: -100.00 | Epsilon: 0.2409 | Action: (4, 2) Reveal | Revealed: 58/59
#
# ============================================================
# Episode 285 finished: LOSS | Score: 1770 | Loss: 0.2511
# Episodes: 285 | Win Rate: 9.47% | Highest Score: 37650.00 | Time Efficiency: 7.25 steps/sec | Left Click Avg: 9.00 c/g (2.42 c/s) | Right Click Avg: 17.95 c/g (4.83 c/s) | Total Click Avg: 26.94 c/g (7.25 c/s) | Game Conclusion History: 27 Wins, 258 Losses
# ============================================================
#
# [Ep 286, Step 10] Score: 3317 | Reward: -0.10 | Epsilon: 0.2397 | Action: (5, 5) Flag | Revealed: 53/59
# [Ep 286, Step 20] Score: 3367 | Reward: -0.10 | Epsilon: 0.2397 | Action: (7, 5) Flag | Revealed: 54/59
# [Ep 286, Step 30] Score: 3367 | Reward: -0.10 | Epsilon: 0.2397 | Action: (2, 2) Flag | Revealed: 55/59
# [Ep 286, Step 40] Score: 3377 | Reward: -0.10 | Epsilon: 0.2397 | Action: (5, 5) Flag | Revealed: 56/59
# [Ep 286, Step 50] Score: 3427 | Reward: -0.10 | Epsilon: 0.2397 | Action: (2, 2) Flag | Revealed: 56/59
# [Ep 286, Step 60] Score: 3377 | Reward: -0.10 | Epsilon: 0.2397 | Action: (2, 2) Flag | Revealed: 56/59
# [Ep 286, Step 70] Score: 3332 | Reward: 0.90 | Epsilon: 0.2397 | Action: (0, 0) Reveal | Revealed: 57/59
# [Ep 286, Step 80] Score: 3297 | Reward: 0.90 | Epsilon: 0.2397 | Action: (2, 1) Reveal | Revealed: 58/59
# [Ep 286, Step 90] Score: 3402 | Reward: -0.10 | Epsilon: 0.2397 | Action: (2, 2) Flag | Revealed: 59/59
# [Ep 286, Step 100] Score: 3402 | Reward: -0.10 | Epsilon: 0.2397 | Action: (7, 5) Flag | Revealed: 59/59
# [Ep 286, Step 110] Score: 3402 | Reward: -0.10 | Epsilon: 0.2397 | Action: (2, 2) Flag | Revealed: 59/59
# [Ep 286, Step 120] Score: 3352 | Reward: -100.00 | Epsilon: 0.2397 | Action: (7, 5) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 286 finished: LOSS | Score: 3352 | Loss: 0.5415
# Episodes: 286 | Win Rate: 9.44% | Highest Score: 37650.00 | Time Efficiency: 7.29 steps/sec | Left Click Avg: 9.00 c/g (2.40 c/s) | Right Click Avg: 18.27 c/g (4.88 c/s) | Total Click Avg: 27.27 c/g (7.29 c/s) | Game Conclusion History: 27 Wins, 259 Losses
# ============================================================
#
# [Ep 287, Step 10] Score: 35 | Reward: 0.90 | Epsilon: 0.2385 | Action: (4, 4) Reveal | Revealed: 5/59
# [Ep 287, Step 17] Score: 2415 | Reward: -100.00 | Epsilon: 0.2385 | Action: (3, 5) Reveal | Revealed: 52/59
#
# ============================================================
# Episode 287 finished: LOSS | Score: 2415 | Loss: 2.8434
# Episodes: 287 | Win Rate: 9.41% | Highest Score: 37650.00 | Time Efficiency: 7.29 steps/sec | Left Click Avg: 9.00 c/g (2.41 c/s) | Right Click Avg: 18.24 c/g (4.88 c/s) | Total Click Avg: 27.23 c/g (7.29 c/s) | Game Conclusion History: 27 Wins, 260 Losses
# ============================================================
#
# [Ep 288, Step 10] Score: 2237 | Reward: -0.10 | Epsilon: 0.2373 | Action: (4, 4) Flag | Revealed: 59/59
# [Ep 288, Step 20] Score: 2287 | Reward: -0.10 | Epsilon: 0.2373 | Action: (4, 4) Flag | Revealed: 60/59
# [Ep 288, Step 30] Score: 2287 | Reward: -0.10 | Epsilon: 0.2373 | Action: (4, 4) Flag | Revealed: 60/59
# [Ep 288, Step 40] Score: 2287 | Reward: -0.10 | Epsilon: 0.2373 | Action: (4, 4) Flag | Revealed: 60/59
# [Ep 288, Step 50] Score: 2237 | Reward: -0.10 | Epsilon: 0.2373 | Action: (7, 1) Flag | Revealed: 60/59
# [Ep 288, Step 57] Score: 2187 | Reward: -100.00 | Epsilon: 0.2373 | Action: (6, 0) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 288 finished: LOSS | Score: 2187 | Loss: 0.8869
# Episodes: 288 | Win Rate: 9.38% | Highest Score: 37650.00 | Time Efficiency: 7.30 steps/sec | Left Click Avg: 8.99 c/g (2.40 c/s) | Right Click Avg: 18.35 c/g (4.90 c/s) | Total Click Avg: 27.34 c/g (7.30 c/s) | Game Conclusion History: 27 Wins, 261 Losses
# ============================================================
#
# [Ep 289, Step 10] Score: 25 | Reward: 0.90 | Epsilon: 0.2361 | Action: (4, 1) Reveal | Revealed: 4/59
# [Ep 289, Step 20] Score: 25 | Reward: -0.10 | Epsilon: 0.2361 | Action: (6, 6) Flag | Revealed: 4/59
# [Ep 289, Step 30] Score: 25 | Reward: -0.10 | Epsilon: 0.2361 | Action: (2, 0) Flag | Revealed: 4/59
# [Ep 289, Step 40] Score: 35 | Reward: -0.10 | Epsilon: 0.2361 | Action: (6, 6) Flag | Revealed: 5/59
# [Ep 289, Step 48] Score: 1585 | Reward: -100.00 | Epsilon: 0.2361 | Action: (1, 0) Reveal | Revealed: 43/59
#
# ============================================================
# Episode 289 finished: LOSS | Score: 1585 | Loss: 1.2764
# Episodes: 289 | Win Rate: 9.34% | Highest Score: 37650.00 | Time Efficiency: 7.31 steps/sec | Left Click Avg: 8.99 c/g (2.40 c/s) | Right Click Avg: 18.42 c/g (4.91 c/s) | Total Click Avg: 27.41 c/g (7.31 c/s) | Game Conclusion History: 27 Wins, 262 Losses
# ============================================================
#
# [Ep 290, Step 10] Score: 2636 | Reward: -0.10 | Epsilon: 0.2349 | Action: (3, 6) Flag | Revealed: 50/59
# [Ep 290, Step 20] Score: 2641 | Reward: -0.10 | Epsilon: 0.2349 | Action: (3, 6) Flag | Revealed: 51/59
# [Ep 290, Step 30] Score: 2641 | Reward: -0.10 | Epsilon: 0.2349 | Action: (3, 6) Flag | Revealed: 51/59
# [Ep 290, Step 40] Score: 2696 | Reward: -0.10 | Epsilon: 0.2349 | Action: (3, 6) Flag | Revealed: 53/59
# [Ep 290, Step 50] Score: 2696 | Reward: -0.10 | Epsilon: 0.2349 | Action: (3, 6) Flag | Revealed: 53/59
# [Ep 290, Step 52] Score: 2646 | Reward: -100.00 | Epsilon: 0.2349 | Action: (0, 7) Reveal | Revealed: 54/59
#
# ============================================================
# Episode 290 finished: LOSS | Score: 2646 | Loss: 0.8282
# Episodes: 290 | Win Rate: 9.31% | Highest Score: 37650.00 | Time Efficiency: 7.32 steps/sec | Left Click Avg: 8.98 c/g (2.39 c/s) | Right Click Avg: 18.51 c/g (4.93 c/s) | Total Click Avg: 27.49 c/g (7.32 c/s) | Game Conclusion History: 27 Wins, 263 Losses
# ============================================================
#
# [Ep 291, Step 10] Score: 3677 | Reward: -0.10 | Epsilon: 0.2337 | Action: (0, 7) Flag | Revealed: 58/59
# [Ep 291, Step 20] Score: 3737 | Reward: -0.10 | Epsilon: 0.2337 | Action: (7, 0) Flag | Revealed: 59/59
# [Ep 291, Step 29] Score: 3687 | Reward: -100.00 | Epsilon: 0.2337 | Action: (7, 3) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 291 finished: LOSS | Score: 3687 | Loss: 0.2686
# Episodes: 291 | Win Rate: 9.28% | Highest Score: 37650.00 | Time Efficiency: 7.32 steps/sec | Left Click Avg: 8.97 c/g (2.39 c/s) | Right Click Avg: 18.53 c/g (4.93 c/s) | Total Click Avg: 27.50 c/g (7.32 c/s) | Game Conclusion History: 27 Wins, 264 Losses
# ============================================================
#
# [Ep 292, Step 6] Score: 3161 | Reward: -100.00 | Epsilon: 0.2326 | Action: (1, 3) Reveal | Revealed: 55/59
#
# ============================================================
# Episode 292 finished: LOSS | Score: 3161 | Loss: 2.4839
# Episodes: 292 | Win Rate: 9.25% | Highest Score: 37650.00 | Time Efficiency: 7.31 steps/sec | Left Click Avg: 8.96 c/g (2.39 c/s) | Right Click Avg: 18.47 c/g (4.93 c/s) | Total Click Avg: 27.42 c/g (7.31 c/s) | Game Conclusion History: 27 Wins, 265 Losses
# ============================================================
#
# [Ep 293, Step 10] Score: 3181 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 55/59
# [Ep 293, Step 20] Score: 3246 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 57/59
# [Ep 293, Step 30] Score: 3306 | Reward: -0.10 | Epsilon: 0.2314 | Action: (6, 5) Flag | Revealed: 58/59
# [Ep 293, Step 40] Score: 3256 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 58/59
# [Ep 293, Step 50] Score: 3306 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 7) Flag | Revealed: 58/59
# [Ep 293, Step 60] Score: 3256 | Reward: -0.10 | Epsilon: 0.2314 | Action: (1, 2) Flag | Revealed: 58/59
# [Ep 293, Step 70] Score: 3206 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 58/59
# [Ep 293, Step 80] Score: 3306 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 58/59
# [Ep 293, Step 90] Score: 3306 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 58/59
# [Ep 293, Step 100] Score: 3256 | Reward: -0.10 | Epsilon: 0.2314 | Action: (1, 2) Flag | Revealed: 58/59
# [Ep 293, Step 110] Score: 3256 | Reward: -0.10 | Epsilon: 0.2314 | Action: (1, 2) Flag | Revealed: 58/59
# [Ep 293, Step 120] Score: 3256 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 58/59
# [Ep 293, Step 130] Score: 3306 | Reward: -0.10 | Epsilon: 0.2314 | Action: (1, 2) Flag | Revealed: 58/59
# [Ep 293, Step 140] Score: 3256 | Reward: -0.10 | Epsilon: 0.2314 | Action: (7, 5) Flag | Revealed: 58/59
# [Ep 293, Step 144] Score: 3256 | Reward: -100.00 | Epsilon: 0.2314 | Action: (7, 5) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 293 finished: LOSS | Score: 3256 | Loss: 0.6234
# Episodes: 293 | Win Rate: 9.22% | Highest Score: 37650.00 | Time Efficiency: 7.36 steps/sec | Left Click Avg: 8.96 c/g (2.37 c/s) | Right Click Avg: 18.87 c/g (4.99 c/s) | Total Click Avg: 27.82 c/g (7.36 c/s) | Game Conclusion History: 27 Wins, 266 Losses
# ============================================================
#
# [Ep 294, Step 10] Score: 2930 | Reward: -0.10 | Epsilon: 0.2302 | Action: (6, 4) Flag | Revealed: 50/59
# [Ep 294, Step 20] Score: 2930 | Reward: -0.10 | Epsilon: 0.2302 | Action: (6, 4) Flag | Revealed: 51/59
# [Ep 294, Step 30] Score: 3035 | Reward: -0.10 | Epsilon: 0.2302 | Action: (6, 4) Flag | Revealed: 52/59
# [Ep 294, Step 40] Score: 3040 | Reward: -0.10 | Epsilon: 0.2302 | Action: (6, 4) Flag | Revealed: 54/59
# [Ep 294, Step 46] Score: 3070 | Reward: -100.00 | Epsilon: 0.2302 | Action: (6, 3) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 294 finished: LOSS | Score: 3070 | Loss: 0.9654
# Episodes: 294 | Win Rate: 9.18% | Highest Score: 37650.00 | Time Efficiency: 7.37 steps/sec | Left Click Avg: 8.95 c/g (2.36 c/s) | Right Click Avg: 18.94 c/g (5.00 c/s) | Total Click Avg: 27.88 c/g (7.37 c/s) | Game Conclusion History: 27 Wins, 267 Losses
# ============================================================
#
# [Ep 295, Step 10] Score: 3052 | Reward: -0.10 | Epsilon: 0.2291 | Action: (6, 5) Flag | Revealed: 54/59
# [Ep 295, Step 19] Score: 3157 | Reward: -100.00 | Epsilon: 0.2291 | Action: (6, 3) Reveal | Revealed: 57/59
#
# ============================================================
# Episode 295 finished: LOSS | Score: 3157 | Loss: 0.5128
# Episodes: 295 | Win Rate: 9.15% | Highest Score: 37650.00 | Time Efficiency: 7.36 steps/sec | Left Click Avg: 8.95 c/g (2.36 c/s) | Right Click Avg: 18.91 c/g (5.00 c/s) | Total Click Avg: 27.85 c/g (7.36 c/s) | Game Conclusion History: 27 Wins, 268 Losses
# ============================================================
#
# [Ep 296, Step 10] Score: 2115 | Reward: -0.10 | Epsilon: 0.2279 | Action: (0, 7) Flag | Revealed: 57/59
# [Ep 296, Step 20] Score: 2115 | Reward: -0.10 | Epsilon: 0.2279 | Action: (0, 7) Flag | Revealed: 58/59
# [Ep 296, Step 21] Score: 2115 | Reward: -100.00 | Epsilon: 0.2279 | Action: (2, 5) Reveal | Revealed: 59/59
#
# ============================================================
# Episode 296 finished: LOSS | Score: 2115 | Loss: 0.9220
# Episodes: 296 | Win Rate: 9.12% | Highest Score: 37650.00 | Time Efficiency: 7.36 steps/sec | Left Click Avg: 8.94 c/g (2.36 c/s) | Right Click Avg: 18.90 c/g (5.00 c/s) | Total Click Avg: 27.83 c/g (7.36 c/s) | Game Conclusion History: 27 Wins, 269 Losses
# ============================================================
#
# [Ep 297, Step 10] Score: 3287 | Reward: -0.10 | Epsilon: 0.2268 | Action: (0, 3) Flag | Revealed: 54/59
# [Ep 297, Step 20] Score: 3337 | Reward: -0.10 | Epsilon: 0.2268 | Action: (7, 6) Flag | Revealed: 55/59
# [Ep 297, Step 30] Score: 3337 | Reward: -0.10 | Epsilon: 0.2268 | Action: (0, 3) Flag | Revealed: 55/59
# [Ep 297, Step 40] Score: 3337 | Reward: -0.10 | Epsilon: 0.2268 | Action: (0, 3) Flag | Revealed: 55/59
# [Ep 297, Step 50] Score: 3347 | Reward: 0.90 | Epsilon: 0.2268 | Action: (7, 7) Reveal | Revealed: 58/59
# [Ep 297, Step 58] Score: 3352 | Reward: -100.00 | Epsilon: 0.2268 | Action: (5, 0) Reveal | Revealed: 60/59
#
# ============================================================
# Episode 297 finished: LOSS | Score: 3352 | Loss: 0.6714
# Episodes: 297 | Win Rate: 9.09% | Highest Score: 37650.00 | Time Efficiency: 7.37 steps/sec | Left Click Avg: 8.94 c/g (2.36 c/s) | Right Click Avg: 19.00 c/g (5.01 c/s) | Total Click Avg: 27.93 c/g (7.37 c/s) | Game Conclusion History: 27 Wins, 270 Losses
# ============================================================
#
# [Ep 298, Step 4] Score: 3907 | Reward: -100.00 | Epsilon: 0.2257 | Action: (4, 3) Reveal | Revealed: 61/59
#
# ============================================================
# Episode 298 finished: LOSS | Score: 3907 | Loss: 6.2991
# Episodes: 298 | Win Rate: 9.06% | Highest Score: 37650.00 | Time Efficiency: 7.36 steps/sec | Left Click Avg: 8.92 c/g (2.36 c/s) | Right Click Avg: 18.93 c/g (5.01 c/s) | Total Click Avg: 27.85 c/g (7.36 c/s) | Game Conclusion History: 27 Wins, 271 Losses
# ============================================================
#
# [Ep 299, Step 6] Score: 2945 | Reward: -100.00 | Epsilon: 0.2245 | Action: (7, 1) Reveal | Revealed: 53/59
#
# ============================================================
# Episode 299 finished: LOSS | Score: 2945 | Loss: 0.6025
# Episodes: 299 | Win Rate: 9.03% | Highest Score: 37650.00 | Time Efficiency: 7.36 steps/sec | Left Click Avg: 8.91 c/g (2.36 c/s) | Right Click Avg: 18.87 c/g (5.00 c/s) | Total Click Avg: 27.78 c/g (7.36 c/s) | Game Conclusion History: 27 Wins, 272 Losses
# ============================================================
#
# [Ep 300, Step 10] Score: 1550 | Reward: -0.10 | Epsilon: 0.2234 | Action: (6, 1) Flag | Revealed: 39/59
# [Ep 300, Step 20] Score: 1550 | Reward: -0.10 | Epsilon: 0.2234 | Action: (6, 1) Flag | Revealed: 39/59
# [Ep 300, Step 30] Score: 1555 | Reward: -0.10 | Epsilon: 0.2234 | Action: (7, 2) Flag | Revealed: 40/59
# [Ep 300, Step 40] Score: 1560 | Reward: 0.90 | Epsilon: 0.2234 | Action: (6, 7) Reveal | Revealed: 41/59
# [Ep 300, Step 50] Score: 1836 | Reward: -0.10 | Epsilon: 0.2234 | Action: (7, 6) Flag | Revealed: 53/59
# [Ep 300, Step 60] Score: 1796 | Reward: -0.10 | Epsilon: 0.2234 | Action: (7, 6) Flag | Revealed: 54/59
# [Ep 300, Step 66] Score: 1801 | Reward: -100.00 | Epsilon: 0.2234 | Action: (7, 7) Reveal | Revealed: 56/59
#
# Saving progress to ./models\mc_model_20251011_173429_checkpoint_ep300...
# Progress saved successfully.
#
# ============================================================
# Episode 300 finished: LOSS | Score: 1801 | Loss: 0.5347
# Episodes: 300 | Win Rate: 9.00% | Highest Score: 37650.00 | Time Efficiency: 7.37 steps/sec | Left Click Avg: 8.92 c/g (2.36 c/s) | Right Click Avg: 18.99 c/g (5.02 c/s) | Total Click Avg: 27.91 c/g (7.37 c/s) | Game Conclusion History: 27 Wins, 273 Losses
# ============================================================
#
#
# Saving progress to ./models\mc_model_20251011_173429...
# Progress saved successfully.

# %%
# pygame.quit()

# %%
# saveModel(MODEL_NAME, agent)
